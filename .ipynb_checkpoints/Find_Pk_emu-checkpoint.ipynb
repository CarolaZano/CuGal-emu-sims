# %%
from configobj import ConfigObj
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline
from scipy.interpolate import RegularGridInterpolator
import pyccl as ccl
from pyDOE2 import *
import matplotlib

#from HiCOLA import Frontend

# %% [markdown]
# # Get Latin Hypercube

# %%
def wr_funct(T_CMB):
    return 4.48150052e-7*T_CMB**4 *(1+ 3.044*7/8 * (4/11)**(4/3))

T_CMB = 2.72548 # K
print(wr_funct(T_CMB))
# Out:
# 4.182345109176885e-05

# %% [markdown]
# ## Get old design

# %%
# We have Omega_m*h^2 , n_s    , A_s  ,   E_ds   ,     f_phi
sample = np.loadtxt('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_as_design').T

print(sample.shape)

sample[-2] = (sample[-2] - np.min(sample[-2]))/(np.max(sample[-2]) - np.min(sample[-2]))
h_min = 0.61
h_max = 0.73
h_fid = 0.67
sample[-2] = sample[-2]* (h_max- h_min) + h_min
# Use Omega_m instead of omega_m
sample[0] = sample[0]/h_max**2
print(np.max(sample[0]) , np.min(sample[0]) )

# Use Omega_m instead of omega_cdm

sample[0] = sample[0] + 0.0223/0.67**2

print(np.max(sample[0]), np.min(sample[0]))


# Tuning f_phi

fig, ax = plt.subplots(1,1, sharex = True, sharey=True)
fig.set_size_inches(10,2)

f_phi_min = 0.02

sample[4] = sample[4]*(1-f_phi_min) + f_phi_min

ax.scatter((sample[4]),
           np.ones(len(sample[4])))

ax.axes.get_yaxis().set_ticks([])
ax.set_xlabel(r"$f_{\phi}$")


print(np.min(sample[4]), np.max(sample[4]))
print(np.argmin(sample[4]))
# Out:
# (5, 50)
# 0.28147870144492404 0.22518296115593922
# 0.33115568963828557 0.27485994934930075
# 0.02 1.0
# 35

# %%
fig, axs = plt.subplots(4, 4)

axs[0, 0].scatter(sample[1], sample[2], s=0.5)
axs[1, 0].scatter(sample[1], sample[0], s=0.5)
axs[2, 0].scatter(sample[1], sample[-1], s=0.5)
axs[3, 0].scatter(sample[1], sample[-2], s=0.5)

axs[1, 1].scatter(sample[2], sample[0], s=0.5)
axs[2, 1].scatter(sample[2], sample[-1], s=0.5)
axs[3, 1].scatter(sample[2], sample[-2], s=0.5)

axs[2, 2].scatter(sample[0], sample[-1], s=0.5)
axs[3, 2].scatter(sample[0], sample[-2], s=0.5)
axs[3, 3].scatter(sample[-1], sample[-2], s=0.5)

# Remove top corner
axs[2, 3].set_axis_off()
axs[1, 3].set_axis_off()
axs[0, 3].set_axis_off()
axs[1, 2].set_axis_off()
axs[0, 2].set_axis_off()
axs[0, 1].set_axis_off()
# Remove excess axes
axs[0, 0].get_xaxis().set_visible(False)
axs[1, 0].get_xaxis().set_visible(False)
axs[1, 1].get_xaxis().set_visible(False)
axs[2, 0].get_xaxis().set_visible(False)
axs[2, 1].get_xaxis().set_visible(False)
axs[2, 2].get_xaxis().set_visible(False)
axs[1, 1].get_yaxis().set_visible(False)
axs[2, 1].get_yaxis().set_visible(False)
axs[3, 1].get_yaxis().set_visible(False)
axs[2, 2].get_yaxis().set_visible(False)
axs[3, 2].get_yaxis().set_visible(False)
axs[3, 3].get_yaxis().set_visible(False)

axs[0, 0].set_ylabel(r"$A_{s}$")
axs[1, 0].set_ylabel(r"$\Omega_{m}$")
axs[2, 0].set_ylabel(r"$f_{\phi}$")
axs[3, 0].set_ylabel(r"$h$")
axs[3, 0].set_xlabel(r"$n_s$")
axs[3, 1].set_xlabel(r"$A_{s}$")
axs[3, 2].set_xlabel(r"$\Omega_{m}$")
axs[3, 3].set_xlabel(r"$f_{\phi}$")

plt.show()
# 0.223 < Omg_m < 0.364
# 0.953 < n_s < 1.063
# 2.03 < 10^9 * A_s < 2.204     # from planck paper only - because of tension 3 sigma
# 0.0465 < Omg_b < 0.0566
# 0.631 < h < 0.721

# %%
print(np.max(sample[2]))
print(np.min(sample[2]))
# Out:
# 3.291e-09
# 1.453e-09

# %% [markdown]
# ### Investigating quadratic sampling

# %%
# f_phi = (x - 0.5)^2
pow = 0.8
fphi = np.sign(sample[4] - 0.5) * np.abs(sample[4] - 0.5)**pow /0.5**(pow-1) + 0.5

# %%
print(np.min(np.append(sample[4][:np.argmin(sample[4])],sample[4][np.argmin(sample[4])+1 :])))
print(sample[4])
print(fphi)
# Out:
# 0.02041
# [0.4694  0.5714  0.2041  0.2653  0.3061  0.5102  0.4082  0.08163 0.8571
#  0.3469  0.8367  0.02041 0.898   0.2245  1.      0.6122  0.6327  0.449
#  0.9592  0.8776  0.1837  0.3265  0.2449  0.06122 0.2857  0.7143  0.9388
#  0.7551  0.6735  0.8163  0.1224  0.04082 0.551   0.3673  0.3878  0.
#  0.7755  0.102   0.9796  0.1633  0.6531  0.1429  0.9184  0.5918  0.4898
#  0.6939  0.7347  0.7959  0.4286  0.5306 ]
# [0.44649786 0.60537864 0.17136791 0.22697371 0.2656547  0.52221642
#  0.37115483 0.06644677 0.88196703 0.30601232 0.8644085  0.01639576
#  0.91658196 0.18962175 1.         0.65128236 0.67301778 0.41948994
#  0.96708455 0.8994106  0.15336425 0.28559565 0.20814821 0.04960718
#  0.24612979 0.75387021 0.95040924 0.79185179 0.71440435 0.84663575
#  0.1005894  0.03293172 0.58051006 0.32698222 0.34871764 0.
#  0.81037825 0.08341804 0.9836123  0.1355915  0.69398768 0.11803297
#  0.9335781  0.62884517 0.47778358 0.7343453  0.77302629 0.82863209
#  0.39462136 0.55350214]

# %%
fig, ax = plt.subplots(1,1, sharex = True, sharey=True)
fig.set_size_inches(10,2)

ax.scatter((sample[4]),
           np.ones(len(sample[4])))

ax.axes.get_yaxis().set_ticks([])
ax.set_xlabel(r"$f_{\phi}$")
# Out:
# Text(0.5, 0, '$f_{\\phi}$')

# %%
"""Show with f_phi rather than log(f_phi) -will not be used in analysis"""

fig, axs = plt.subplots(3,3)

axs[0, 0].scatter(sample_new[1], sample_new[2], s=0.5)
axs[1, 0].scatter(sample_new[1], sample_new[0], s=0.5)
axs[2, 0].scatter(sample_new[1], fphi, s=0.5)

axs[1, 1].scatter(sample_new[2], sample_new[0], s=0.5)
axs[2, 1].scatter(sample_new[2], fphi, s=0.5)

axs[2, 2].scatter(sample_new[0], fphi, s=0.5)

# Remove top corner
axs[1, 2].set_axis_off()
axs[0, 2].set_axis_off()
axs[0, 1].set_axis_off()
# Remove excess axes
axs[0, 0].get_xaxis().set_visible(False)
axs[1, 0].get_xaxis().set_visible(False)
axs[1, 1].get_xaxis().set_visible(False)

axs[1, 1].get_yaxis().set_visible(False)
axs[2, 1].get_yaxis().set_visible(False)
axs[2, 2].get_yaxis().set_visible(False)

axs[0, 0].set_ylabel(r"$A_{s}$")
axs[1, 0].set_ylabel(r"$w_{m}$")
axs[2, 0].set_ylabel(r"$f_{\phi}$")
axs[2, 0].set_xlabel(r"$n_s$")
axs[2, 1].set_xlabel(r"$A_{s}$")
axs[2, 2].set_xlabel(r"$w_{m}$")
fig.suptitle(r"logarithmic sampling in $f_{\phi}$ [$f_{\phi}$ plot]")

plt.show()
# 0.223 < Omg_m < 0.364
# 0.953 < n_s < 1.063
# 2.03 < 10^9 * A_s < 2.204     # from planck paper only - because of tension 3 sigma
# 0.0465 < Omg_b < 0.0566
# 0.631 < h < 0.721

# %% [markdown]
# ### Investigating using logf_phi sample

# %%
np.log10(3e-2)
# Out:
# -1.5228787452803376

# %%
log10fphi = sample[4]*1.5228787452803376 -1.5228787452803376
fphi = 10**log10fphi

sample_new = np.array([sample[0],sample[1],sample[2],log10fphi])


print(sample_new.shape)
# Out:
# (4, 50)

# %%
fig, axs = plt.subplots(3,3)

axs[0, 0].scatter(sample_new[1], sample_new[2], s=0.5)
axs[1, 0].scatter(sample_new[1], sample_new[0], s=0.5)
axs[2, 0].scatter(sample_new[1], sample_new[-1], s=0.5)

axs[1, 1].scatter(sample_new[2], sample_new[0], s=0.5)
axs[2, 1].scatter(sample_new[2], sample_new[-1], s=0.5)

axs[2, 2].scatter(sample_new[0], sample_new[-1], s=0.5)

# Remove top corner
axs[1, 2].set_axis_off()
axs[0, 2].set_axis_off()
axs[0, 1].set_axis_off()
# Remove excess axes
axs[0, 0].get_xaxis().set_visible(False)
axs[1, 0].get_xaxis().set_visible(False)
axs[1, 1].get_xaxis().set_visible(False)

axs[1, 1].get_yaxis().set_visible(False)
axs[2, 1].get_yaxis().set_visible(False)
axs[2, 2].get_yaxis().set_visible(False)

axs[0, 0].set_ylabel(r"$A_{s}$")
axs[1, 0].set_ylabel(r"$w_{m}$")
axs[2, 0].set_ylabel(r"log$_{10}(f_{\phi})$")
axs[2, 0].set_xlabel(r"$n_s$")
axs[2, 1].set_xlabel(r"$A_{s}$")
axs[2, 2].set_xlabel(r"$w_{m}$")

fig.suptitle(r"logarithmic sampling in $f_{\phi}$ [log$(f_{\phi})$ plot]")

plt.show()
# 0.223 < Omg_m < 0.364
# 0.953 < n_s < 1.063
# 2.03 < 10^9 * A_s < 2.204     # from planck paper only - because of tension 3 sigma
# 0.0465 < Omg_b < 0.0566
# 0.631 < h < 0.721

# %%
"""Show with f_phi rather than log(f_phi) -will not be used in analysis"""

fig, axs = plt.subplots(3,3)

axs[0, 0].scatter(sample_new[1], sample_new[2], s=0.5)
axs[1, 0].scatter(sample_new[1], sample_new[0], s=0.5)
axs[2, 0].scatter(sample_new[1], fphi, s=0.5)

axs[1, 1].scatter(sample_new[2], sample_new[0], s=0.5)
axs[2, 1].scatter(sample_new[2], fphi, s=0.5)

axs[2, 2].scatter(sample_new[0], fphi, s=0.5)

# Remove top corner
axs[1, 2].set_axis_off()
axs[0, 2].set_axis_off()
axs[0, 1].set_axis_off()
# Remove excess axes
axs[0, 0].get_xaxis().set_visible(False)
axs[1, 0].get_xaxis().set_visible(False)
axs[1, 1].get_xaxis().set_visible(False)

axs[1, 1].get_yaxis().set_visible(False)
axs[2, 1].get_yaxis().set_visible(False)
axs[2, 2].get_yaxis().set_visible(False)

axs[0, 0].set_ylabel(r"$A_{s}$")
axs[1, 0].set_ylabel(r"$w_{m}$")
axs[2, 0].set_ylabel(r"$f_{\phi}$")
axs[2, 0].set_xlabel(r"$n_s$")
axs[2, 1].set_xlabel(r"$A_{s}$")
axs[2, 2].set_xlabel(r"$w_{m}$")
fig.suptitle(r"logarithmic sampling in $f_{\phi}$ [$f_{\phi}$ plot]")

plt.show()
# 0.223 < Omg_m < 0.364
# 0.953 < n_s < 1.063
# 2.03 < 10^9 * A_s < 2.204     # from planck paper only - because of tension 3 sigma
# 0.0465 < Omg_b < 0.0566
# 0.631 < h < 0.721

# %% [markdown]
# ### Investigating using a mix of log and linear sampling

# %%
n_cutoff = 0.5
fphi_min = np.log10(3e-3)
ratio_edges = 0.5/((n_cutoff)/10**((0.5)*(-fphi_min) + fphi_min))

f_phi_doublelog = (1 - (n_cutoff)/0.17320508075688773*10** ((1-sample[4])*1.5228787452803376 -1.5228787452803376))*np.heaviside(sample[4] - 0.5, 0) +\
           np.heaviside(0.5- sample[4] , 0) * (1-n_cutoff)/0.17320508075688773*10** (sample[4]*1.5228787452803376 -1.5228787452803376)

f_phi_doublelog = (1 - (n_cutoff)/ratio_edges*10**((1-sample[4])*(-fphi_min) + fphi_min))*np.heaviside(sample[4] - 0.5, 0) +\
           np.heaviside(0.5- sample[4] , 0) * (1-n_cutoff)/ratio_edges*10** (sample[4]*(-fphi_min) +fphi_min)

fig, ax = plt.subplots(1,1, sharex = True, sharey=True)
fig.set_size_inches(10,2)

ax.scatter(np.log10(f_phi_doublelog),
           np.ones(len(sample[4])))

print("f_phi_min = ", (np.min(f_phi_doublelog)))
print("f_phi_max = ", (np.max(f_phi_doublelog)))
"""
n_base = 20

plt.scatter((1 - 0.5/0.17320508075688773* n_base ** ((1-sample[4])*(-1*np.emath.logn(n_base, 3e-2)) + np.emath.logn(n_base, 3e-2)))
            *np.heaviside(sample[4] - 0.5, 0) +
           np.heaviside(0.5 - sample[4] , 0) * 0.5/0.17320508075688773* n_base ** (sample[4]*np.emath.logn(n_base, 3e-2)*-1
                                                +np.emath.logn(n_base, 3e-2)),
           np.ones(len(sample[4])))
"""
count = 0
for i in range(len(f_phi_doublelog)):
    if f_phi_doublelog[i] < n_cutoff:
        count += 1
print(count)
ax.axes.get_yaxis().set_ticks([])
ax.set_xlabel(r"log$_{10}(f_{\phi})$")
# Out:
# f_phi_min =  0.027386127875258306
# f_phi_max =  0.9726138721247417
# 25
# Text(0.5, 0, 'log$_{10}(f_{\\phi})$')

# %%
print(np.heaviside(0.8 - 0.7, 0))
print(np.heaviside(0.6 - 0.7, 0))
# Out:
# 1.0
# 0.0

# %%
fig, axs = plt.subplots(4, 4)

axs[0, 0].scatter(sample[1], sample[2], s=0.5)
axs[1, 0].scatter(sample[1], sample[0], s=0.5)
axs[2, 0].scatter(sample[1], np.log10(f_phi_doublelog), s=0.5)
axs[3, 0].scatter(sample[1], sample[3], s=0.5)

axs[1, 1].scatter(sample[2], sample[0], s=0.5)
axs[2, 1].scatter(sample[2], np.log10(f_phi_doublelog), s=0.5)
axs[3, 1].scatter(sample[2], sample[3], s=0.5)

axs[2, 2].scatter(sample[0], np.log10(f_phi_doublelog), s=0.5)
axs[3, 2].scatter(sample[0], sample[3], s=0.5)
axs[3, 3].scatter(np.log10(f_phi_doublelog), sample[-2], s=0.5)

# Remove top corner
axs[2, 3].set_axis_off()
axs[1, 3].set_axis_off()
axs[0, 3].set_axis_off()
axs[1, 2].set_axis_off()
axs[0, 2].set_axis_off()
axs[0, 1].set_axis_off()
# Remove excess axes
axs[0, 0].get_xaxis().set_visible(False)
axs[1, 0].get_xaxis().set_visible(False)
axs[1, 1].get_xaxis().set_visible(False)
axs[2, 0].get_xaxis().set_visible(False)
axs[2, 1].get_xaxis().set_visible(False)
axs[2, 2].get_xaxis().set_visible(False)
axs[1, 1].get_yaxis().set_visible(False)
axs[2, 1].get_yaxis().set_visible(False)
axs[3, 1].get_yaxis().set_visible(False)
axs[2, 2].get_yaxis().set_visible(False)
axs[3, 2].get_yaxis().set_visible(False)
axs[3, 3].get_yaxis().set_visible(False)

axs[0, 0].set_ylabel(r"$A_{s}$")
axs[1, 0].set_ylabel(r"$w_{m}$")
axs[2, 0].set_ylabel(r"$log_{10}(f_{\phi})$")
axs[3, 0].set_ylabel(r"$h$")
axs[3, 0].set_xlabel(r"$n_s$")
axs[3, 1].set_xlabel(r"$A_{s}$")
axs[3, 2].set_xlabel(r"$w_{m}$")
axs[3, 3].set_xlabel(r"$log_{10}(f_{\phi})$")

plt.show()
# 0.223 < Omg_m < 0.364
# 0.953 < n_s < 1.063
# 2.03 < 10^9 * A_s < 2.204     # from planck paper only - because of tension 3 sigma
# 0.0465 < Omg_b < 0.0566
# 0.631 < h < 0.721

# %%
"""Show with f_phi rather than log(f_phi) -will not be used in analysis"""

fig, axs = plt.subplots(3,3)

axs[0, 0].scatter(sample_new[1], sample_new[2], s=0.5)
axs[1, 0].scatter(sample_new[1], sample_new[0], s=0.5)
axs[2, 0].scatter(sample_new[1], f_phi_doublelog, s=0.5)

axs[1, 1].scatter(sample_new[2], sample_new[0], s=0.5)
axs[2, 1].scatter(sample_new[2], f_phi_doublelog, s=0.5)

axs[2, 2].scatter(sample_new[0], f_phi_doublelog, s=0.5)

# Remove top corner
axs[1, 2].set_axis_off()
axs[0, 2].set_axis_off()
axs[0, 1].set_axis_off()
# Remove excess axes
axs[0, 0].get_xaxis().set_visible(False)
axs[1, 0].get_xaxis().set_visible(False)
axs[1, 1].get_xaxis().set_visible(False)

axs[1, 1].get_yaxis().set_visible(False)
axs[2, 1].get_yaxis().set_visible(False)
axs[2, 2].get_yaxis().set_visible(False)

axs[0, 0].set_ylabel(r"$A_{s}$")
axs[1, 0].set_ylabel(r"$w_{m}$")
axs[2, 0].set_ylabel(r"$f_{\phi}$")
axs[2, 0].set_xlabel(r"$n_s$")
axs[2, 1].set_xlabel(r"$A_{s}$")
axs[2, 2].set_xlabel(r"$w_{m}$")
fig.suptitle(r"double logarithmic sampling in $f_{\phi}$ [$f_{\phi}$ plot]")

plt.show()
# 0.223 < Omg_m < 0.364
# 0.953 < n_s < 1.063
# 2.03 < 10^9 * A_s < 2.204     # from planck paper only - because of tension 3 sigma
# 0.0465 < Omg_b < 0.0566
# 0.631 < h < 0.721

# %%
# get list in index of f_phi in increasing order of f_phi

def sort_by_indexes(lst, indexes, reverse=False):
  return [val for (_, val) in sorted(zip(indexes, lst), key=lambda x: \
          x[0], reverse=reverse)]
    
indx_fphi = np.arange(0,len(fphi))

newsort = sort_by_indexes(indx_fphi, fphi)

odd_i = []
even_i = []
for i in range(0, len(newsort)):
    if i % 2:
        even_i.append(newsort[i])
    else :
        odd_i.append(newsort[i])

# get list in index of f_phi in increasing order of f_phi

f_phi_new_evenspace = (np.array(log10fphi) + 1.5228787452803376)/1.5228787452803376

sample_new_double = []
for i in range(0, len(f_phi_new_evenspace)):
    if i in odd_i:
        plt.scatter(fphi[i], 1, color="r")
        sample_new_double.append(fphi[i])
    else:
        plt.scatter(f_phi_new_evenspace[i], 1, color="b")
        sample_new_double.append(f_phi_new_evenspace[i])

# %%
fig, axs = plt.subplots(2,1, sharex = True, sharey=True)
fig.set_size_inches(10,3)

axs[0].scatter(fphi, np.ones(len(fphi)), color="b")


axs[1].axes.get_yaxis().set_ticks([])
axs[0].axes.get_yaxis().set_ticks([])
axs[1].set_xlabel(r"$f_{\phi}$")

fig.suptitle(r"comparing logarithmic sampling with a mixed linear and logarithmic sampling in $f_{\phi}$")

for i in range(0, len(fphi)):
    if i in even_i:
        axs[0].scatter(fphi[i], 1, color="r")

for i in range(0, len(f_phi_new_evenspace)):
    if i in odd_i:
        axs[1].scatter(fphi[i], 1, color="r")
    else:
        axs[1].scatter(f_phi_new_evenspace[i], 1, color="b")

print(f_phi_new_evenspace[newsort[1]])
# Out:
# 0.02040999999999996

# %%
plt.scatter(sample_new_double, np.ones(len(sample_new_double)), color="b")

# %%
fig, axs = plt.subplots(3,3)

axs[0, 0].scatter(sample_new[1], sample_new[2], s=0.5)
axs[1, 0].scatter(sample_new[1], sample_new[0], s=0.5)
axs[2, 0].scatter(sample_new[1], np.log10(sample_new_double), s=0.5)

axs[1, 1].scatter(sample_new[2], sample_new[0], s=0.5)
axs[2, 1].scatter(sample_new[2], np.log10(sample_new_double), s=0.5)

axs[2, 2].scatter(sample_new[0], np.log10(sample_new_double), s=0.5)

for i in range(0, len(fphi)):
    if i in odd_i:
        axs[2, 0].scatter(sample_new[1][i], np.log10(sample_new_double)[i], s=0.5, color="r")
        axs[2, 1].scatter(sample_new[2][i], np.log10(sample_new_double)[i], s=0.5, color="r")
        axs[2, 2].scatter(sample_new[0][i], np.log10(sample_new_double)[i], s=0.5, color="r")

# Remove top corner
axs[1, 2].set_axis_off()
axs[0, 2].set_axis_off()
axs[0, 1].set_axis_off()
# Remove excess axes
axs[0, 0].get_xaxis().set_visible(False)
axs[1, 0].get_xaxis().set_visible(False)
axs[1, 1].get_xaxis().set_visible(False)

axs[1, 1].get_yaxis().set_visible(False)
axs[2, 1].get_yaxis().set_visible(False)
axs[2, 2].get_yaxis().set_visible(False)

axs[0, 0].set_ylabel(r"$A_{s}$")
axs[1, 0].set_ylabel(r"$w_{m}$")
axs[2, 0].set_ylabel(r"log$_{10}(f_{\phi})$")
axs[2, 0].set_xlabel(r"$n_s$")
axs[2, 1].set_xlabel(r"$A_{s}$")
axs[2, 2].set_xlabel(r"$w_{m}$")

fig.suptitle(r"mixed linear and logarithmic sampling in $f_{\phi}$ [log$(f_{\phi})$ plot]")

plt.show()
# 0.223 < Omg_m < 0.364
# 0.953 < n_s < 1.063
# 2.03 < 10^9 * A_s < 2.204     # from planck paper only - because of tension 3 sigma
# 0.0465 < Omg_b < 0.0566
# 0.631 < h < 0.721

# %%
"""Show with f_phi rather than log(f_phi) -will not be used in analysis"""

fig, axs = plt.subplots(3,3)

axs[0, 0].scatter(sample_new[1], sample_new[2], s=0.5)
axs[1, 0].scatter(sample_new[1], sample_new[0], s=0.5)
axs[2, 0].scatter(sample_new[1], sample_new_double, s=0.5)

axs[1, 1].scatter(sample_new[2], sample_new[0], s=0.5)
axs[2, 1].scatter(sample_new[2], sample_new_double, s=0.5)

axs[2, 2].scatter(sample_new[0], sample_new_double, s=0.5)

for i in range(0, len(fphi)):
    if i in odd_i:
        axs[2, 0].scatter(sample_new[1][i], sample_new_double[i], s=0.5, color="r")
        axs[2, 1].scatter(sample_new[2][i], sample_new_double[i], s=0.5, color="r")
        axs[2, 2].scatter(sample_new[0][i], sample_new_double[i], s=0.5, color="r")

# Remove top corner
axs[1, 2].set_axis_off()
axs[0, 2].set_axis_off()
axs[0, 1].set_axis_off()
# Remove excess axes
axs[0, 0].get_xaxis().set_visible(False)
axs[1, 0].get_xaxis().set_visible(False)
axs[1, 1].get_xaxis().set_visible(False)

axs[1, 1].get_yaxis().set_visible(False)
axs[2, 1].get_yaxis().set_visible(False)
axs[2, 2].get_yaxis().set_visible(False)

axs[0, 0].set_ylabel(r"$A_{s}$")
axs[1, 0].set_ylabel(r"$w_{m}$")
axs[2, 0].set_ylabel(r"$f_{\phi}$")
axs[2, 0].set_xlabel(r"$n_s$")
axs[2, 1].set_xlabel(r"$A_{s}$")
axs[2, 2].set_xlabel(r"$w_{m}$")
fig.suptitle(r"mixed linear and logarithmic sampling in $f_{\phi}$ [$f_{\phi}$ plot]")

plt.show()
# 0.223 < Omg_m < 0.364
# 0.953 < n_s < 1.063
# 2.03 < 10^9 * A_s < 2.204     # from planck paper only - because of tension 3 sigma
# 0.0465 < Omg_b < 0.0566
# 0.631 < h < 0.721

# %% [markdown]
# ### Saving the chosen sampling strategy

# %%
# We want Omega_m , n_s    , A_s ,h,  f_phi

sample_new = np.array([sample[0],sample[1],sample[2],sample[3],sample[4]])

np.savetxt('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker', sample_new.T)

# %% [markdown]
# # Run Backend

# %% [markdown]
# ## Get Power Spectra

# %%
## Power spectrum from CCL - backscaling

Pk_ccl = np.zeros((len(sample_new[0]),500))

## Linear Power spectra
for i in range(len(sample_new[0])):
    
    wb = 0.0223
    wr = wr_funct(T_CMB)

    ns = sample_new[1]
    As = sample_new[2]
    h = sample_new[3]
    wm = sample_new[0]*h**2

    kk_ccl = np.logspace(-3,1,len(Pk_ccl[0]))*h[i]               # in 1/Mpc
    cosmoLCDM = ccl.Cosmology(Omega_c=(wm[i] - wb)/h[i]**2,
                               Omega_b=wb/h[i]**2, 
                               A_s=As[i], 
                               h = h[i],
                               n_s=ns[i],
                               Omega_k=0)

# Omega_g::: Note that if a non-None value is given, this may result in a physically 
# inconsistent model because the CMB temperature will still be non-zero in the parameters.
    cosmoLCDM_norad = ccl.Cosmology(Omega_c=(wm[i] - wb)/h[i]**2,
                               Omega_b=wb/h[i]**2, 
                               A_s=As[i], 
                               h = h[i],
                               n_s=ns[i],
                               Omega_k=0,
                               Omega_g = 0,
                               T_CMB = 0.0)

    Pk_0 = ccl.power.linear_matter_power(cosmoLCDM, kk_ccl, 1)    # in (Mpc)^3

    Growth_0 = ccl.background.growth_factor(cosmoLCDM_norad, 1)

    Growth_49 = ccl.background.growth_factor(cosmoLCDM_norad, 1/(1+49))

    Pk_ccl[i] = (Growth_49/Growth_0)**2 * Pk_0*h[i]**3    # in (Mpc)^3/h^3

    kk_ccl = kk_ccl/h[i]    # in h/Mpc
## Save power spectrum for initial conditions (Linear)
    np.savetxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_{}.dat".format(i), np.array([kk_ccl, Pk_ccl[i]]).T)

kk_ccl = np.logspace(-3,1,500)

# %%
## Plot power spectra (at z = 49, expect very different from z=0)

for i in range(50):
    plt.plot(kk_ccl,Pk_ccl[i])

plt.xscale("log")
plt.yscale("log")

# %% [markdown]
# ## Get expansion and force files

# %%
"""Define tracker functions"""

# If we are on the tracker, we will get the following constraints equations

# For today formalism 
def k_1T(Omg_m, Omg_r, f_phi):
    return 6*f_phi*(Omg_m + Omg_r - 1)

# dS formalism

def E_dS(Omg_m, Omg_r, f_phi):

    return np.sqrt((1-f_phi)*(1-Omg_m-Omg_r)/2 + np.sqrt(
        ((1-f_phi)*(1-Omg_m-Omg_r)/2)**2 + f_phi*(1-Omg_m-Omg_r)
    ))

# %%
''' Define useful functions'''

def hypercube_arrays(txt):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi)
    returns two arrays, one for numerical and one for horndeski array
    # numerical - [h , wr , wb , wc, n_s , A_s]
    # horndeski - [f_phi, H0, k_1, g_31]
    """
    hcube = np.loadtxt(txt).T

    wb = 0.0223*np.ones(len(hcube[0]))
    wr = wr_funct(T_CMB)*np.ones(len(hcube[0]))
    
    n_s = hcube[1]
    A_s = hcube[2]
    h = hcube[3]
    wm = hcube[0]*h**2


    arr_num = [h, wr, wb, wm - wb, n_s, A_s]
    
    return arr_num

def Update_ini(run, f_phi, arr_num, horn_ini, num_ini):
    """
    Updates files num_ini and horn_ini to include the parameters (numerical and MG) from 
    f_phi and
    arr_num = h , wr , wb , wc, n_s , A_s
    """
    ## Horndeski params
    h , wr , wb , wc, n_s , A_s = arr_num
    config_h = ConfigObj(horn_ini)
    
    k1_track = k_1T((wc + wb)/h**2, wr/h**2, f_phi)

    keys_h = config_h.keys()
    
    config_h[keys_h[1]] = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output'
    config_h[keys_h[0]] = 'horndeski_model'
    
    config_h[keys_h[2]] = 'k_1*X'
    config_h[keys_h[3]] = 'g_31*X'
    config_h[keys_h[4]] = '0.5'

    config_h[keys_h[7]] = str(k1_track)
    config_h[keys_h[8]] = str("1")
    config_h[keys_h[9]] = str(f_phi)
    config_h[keys_h[10]] = str("1")
    config_h[keys_h[11]] = str("1")
    config_h[keys_h[20]] = str("False")
    config_h[keys_h[22]] = str("1")
    
    ## Numerical params
    config_n = ConfigObj(num_ini)
    keys_n = config_n.keys()
    
    config_n[keys_n[0]] = 'run_'+str(run)

    
    config_n[keys_n[6]] = str(h)
    config_n[keys_n[7]] = str(wr)
    config_n[keys_n[8]] = str(wb)
    config_n[keys_n[9]] = str(wc)
    config_h.filename = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini'
    config_n.filename = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'
    config_h.write(); config_n.write()

# %%
"""!!!!! CAREFUL WHEN RUNNING THIS deletes a whole directory of frontend parameter files"""
### Run frontend for all different .ini files

command = 'cd; rm -r /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/'
os.system(command)
command = 'cd /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/; mkdir Output'
os.system(command)

txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

a_n = hypercube_arrays(txt)
for i in range(len(np.array(a_n).T)):
    Update_ini(str(i), np.loadtxt(txt).T[-1][i], np.array(a_n).T[i], '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_parameters.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_parameters.ini')
    command = 'cd ; cd /home/c2042999/HiCOLA_env/Hi-COLA; python3 -m HiCOLA.Frontend.generate_simulation_input /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'
    os.system(command)
# Out:
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-1.9525828731048485, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.31051391819899116
# Omega_r0 = 9.213906405331266e-05
# Omega_lambda0 = 0.3639634638861474
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 0.6508609577016169
# ...

# %% [markdown]
# ## Plot Backend

# %%
## Plotting ##
txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

a_n = hypercube_arrays(txt)

fig, ax = plt.subplots(3,1, figsize=(12,8),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0)

sample_new = np.loadtxt('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker').T

# We want Omega_m*h^2 , n_s    , A_s ,h,  f_phi
for i in range(len(a_n[0])):
    expansion_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_{}_expansion.txt".format(i))

    wr = wr_funct(T_CMB)
    h = sample_new[3][i]
    wm = sample_new[0][i]*h**2

    a_today = expansion_today.T[0]
    E_a_today = expansion_today.T[1]
    E_a_GR = np.sqrt((wm)*a_today**(-3) + wr*a_today**(-4) + (h**2 - (wm) -wr))/h

    ax[0].plot(1/a_today -1, E_a_today/E_a_GR, alpha=0.7)

    force_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_{}_force.txt".format(i))

    a_today = force_today.T[0]
    chiD_today = force_today.T[1]
    coupling = force_today.T[2]

    ax[1].plot(1/a_today -1, chiD_today, alpha=0.7)

    ax[2].plot(1/a_today -1, coupling, alpha=0.7)

ax[0].set_xscale("log")
ax[2].set_xlabel("z")
ax[0].set_ylabel(r"$E^{CuGal}/E^{\Lambda CDM}$")

ax[1].set_ylabel(r"$chiD^{CuGal}/chiD^{\Lambda CDM}$")
ax[2].set_ylabel(r"$coupling^{CuGal}$")
# Out:
# Text(0, 0.5, '$coupling^{CuGal}$')

# %%
## Plotting ##
txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

cmap = matplotlib.colormaps['viridis']

a_n = hypercube_arrays(txt)

fig, ax = plt.subplots(2,1, figsize=(12,6),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0)

sample_new = np.loadtxt('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker').T

theta = sample_new[-1]
frac0 = (theta - min(theta))/(max(theta)-min(theta))
norm0 = matplotlib.colors.Normalize(vmin=min(theta), vmax=max(theta))
print(np.argmax(np.delete(frac0,14)))
print(np.argmax(frac0))
print(a_n[4][38])
print(a_n[4][14])
cbar = fig.colorbar(matplotlib.cm.ScalarMappable(norm=norm0, cmap=cmap), ax = ax, orientation='vertical')
cbar.set_label('$f_{\phi}$', rotation=0, fontsize=15)


# We want Omega_m*h^2 , n_s    , A_s ,h,  f_phi
for i in range(len(a_n[0])):
    expansion_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_{}_expansion.txt".format(i))

    wr = wr_funct(T_CMB)
    h = sample_new[3][i]
    wm = sample_new[0][i]*h**2

    a_today = expansion_today.T[0]
    E_a_today = expansion_today.T[1]
    E_a_GR = np.sqrt((wm)*a_today**(-3) + wr*a_today**(-4) + (h**2 - (wm) -wr))/h

    ax[0].plot(1/a_today -1, E_a_today/E_a_GR, alpha=0.7, color = cmap(frac0[i]))

    force_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_{}_force.txt".format(i))

    a_today = force_today.T[0]
    chiD_today = force_today.T[1]
    coupling = force_today.T[2]


    ax[1].semilogy(1/a_today -1, coupling, alpha=0.7, color = cmap(frac0[i]))

ax[0].set_xscale("log")
ax[1].set_xlabel("z", fontsize=15)
ax[0].set_ylabel(r"$E^{CuGal}/E^{\Lambda CDM}$", fontsize=15)

ax[1].set_ylabel(r"$\beta(z)$", fontsize=15)
ax[1].set_xlim(5e-3,1e3)

#plt.savefig('/home/c2042999/PCA_project/HiCOLA_frontend.pdf' , bbox_inches='tight')
# Out:
# 37
# 14
# 0.9673
# 0.8959
# (0.005, 1000.0)

# %% [markdown]
# # Run Frontend

# %%
# Create cola folders - only need to do this once

#for i in range(len(np.array(a_n).T)):
    # CAREFUL!! might not need this next step
    #command = 'cd; rm -r /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_{}_tracker'.format(str(i))
    #os.system(command)
    #os.system("cd; cd /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/; mkdir COLA_{}_tracker".format(str(i)))
    #command = 'cd; rm -r /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_{}_GR_tracker'.format(str(i))
    #os.system(command)
    #os.system("cd; cd /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/; mkdir COLA_{}_GR_tracker".format(str(i)))

# %%
def rewriteluafile(k,txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    wb = 0.0223
    wr = wr_funct(T_CMB)
    
    hcube = np.loadtxt(txt).T
    n_s = hcube[1][k]
    A_s = hcube[2][k]
    h = hcube[3][k]
    wm = hcube[0][k]*h**2

    f_phi = hcube[4][k]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}_tracker.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_{}_tracker"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_{}_expansion.txt"'.format(str(k))+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_{}_force.txt"'.format(str(k))+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_{}_tracker"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = false'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_{}.dat"'.format(str(k))+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# Same as above
txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

# %%
def rewriteluafile_phasepair(k,txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    wb = 0.0223
    wr = wr_funct(T_CMB)
    
    hcube = np.loadtxt(txt).T
    n_s = hcube[1][k]
    A_s = hcube[2][k]
    h = hcube[3][k]
    wm = hcube[0][k]*h**2

    f_phi = hcube[4][k]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}_tracker_phasepair.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_{}_tracker_phasepair"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_{}_expansion.txt"'.format(str(k))+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_{}_force.txt"'.format(str(k))+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(3.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_{}_tracker"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = true'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_{}.dat"'.format(str(k))+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# Same as above
txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

# %%
"""Re-write lua file"""
for i in range(len(np.array(a_n).T)):
    rewriteluafile(i,txt,400,512,1536)
    # phase pair
    rewriteluafile_phasepair(i,txt,400,512,1536)

# %%
"""Create Pk"""
for i in range(len(np.array(a_n).T)):
    os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}_tracker.lua".format(str(i)))
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-5]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-5]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-5]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-5]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-5]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-5]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-5]
# ...

# %%
"""Create Pk phasepair"""
for i in range(len(np.array(a_n).T)):
    os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}_tracker_phasepair.lua".format(str(i)))

# %% [markdown]
# # Results

# %%
"Check phase pair"

k, Pk_NL_phase,Pk_Lin_phase = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_tracker/pofk_my_new_Hi-COLA_simulation_0_tracker_phasepair_cb_z0.000.txt").T
k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_tracker/pofk_my_new_Hi-COLA_simulation_0_tracker_cb_z0.000.txt").T

# %%
plt.plot(k,Pk_NL, label = "seed 108")
plt.plot(k, Pk_NL_phase, label="phase reverse for seed 108")

plt.plot(k,(Pk_NL_phase + Pk_NL)/2, "k", label = "phase pair average")

plt.xscale("log")
plt.yscale("log")
plt.ylabel("P(k)")
plt.legend()
