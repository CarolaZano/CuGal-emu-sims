# %%
from configobj import ConfigObj
import subprocess
import numpy as np
import scipy
import os
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline
from scipy.interpolate import RegularGridInterpolator
import pyccl as ccl
from pyDOE2 import *
import matplotlib
import itertools
#from HiCOLA import Frontend

# %%
sample_new = np.loadtxt('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_validation_edges').T

# %% [markdown]
# # Run Frontend

# %%
def rewriteluafile(k,txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,h,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    wb = 0.0223
    wr = wr_funct(T_CMB)
    
    hcube = np.loadtxt(txt).T
    n_s = hcube[1][k]
    A_s = hcube[2][k]
    h = hcube[3][k]
    wm = hcube[0][k]*h**2

    f_phi = hcube[4][k]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles_validation_edges/Hi-COLA_params_emu_{}_GR_tracker.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_{}_GR_tracker"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend_validation_edges/COLA_{}_GR_tracker"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {100}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = false'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z_validation_edges/Pk_lin_z49_LCDM_backscaled_{}.dat"'.format(str(k))+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
def hypercube_arrays(txt):
    """
    Takes in txt file with (omega_m,n_s,A_s,h,f_phi)
    returns two arrays, one for numerical and one for horndeski array
    # numerical - [h , wr , wb , wc, n_s , A_s]
    # horndeski - [f_phi, H0, k_1, g_31]
    """
    hcube = np.loadtxt(txt).T

    wb = 0.0223*np.ones(len(hcube[0]))
    wr = wr_funct(T_CMB)*np.ones(len(hcube[0]))
    
    n_s = hcube[1]
    A_s = hcube[2]
    h = hcube[3]
    wm = hcube[0]*h**2


    arr_num = [h, wr, wb, wm - wb, n_s, A_s]
    
    return arr_num

def wr_funct(T_CMB):
    return 4.48150052e-7*T_CMB**4 *(1+ 3.044*7/8 * (4/11)**(4/3))

T_CMB = 2.72548 # K

txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_validation_edges'

a_n = hypercube_arrays(txt)

# %%
def rewriteluafile_phasepair(k,txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    wb = 0.0223
    wr = wr_funct(T_CMB)
    
    hcube = np.loadtxt(txt).T
    n_s = hcube[1][k]
    A_s = hcube[2][k]
    h = hcube[3][k]
    wm = hcube[0][k]*h**2

    f_phi = hcube[4][k]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles_validation_edges/Hi-COLA_params_emu_{}_GR_tracker_phasepair.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_{}_GR_tracker_phasepair"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(3.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend_validation_edges/COLA_{}_GR_tracker"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {100}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = true'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z_validation_edges/Pk_lin_z49_LCDM_backscaled_{}.dat"'.format(str(k))+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
"""Re-write lua file"""
for i in range(len(np.array(a_n).T)):
    rewriteluafile(i,txt,400,512,1536)
    # phase pair
    rewriteluafile_phasepair(i,txt,400,512,1536)

# %%
"""Create Pk"""
for i in range(len(np.array(a_n).T)):
    os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles_validation_edges/Hi-COLA_params_emu_{}_GR_tracker.lua".format(str(i)))
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-5]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-5]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-5]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-5]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-5]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-5]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-5]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-5]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-5]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-5]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-5]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-5]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-5]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-5]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-5]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-5]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-5]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-5]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-5]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-5]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-5]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-5]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-5]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-5]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-5]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-5]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-5]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-5]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-5]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-5]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-5]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-5]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 55 elements:
# #=====================================================
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 1.5895e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.222744
#   cosmology_OmegaLambda          : 0.717306
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.059837
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.610475
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : LCDM
#   cosmology_ns                   : 0.889661
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : GR
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z_validation_edges/Pk_lin_z49_LCDM_backscaled_0.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : false
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend_validation_edges/COLA_0_GR_tracker
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_0_GR_tracker
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              100 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [LCDM]
# # Omegab      : 0.059837
# # OmegaM      : 0.282581
# # OmegaMNu    : 0
# # OmegaCDM    : 0.222744
# # OmegaLambda : 0.717306
# # OmegaR      : 6.63546e-05
# # OmegaNu     : 4.59021e-05
# # OmegaRtot   : 0.000112257
# # OmegaK      : 0
# # h           : 0.610475
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 1.5895e-09
# # ns          : 0.889661
# # kpivot      : 0.05 1/Mpc
# #=====================================================
#
# #=====================================================
# # GravityModel is [GR] and has the cosmology: [LCDM]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_0_GR_tracker
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z_validation_edges/Pk_lin_z49_LCDM_backscaled_0.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : false
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 100
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend_validation_edges/COLA_0_GR_tracker
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z_validation_edges/Pk_lin_z49_LCDM_backscaled_0.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      3.25757         672503
# 0.00251653      6.7021          645104
# 0.00621709      11.7348         570873
# 0.0153593       14.0969         418446
# 0.0379453       6.62433         191834
# 0.0937441       2.04671         71311.6
# 0.231595        0.379089        20524.8
# 0.572157        0.0544685       5203.06
# 1.41352         0.00617881      1171.97
# 3.4921          0.000612008     246.672
# 8.62724         5.52503e-05     49.5661
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 13.8583 (Mpc/h)^3
# k =  0.10: P(k,zini) = 1.73682 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0144853 (Mpc/h)^3
# k = 10.00: P(k,zini) = 3.70544e-05 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.532847
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.547274 Mpc/h
# Maximum 1LPT velocity: 205.13 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.00429248 Mpc/h
# Maximum 2LPT velocity: 3.22888 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 100
# Step: 0    / 100
# Positions  from z = 49              -> 32.557
# Velocities from z = 49              -> 39.1606
# Step: 1    / 100
# Positions  from z = 32.557          -> 24.2525
# Velocities from z = 39.1606         -> 27.8184
# Step: 2    / 100
# Positions  from z = 24.2525         -> 19.2429
# Velocities from z = 27.8184         -> 21.4719
# Step: 3    / 100
# Positions  from z = 19.2429         -> 15.8919
# Velocities from z = 21.4719         -> 17.4162
# Step: 4    / 100
# Positions  from z = 15.8919         -> 13.4928
# Velocities from z = 17.4162         -> 14.6006
# Step: 5    / 100
# Positions  from z = 13.4928         -> 11.6904
# Velocities from z = 14.6006         -> 12.5318
# Step: 6    / 100
# Positions  from z = 11.6904         -> 10.2867
# Velocities from z = 12.5318         -> 10.9474
# Step: 7    / 100
# Positions  from z = 10.2867         -> 9.1626
# Velocities from z = 10.9474         -> 9.69519
# Step: 8    / 100
# Positions  from z = 9.1626          -> 8.24214
# Velocities from z = 9.69519         -> 8.68054
# Step: 9    / 100
# Positions  from z = 8.24214         -> 7.47458
# Velocities from z = 8.68054         -> 7.84173
# Step: 10   / 100
# Positions  from z = 7.47458         -> 6.82473
# Velocities from z = 7.84173         -> 7.1367
# Step: 11   / 100
# Positions  from z = 6.82473         -> 6.26744
# Velocities from z = 7.1367          -> 6.5358
# Step: 12   / 100
# Positions  from z = 6.26744         -> 5.78426
# Velocities from z = 6.5358          -> 6.01754
# Step: 13   / 100
# Positions  from z = 5.78426         -> 5.36132
# Velocities from z = 6.01754         -> 5.56599
# Step: 14   / 100
# Positions  from z = 5.36132         -> 4.98802
# Velocities from z = 5.56599         -> 5.16903
# Step: 15   / 100
# Positions  from z = 4.98802         -> 4.65611
# Velocities from z = 5.16903         -> 4.81734
# Step: 16   / 100
# Positions  from z = 4.65611         -> 4.35906
# Velocities from z = 4.81734         -> 4.50358
# Step: 17   / 100
# Positions  from z = 4.35906         -> 4.09165
# Velocities from z = 4.50358         -> 4.22193
# Step: 18   / 100
# Positions  from z = 4.09165         -> 3.84966
# Velocities from z = 4.22193         -> 3.96771
# Step: 19   / 100
# Positions  from z = 3.84966         -> 3.62963
# Velocities from z = 3.96771         -> 3.73709
# Step: 20   / 100
# Positions  from z = 3.62963         -> 3.4287
# Velocities from z = 3.73709         -> 3.52694
# Step: 21   / 100
# Positions  from z = 3.4287          -> 3.24448
# Velocities from z = 3.52694         -> 3.33463
# Step: 22   / 100
# Positions  from z = 3.24448         -> 3.07498
# Velocities from z = 3.33463         -> 3.158
# Step: 23   / 100
# Positions  from z = 3.07498         -> 2.9185
# Velocities from z = 3.158           -> 2.99521
# Step: 24   / 100
# Positions  from z = 2.9185          -> 2.77358
# Velocities from z = 2.99521         -> 2.84468
# Step: 25   / 100
# Positions  from z = 2.77358         -> 2.63901
# Velocities from z = 2.84468         -> 2.70508
# Step: 26   / 100
# Positions  from z = 2.63901         -> 2.5137
# Velocities from z = 2.70508         -> 2.57526
# Step: 27   / 100
# Positions  from z = 2.5137          -> 2.39674
# Velocities from z = 2.57526         -> 2.45423
# Step: 28   / 100
# Positions  from z = 2.39674         -> 2.28731
# Velocities from z = 2.45423         -> 2.34113
# Step: 29   / 100
# Positions  from z = 2.28731         -> 2.18471
# Velocities from z = 2.34113         -> 2.2352
# Step: 30   / 100
# Positions  from z = 2.18471         -> 2.08833
# Velocities from z = 2.2352          -> 2.13578
# Step: 31   / 100
# Positions  from z = 2.08833         -> 1.9976
# Velocities from z = 2.13578         -> 2.04229
# Step: 32   / 100
# Positions  from z = 1.9976          -> 1.91206
# Velocities from z = 2.04229         -> 1.95421
# Step: 33   / 100
# Positions  from z = 1.91206         -> 1.83126
# Velocities from z = 1.95421         -> 1.87109
# Step: 34   / 100
# Positions  from z = 1.83126         -> 1.75482
# Velocities from z = 1.87109         -> 1.79252
# Step: 35   / 100
# Positions  from z = 1.75482         -> 1.6824
# Velocities from z = 1.79252         -> 1.71813
# Step: 36   / 100
# Positions  from z = 1.6824          -> 1.6137
# Velocities from z = 1.71813         -> 1.6476
# Step: 37   / 100
# Positions  from z = 1.6137          -> 1.54842
# Velocities from z = 1.6476          -> 1.58065
# Step: 38   / 100
# Positions  from z = 1.54842         -> 1.48633
# Velocities from z = 1.58065         -> 1.51699
# Step: 39   / 100
# Positions  from z = 1.48633         -> 1.42718
# Velocities from z = 1.51699         -> 1.4564
# Step: 40   / 100
# Positions  from z = 1.42718         -> 1.37079
# Velocities from z = 1.4564          -> 1.39866
# Step: 41   / 100
# Positions  from z = 1.37079         -> 1.31696
# Velocities from z = 1.39866         -> 1.34357
# Step: 42   / 100
# Positions  from z = 1.31696         -> 1.26552
# Velocities from z = 1.34357         -> 1.29095
# Step: 43   / 100
# Positions  from z = 1.26552         -> 1.21631
# Velocities from z = 1.29095         -> 1.24065
# Step: 44   / 100
# Positions  from z = 1.21631         -> 1.1692
# Velocities from z = 1.24065         -> 1.1925
# Step: 45   / 100
# Positions  from z = 1.1692          -> 1.12404
# Velocities from z = 1.1925          -> 1.14638
# Step: 46   / 100
# Positions  from z = 1.12404         -> 1.08073
# Velocities from z = 1.14638         -> 1.10217
# Step: 47   / 100
# Positions  from z = 1.08073         -> 1.03915
# Velocities from z = 1.10217         -> 1.05973
# Step: 48   / 100
# Positions  from z = 1.03915         -> 0.9992
# Velocities from z = 1.05973         -> 1.01898
# Step: 49   / 100
# Positions  from z = 0.9992          -> 0.960784
# Velocities from z = 1.01898         -> 0.979806
# Step: 50   / 100
# Positions  from z = 0.960784        -> 0.923817
# Velocities from z = 0.979806        -> 0.942125
# Step: 51   / 100
# Positions  from z = 0.923817        -> 0.888218
# Velocities from z = 0.942125        -> 0.905851
# Step: 52   / 100
# Positions  from z = 0.888218        -> 0.853912
# Velocities from z = 0.905851        -> 0.870907
# Step: 53   / 100
# Positions  from z = 0.853912        -> 0.82083
# Velocities from z = 0.870907        -> 0.837222
# Step: 54   / 100
# Positions  from z = 0.82083         -> 0.788909
# Velocities from z = 0.837222        -> 0.804728
# Step: 55   / 100
# Positions  from z = 0.788909        -> 0.758087
# Velocities from z = 0.804728        -> 0.773364
# Step: 56   / 100
# Positions  from z = 0.758087        -> 0.72831
# Velocities from z = 0.773364        -> 0.743071
# Step: 57   / 100
# Positions  from z = 0.72831         -> 0.699524
# Velocities from z = 0.743071        -> 0.713796
# Step: 58   / 100
# Positions  from z = 0.699524        -> 0.671682
# Velocities from z = 0.713796        -> 0.685488
# Step: 59   / 100
# Positions  from z = 0.671682        -> 0.644737
# Velocities from z = 0.685488        -> 0.6581
# Step: 60   / 100
# Positions  from z = 0.644737        -> 0.618647
# Velocities from z = 0.6581          -> 0.631588
# Step: 61   / 100
# Positions  from z = 0.618647        -> 0.593372
# Velocities from z = 0.631588        -> 0.60591
# Step: 62   / 100
# Positions  from z = 0.593372        -> 0.568874
# Velocities from z = 0.60591         -> 0.581028
# Step: 63   / 100
# Positions  from z = 0.568874        -> 0.545117
# Velocities from z = 0.581028        -> 0.556905
# Step: 64   / 100
# Positions  from z = 0.545117        -> 0.52207
# Velocities from z = 0.556905        -> 0.533507
# Step: 65   / 100
# Positions  from z = 0.52207         -> 0.4997
# Velocities from z = 0.533507        -> 0.510802
# Step: 66   / 100
# Positions  from z = 0.4997          -> 0.477978
# Velocities from z = 0.510802        -> 0.48876
# Step: 67   / 100
# Positions  from z = 0.477978        -> 0.456876
# Velocities from z = 0.48876         -> 0.467351
# Step: 68   / 100
# Positions  from z = 0.456876        -> 0.436369
# Velocities from z = 0.467351        -> 0.44655
# Step: 69   / 100
# Positions  from z = 0.436369        -> 0.416431
# Velocities from z = 0.44655         -> 0.42633
# Step: 70   / 100
# Positions  from z = 0.416431        -> 0.397038
# Velocities from z = 0.42633         -> 0.406668
# Step: 71   / 100
# Positions  from z = 0.397038        -> 0.37817
# Velocities from z = 0.406668        -> 0.38754
# Step: 72   / 100
# Positions  from z = 0.37817         -> 0.359804
# Velocities from z = 0.38754         -> 0.368925
# Step: 73   / 100
# Positions  from z = 0.359804        -> 0.341922
# Velocities from z = 0.368925        -> 0.350804
# Step: 74   / 100
# Positions  from z = 0.341922        -> 0.324503
# Velocities from z = 0.350804        -> 0.333156
# Step: 75   / 100
# Positions  from z = 0.324503        -> 0.307531
# Velocities from z = 0.333156        -> 0.315963
# Step: 76   / 100
# Positions  from z = 0.307531        -> 0.290989
# Velocities from z = 0.315963        -> 0.299207
# Step: 77   / 100
# Positions  from z = 0.290989        -> 0.27486
# Velocities from z = 0.299207        -> 0.282874
# Step: 78   / 100
# Positions  from z = 0.27486         -> 0.259129
# Velocities from z = 0.282874        -> 0.266945
# Step: 79   / 100
# Positions  from z = 0.259129        -> 0.243781
# Velocities from z = 0.266945        -> 0.251408
# Step: 80   / 100
# Positions  from z = 0.243781        -> 0.228803
# Velocities from z = 0.251408        -> 0.236247
# Step: 81   / 100
# Positions  from z = 0.228803        -> 0.214182
# Velocities from z = 0.236247        -> 0.221449
# Step: 82   / 100
# Positions  from z = 0.214182        -> 0.199904
# Velocities from z = 0.221449        -> 0.207001
# Step: 83   / 100
# Positions  from z = 0.199904        -> 0.185958
# Velocities from z = 0.207001        -> 0.19289
# Step: 84   / 100
# Positions  from z = 0.185958        -> 0.172333
# Velocities from z = 0.19289         -> 0.179106
# Step: 85   / 100
# Positions  from z = 0.172333        -> 0.159017
# Velocities from z = 0.179106        -> 0.165637
# Step: 86   / 100
# Positions  from z = 0.159017        -> 0.146
# Velocities from z = 0.165637        -> 0.152472
# Step: 87   / 100
# Positions  from z = 0.146           -> 0.133273
# Velocities from z = 0.152472        -> 0.139601
# Step: 88   / 100
# Positions  from z = 0.133273        -> 0.120825
# Velocities from z = 0.139601        -> 0.127015
# Step: 89   / 100
# Positions  from z = 0.120825        -> 0.108647
# Velocities from z = 0.127015        -> 0.114703
# Step: 90   / 100
# Positions  from z = 0.108647        -> 0.0967317
# Velocities from z = 0.114703        -> 0.102657
# Step: 91   / 100
# Positions  from z = 0.0967317       -> 0.0850694
# Velocities from z = 0.102657        -> 0.0908694
# Step: 92   / 100
# Positions  from z = 0.0850694       -> 0.0736526
# Velocities from z = 0.0908694       -> 0.0793308
# Step: 93   / 100
# Positions  from z = 0.0736526       -> 0.0624734
# Velocities from z = 0.0793308       -> 0.0680337
# Step: 94   / 100
# Positions  from z = 0.0624734       -> 0.0515247
# Velocities from z = 0.0680337       -> 0.0569707
# Step: 95   / 100
# Positions  from z = 0.0515247       -> 0.0407993
# Velocities from z = 0.0569707       -> 0.0461345
# Step: 96   / 100
# Positions  from z = 0.0407993       -> 0.0302905
# Velocities from z = 0.0461345       -> 0.0355183
# Step: 97   / 100
# Positions  from z = 0.0302905       -> 0.0199918
# Velocities from z = 0.0355183       -> 0.0251153
# Step: 98   / 100
# Positions  from z = 0.0199918       -> 0.00989699
# Velocities from z = 0.0251153       -> 0.0149193
# Step: 99   / 100
# Positions  from z = 0.00989699      -> 0
# Velocities from z = 0.0149193       -> 0.00492413
# Step: 100  / 100
# Positions  from z = 0               -> 0
# Velocities from z = 0.00492413      -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 100 Total steps taken: 0
# Positions from  z = 49              -> 32.557
# Velocities from z = 49              -> 39.1606
# deltatime_pos = 4.76986         deltatime_vel = 3.0535
# Adding particles (baryons+CDM) to the densityfield

# %%
"""Create Pk phasepair"""
for i in range(len(np.array(a_n).T)):
    os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles_validation_edges/Hi-COLA_params_emu_{}_GR_tracker_phasepair.lua".format(str(i)))
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-5]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-5]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-5]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-5]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-5]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-5]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-5]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-5]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-5]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-5]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-5]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-5]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-5]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-5]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-5]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-5]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-5]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-5]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-5]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-5]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-5]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-5]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-5]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-5]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-5]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-5]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-5]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-5]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-5]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-5]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-5]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-5]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 55 elements:
# #=====================================================
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 1.5895e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.222744
#   cosmology_OmegaLambda          : 0.717306
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.059837
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.610475
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : LCDM
#   cosmology_ns                   : 0.889661
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : GR
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z_validation_edges/Pk_lin_z49_LCDM_backscaled_0.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : true
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend_validation_edges/COLA_0_GR_tracker
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 3
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_0_GR_tracker_phasepair
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              100 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [LCDM]
# # Omegab      : 0.059837
# # OmegaM      : 0.282581
# # OmegaMNu    : 0
# # OmegaCDM    : 0.222744
# # OmegaLambda : 0.717306
# # OmegaR      : 6.63546e-05
# # OmegaNu     : 4.59021e-05
# # OmegaRtot   : 0.000112257
# # OmegaK      : 0
# # h           : 0.610475
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 1.5895e-09
# # ns          : 0.889661
# # kpivot      : 0.05 1/Mpc
# #=====================================================
#
# #=====================================================
# # GravityModel is [GR] and has the cosmology: [LCDM]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_0_GR_tracker_phasepair
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z_validation_edges/Pk_lin_z49_LCDM_backscaled_0.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : true
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 3
# timestep_nsteps                          : 100
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend_validation_edges/COLA_0_GR_tracker
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z_validation_edges/Pk_lin_z49_LCDM_backscaled_0.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      3.25757         672503
# 0.00251653      6.7021          645104
# 0.00621709      11.7348         570873
# 0.0153593       14.0969         418446
# 0.0379453       6.62433         191834
# 0.0937441       2.04671         71311.6
# 0.231595        0.379089        20524.8
# 0.572157        0.0544685       5203.06
# 1.41352         0.00617881      1171.97
# 3.4921          0.000612008     246.672
# 8.62724         5.52503e-05     49.5661
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 13.8583 (Mpc/h)^3
# k =  0.10: P(k,zini) = 1.73682 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0144853 (Mpc/h)^3
# k = 10.00: P(k,zini) = 3.70544e-05 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.532847
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 200%% more particles
# # We will allocate ~1308.62 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 1308.62 MB (mean)
# #                   1308.62 MB (min)
# #                   1308.62 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 12582912
# # The buffer is 33.3333 %% (mean)
# #               33.3333 %% (min)
# #               33.3333 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.547274 Mpc/h
# Maximum 1LPT velocity: 205.13 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.00429248 Mpc/h
# Maximum 2LPT velocity: 3.22888 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 100
# Step: 0    / 100
# Positions  from z = 49              -> 32.557
# Velocities from z = 49              -> 39.1606
# Step: 1    / 100
# Positions  from z = 32.557          -> 24.2525
# Velocities from z = 39.1606         -> 27.8184
# Step: 2    / 100
# Positions  from z = 24.2525         -> 19.2429
# Velocities from z = 27.8184         -> 21.4719
# Step: 3    / 100
# Positions  from z = 19.2429         -> 15.8919
# Velocities from z = 21.4719         -> 17.4162
# Step: 4    / 100
# Positions  from z = 15.8919         -> 13.4928
# Velocities from z = 17.4162         -> 14.6006
# Step: 5    / 100
# Positions  from z = 13.4928         -> 11.6904
# Velocities from z = 14.6006         -> 12.5318
# Step: 6    / 100
# Positions  from z = 11.6904         -> 10.2867
# Velocities from z = 12.5318         -> 10.9474
# Step: 7    / 100
# Positions  from z = 10.2867         -> 9.1626
# Velocities from z = 10.9474         -> 9.69519
# Step: 8    / 100
# Positions  from z = 9.1626          -> 8.24214
# Velocities from z = 9.69519         -> 8.68054
# Step: 9    / 100
# Positions  from z = 8.24214         -> 7.47458
# Velocities from z = 8.68054         -> 7.84173
# Step: 10   / 100
# Positions  from z = 7.47458         -> 6.82473
# Velocities from z = 7.84173         -> 7.1367
# Step: 11   / 100
# Positions  from z = 6.82473         -> 6.26744
# Velocities from z = 7.1367          -> 6.5358
# Step: 12   / 100
# Positions  from z = 6.26744         -> 5.78426
# Velocities from z = 6.5358          -> 6.01754
# Step: 13   / 100
# Positions  from z = 5.78426         -> 5.36132
# Velocities from z = 6.01754         -> 5.56599
# Step: 14   / 100
# Positions  from z = 5.36132         -> 4.98802
# Velocities from z = 5.56599         -> 5.16903
# Step: 15   / 100
# Positions  from z = 4.98802         -> 4.65611
# Velocities from z = 5.16903         -> 4.81734
# Step: 16   / 100
# Positions  from z = 4.65611         -> 4.35906
# Velocities from z = 4.81734         -> 4.50358
# Step: 17   / 100
# Positions  from z = 4.35906         -> 4.09165
# Velocities from z = 4.50358         -> 4.22193
# Step: 18   / 100
# Positions  from z = 4.09165         -> 3.84966
# Velocities from z = 4.22193         -> 3.96771
# Step: 19   / 100
# Positions  from z = 3.84966         -> 3.62963
# Velocities from z = 3.96771         -> 3.73709
# Step: 20   / 100
# Positions  from z = 3.62963         -> 3.4287
# Velocities from z = 3.73709         -> 3.52694
# Step: 21   / 100
# Positions  from z = 3.4287          -> 3.24448
# Velocities from z = 3.52694         -> 3.33463
# Step: 22   / 100
# Positions  from z = 3.24448         -> 3.07498
# Velocities from z = 3.33463         -> 3.158
# Step: 23   / 100
# Positions  from z = 3.07498         -> 2.9185
# Velocities from z = 3.158           -> 2.99521
# Step: 24   / 100
# Positions  from z = 2.9185          -> 2.77358
# Velocities from z = 2.99521         -> 2.84468
# Step: 25   / 100
# Positions  from z = 2.77358         -> 2.63901
# Velocities from z = 2.84468         -> 2.70508
# Step: 26   / 100
# Positions  from z = 2.63901         -> 2.5137
# Velocities from z = 2.70508         -> 2.57526
# Step: 27   / 100
# Positions  from z = 2.5137          -> 2.39674
# Velocities from z = 2.57526         -> 2.45423
# Step: 28   / 100
# Positions  from z = 2.39674         -> 2.28731
# Velocities from z = 2.45423         -> 2.34113
# Step: 29   / 100
# Positions  from z = 2.28731         -> 2.18471
# Velocities from z = 2.34113         -> 2.2352
# Step: 30   / 100
# Positions  from z = 2.18471         -> 2.08833
# Velocities from z = 2.2352          -> 2.13578
# Step: 31   / 100
# Positions  from z = 2.08833         -> 1.9976
# Velocities from z = 2.13578         -> 2.04229
# Step: 32   / 100
# Positions  from z = 1.9976          -> 1.91206
# Velocities from z = 2.04229         -> 1.95421
# Step: 33   / 100
# Positions  from z = 1.91206         -> 1.83126
# Velocities from z = 1.95421         -> 1.87109
# Step: 34   / 100
# Positions  from z = 1.83126         -> 1.75482
# Velocities from z = 1.87109         -> 1.79252
# Step: 35   / 100
# Positions  from z = 1.75482         -> 1.6824
# Velocities from z = 1.79252         -> 1.71813
# Step: 36   / 100
# Positions  from z = 1.6824          -> 1.6137
# Velocities from z = 1.71813         -> 1.6476
# Step: 37   / 100
# Positions  from z = 1.6137          -> 1.54842
# Velocities from z = 1.6476          -> 1.58065
# Step: 38   / 100
# Positions  from z = 1.54842         -> 1.48633
# Velocities from z = 1.58065         -> 1.51699
# Step: 39   / 100
# Positions  from z = 1.48633         -> 1.42718
# Velocities from z = 1.51699         -> 1.4564
# Step: 40   / 100
# Positions  from z = 1.42718         -> 1.37079
# Velocities from z = 1.4564          -> 1.39866
# Step: 41   / 100
# Positions  from z = 1.37079         -> 1.31696
# Velocities from z = 1.39866         -> 1.34357
# Step: 42   / 100
# Positions  from z = 1.31696         -> 1.26552
# Velocities from z = 1.34357         -> 1.29095
# Step: 43   / 100
# Positions  from z = 1.26552         -> 1.21631
# Velocities from z = 1.29095         -> 1.24065
# Step: 44   / 100
# Positions  from z = 1.21631         -> 1.1692
# Velocities from z = 1.24065         -> 1.1925
# Step: 45   / 100
# Positions  from z = 1.1692          -> 1.12404
# Velocities from z = 1.1925          -> 1.14638
# Step: 46   / 100
# Positions  from z = 1.12404         -> 1.08073
# Velocities from z = 1.14638         -> 1.10217
# Step: 47   / 100
# Positions  from z = 1.08073         -> 1.03915
# Velocities from z = 1.10217         -> 1.05973
# Step: 48   / 100
# Positions  from z = 1.03915         -> 0.9992
# Velocities from z = 1.05973         -> 1.01898
# Step: 49   / 100
# Positions  from z = 0.9992          -> 0.960784
# Velocities from z = 1.01898         -> 0.979806
# Step: 50   / 100
# Positions  from z = 0.960784        -> 0.923817
# Velocities from z = 0.979806        -> 0.942125
# Step: 51   / 100
# Positions  from z = 0.923817        -> 0.888218
# Velocities from z = 0.942125        -> 0.905851
# Step: 52   / 100
# Positions  from z = 0.888218        -> 0.853912
# Velocities from z = 0.905851        -> 0.870907
# Step: 53   / 100
# Positions  from z = 0.853912        -> 0.82083
# Velocities from z = 0.870907        -> 0.837222
# Step: 54   / 100
# Positions  from z = 0.82083         -> 0.788909
# Velocities from z = 0.837222        -> 0.804728
# Step: 55   / 100
# Positions  from z = 0.788909        -> 0.758087
# Velocities from z = 0.804728        -> 0.773364
# Step: 56   / 100
# Positions  from z = 0.758087        -> 0.72831
# Velocities from z = 0.773364        -> 0.743071
# Step: 57   / 100
# Positions  from z = 0.72831         -> 0.699524
# Velocities from z = 0.743071        -> 0.713796
# Step: 58   / 100
# Positions  from z = 0.699524        -> 0.671682
# Velocities from z = 0.713796        -> 0.685488
# Step: 59   / 100
# Positions  from z = 0.671682        -> 0.644737
# Velocities from z = 0.685488        -> 0.6581
# Step: 60   / 100
# Positions  from z = 0.644737        -> 0.618647
# Velocities from z = 0.6581          -> 0.631588
# Step: 61   / 100
# Positions  from z = 0.618647        -> 0.593372
# Velocities from z = 0.631588        -> 0.60591
# Step: 62   / 100
# Positions  from z = 0.593372        -> 0.568874
# Velocities from z = 0.60591         -> 0.581028
# Step: 63   / 100
# Positions  from z = 0.568874        -> 0.545117
# Velocities from z = 0.581028        -> 0.556905
# Step: 64   / 100
# Positions  from z = 0.545117        -> 0.52207
# Velocities from z = 0.556905        -> 0.533507
# Step: 65   / 100
# Positions  from z = 0.52207         -> 0.4997
# Velocities from z = 0.533507        -> 0.510802
# Step: 66   / 100
# Positions  from z = 0.4997          -> 0.477978
# Velocities from z = 0.510802        -> 0.48876
# Step: 67   / 100
# Positions  from z = 0.477978        -> 0.456876
# Velocities from z = 0.48876         -> 0.467351
# Step: 68   / 100
# Positions  from z = 0.456876        -> 0.436369
# Velocities from z = 0.467351        -> 0.44655
# Step: 69   / 100
# Positions  from z = 0.436369        -> 0.416431
# Velocities from z = 0.44655         -> 0.42633
# Step: 70   / 100
# Positions  from z = 0.416431        -> 0.397038
# Velocities from z = 0.42633         -> 0.406668
# Step: 71   / 100
# Positions  from z = 0.397038        -> 0.37817
# Velocities from z = 0.406668        -> 0.38754
# Step: 72   / 100
# Positions  from z = 0.37817         -> 0.359804
# Velocities from z = 0.38754         -> 0.368925
# Step: 73   / 100
# Positions  from z = 0.359804        -> 0.341922
# Velocities from z = 0.368925        -> 0.350804
# Step: 74   / 100
# Positions  from z = 0.341922        -> 0.324503
# Velocities from z = 0.350804        -> 0.333156
# Step: 75   / 100
# Positions  from z = 0.324503        -> 0.307531
# Velocities from z = 0.333156        -> 0.315963
# Step: 76   / 100
# Positions  from z = 0.307531        -> 0.290989
# Velocities from z = 0.315963        -> 0.299207
# Step: 77   / 100
# Positions  from z = 0.290989        -> 0.27486
# Velocities from z = 0.299207        -> 0.282874
# Step: 78   / 100
# Positions  from z = 0.27486         -> 0.259129
# Velocities from z = 0.282874        -> 0.266945
# Step: 79   / 100
# Positions  from z = 0.259129        -> 0.243781
# Velocities from z = 0.266945        -> 0.251408
# Step: 80   / 100
# Positions  from z = 0.243781        -> 0.228803
# Velocities from z = 0.251408        -> 0.236247
# Step: 81   / 100
# Positions  from z = 0.228803        -> 0.214182
# Velocities from z = 0.236247        -> 0.221449
# Step: 82   / 100
# Positions  from z = 0.214182        -> 0.199904
# Velocities from z = 0.221449        -> 0.207001
# Step: 83   / 100
# Positions  from z = 0.199904        -> 0.185958
# Velocities from z = 0.207001        -> 0.19289
# Step: 84   / 100
# Positions  from z = 0.185958        -> 0.172333
# Velocities from z = 0.19289         -> 0.179106
# Step: 85   / 100
# Positions  from z = 0.172333        -> 0.159017
# Velocities from z = 0.179106        -> 0.165637
# Step: 86   / 100
# Positions  from z = 0.159017        -> 0.146
# Velocities from z = 0.165637        -> 0.152472
# Step: 87   / 100
# Positions  from z = 0.146           -> 0.133273
# Velocities from z = 0.152472        -> 0.139601
# Step: 88   / 100
# Positions  from z = 0.133273        -> 0.120825
# Velocities from z = 0.139601        -> 0.127015
# Step: 89   / 100
# Positions  from z = 0.120825        -> 0.108647
# Velocities from z = 0.127015        -> 0.114703
# Step: 90   / 100
# Positions  from z = 0.108647        -> 0.0967317
# Velocities from z = 0.114703        -> 0.102657
# Step: 91   / 100
# Positions  from z = 0.0967317       -> 0.0850694
# Velocities from z = 0.102657        -> 0.0908694
# Step: 92   / 100
# Positions  from z = 0.0850694       -> 0.0736526
# Velocities from z = 0.0908694       -> 0.0793308
# Step: 93   / 100
# Positions  from z = 0.0736526       -> 0.0624734
# Velocities from z = 0.0793308       -> 0.0680337
# Step: 94   / 100
# Positions  from z = 0.0624734       -> 0.0515247
# Velocities from z = 0.0680337       -> 0.0569707
# Step: 95   / 100
# Positions  from z = 0.0515247       -> 0.0407993
# Velocities from z = 0.0569707       -> 0.0461345
# Step: 96   / 100
# Positions  from z = 0.0407993       -> 0.0302905
# Velocities from z = 0.0461345       -> 0.0355183
# Step: 97   / 100
# Positions  from z = 0.0302905       -> 0.0199918
# Velocities from z = 0.0355183       -> 0.0251153
# Step: 98   / 100
# Positions  from z = 0.0199918       -> 0.00989699
# Velocities from z = 0.0251153       -> 0.0149193
# Step: 99   / 100
# Positions  from z = 0.00989699      -> 0
# Velocities from z = 0.0149193       -> 0.00492413
# Step: 100  / 100
# Positions  from z = 0               -> 0
# Velocities from z = 0.00492413      -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 100 Total steps taken: 0
# Positions from  z = 49              -> 32.557
# Velocities from z = 49              -> 39.1606
# deltatime_pos = 4.76986         deltatime_vel = 3.0535
# Adding particles (baryons+CDM) to the densityfield

# %% [markdown]
# # Results

# %%
"Check phase pair"

k, Pk_NL_phase,Pk_Lin_phase = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend_validation_edges/COLA_0_tracker/pofk_my_new_Hi-COLA_simulation_0_tracker_phasepair_cb_z0.000.txt").T
k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend_validation_edges/COLA_0_tracker/pofk_my_new_Hi-COLA_simulation_0_tracker_cb_z0.000.txt").T

# %%
plt.plot(k,Pk_NL, label = "seed 108")
plt.plot(k, Pk_NL_phase, label="phase reverse for seed 108")

plt.plot(k,(Pk_NL_phase + Pk_NL)/2, "k", label = "phase pair average")

plt.xscale("log")
plt.yscale("log")
plt.ylabel("P(k)")
plt.legend()
