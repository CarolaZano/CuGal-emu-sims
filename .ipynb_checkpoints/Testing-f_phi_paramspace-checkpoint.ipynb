# %%
from configobj import ConfigObj
import numpy as np
import os
import matplotlib.pyplot as plt
import pylab as plot
from scipy.interpolate import CubicSpline
from scipy.interpolate import RegularGridInterpolator
import pyccl as ccl
import scipy
from matplotlib.pyplot import cm
#from HiCOLA import Frontend

# %% [markdown]
# ## Get expansion and force files

# %% [markdown]
# # Run Backend

# %% [markdown]
# ## Get Power Spectra

# %% [markdown]
# # from paper
# wr = 0.0#4.28e-5
# wc = 0.11933
# wb = 0.02242
# h = 0.6766
#
# # We assume:
# A_s = 2.1e-9
# n_s = 0.966

# %%
f_phi_array = np.logspace(-4,0,9)

print(f_phi_array)
# Out:
# [1.00000000e-04 3.16227766e-04 1.00000000e-03 3.16227766e-03
#  1.00000000e-02 3.16227766e-02 1.00000000e-01 3.16227766e-01
#  1.00000000e+00]

# %%
# Create cola folders - only need to do this once

# CAREFUL!! might not need this next step
#command = 'cd; rm -r /home/c2042999/HiCOLA_env/Cubic_galileon_emu/Output_backend/COLA_seeds'
#os.system(command)
os.system("cd; cd /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/; mkdir COLA_fphi_tests")
# Out:
# mkdir: cannot create directory ‘COLA_fphi_tests’: File exists
# 256

# %%
## Power spectrum from CCL - backscaling

Pk_ccl = np.zeros(500)

# from paper
wr = 0.0#4.28e-5
wc = 0.11933
wb = 0.02242
h = 0.6766

wm = wc + wb
# We assume:
As = 2.1e-9
ns = 0.966

kk_ccl = np.logspace(-3,1,len(Pk_ccl))*h               # in 1/Mpc
cosmoLCDM = ccl.Cosmology(Omega_c=(wm - wb)/h**2,
                               Omega_b=wb/h**2, 
                               A_s=As, 
                               h = h,
                               n_s=ns,
                               Omega_k=0)

# Omega_g::: Note that if a non-None value is given, this may result in a physically 
# inconsistent model because the CMB temperature will still be non-zero in the parameters.
cosmoLCDM_norad = ccl.Cosmology(Omega_c=(wm - wb)/h**2,
                               Omega_b=wb/h**2, 
                               A_s=As, 
                               h = h,
                               n_s=ns,
                               Omega_k=0,
                               Omega_g = 0,
                               T_CMB = 0.0)

Pk_0 = ccl.power.linear_matter_power(cosmoLCDM, kk_ccl, 1)    # in (Mpc)^3

Growth_0 = ccl.background.growth_factor(cosmoLCDM_norad, 1)

Growth_49 = ccl.background.growth_factor(cosmoLCDM_norad, 1/(1+49))

Pk_ccl = (Growth_49/Growth_0)**2 * Pk_0*h**3    # in (Mpc)^3/h^3

kk_ccl = kk_ccl/h    # in h/Mpc
## Save power spectrum for initial conditions (Linear)
np.savetxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_f_phi_tests.dat", np.array([kk_ccl, Pk_ccl]).T)

# %%
## Plot power spectra (at z = 49, expect very different from z=0)

plt.plot(kk_ccl,Pk_ccl)

plt.xscale("log")
plt.yscale("log")

# %% [markdown]
# ## Get expansion and force files

# %%
"""Define tracker functions"""

# If we are on the tracker, we will get the following constraints equations

# For today formalism 
def k_1T(Omg_m, Omg_r, f_phi):
    return 6*f_phi*(Omg_m + Omg_r - 1)

# dS formalism

def E_dS(Omg_m, Omg_r, f_phi):

    return np.sqrt((1-f_phi)*(1-Omg_m-Omg_r)/2 + np.sqrt(
        ((1-f_phi)*(1-Omg_m-Omg_r)/2)**2 + f_phi*(1-Omg_m-Omg_r)
    ))

# %%
''' Define useful functions'''

def hypercube_arrays(f_phi):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi)
    returns two arrays, one for numerical and one for horndeski array
    # numerical - [h , wr , wb , wc, n_s , A_s]
    # horndeski - [f_phi, H0, k_1, g_31]
    """
    wr = 0.0*np.ones(len(f_phi))#4.28e-5
    wc = 0.11933*np.ones(len(f_phi))
    wb = 0.02242*np.ones(len(f_phi))
    h = 0.6766*np.ones(len(f_phi))
    
    # We assume:
    A_s = 2.1e-9*np.ones(len(f_phi))
    n_s = 0.966*np.ones(len(f_phi))

    arr_num = [h, wr, wb, wc, n_s, A_s]
    
    return arr_num

def Update_ini(run, f_phi, arr_num, horn_ini, num_ini):
    """
    Updates files num_ini and horn_ini to include the parameters (numerical and MG) from 
    f_phi and
    arr_num = h , wr , wb , wc, n_s , A_s
    """
    ## Horndeski params
    h , wr , wb , wc, n_s , A_s = arr_num
    config_h = ConfigObj(horn_ini)
    
    k1_track = k_1T((wc + wb)/h**2, wr/h**2, f_phi)

    keys_h = config_h.keys()
    
    config_h[keys_h[1]] = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests'
    config_h[keys_h[0]] = 'horndeski_model'
    
    config_h[keys_h[2]] = 'k_1*X'
    config_h[keys_h[3]] = 'g_31*X'
    config_h[keys_h[4]] = '0.5'

    config_h[keys_h[7]] = str(k1_track)
    config_h[keys_h[8]] = str("1")
    config_h[keys_h[9]] = str(f_phi)
    config_h[keys_h[10]] = str("1")
    config_h[keys_h[11]] = str("1")
    config_h[keys_h[20]] = str("False")
    config_h[keys_h[22]] = str("1")
    
    ## Numerical params
    config_n = ConfigObj(num_ini)
    keys_n = config_n.keys()
    
    config_n[keys_n[0]] = 'run_'+str(run)

    
    config_n[keys_n[6]] = str(h)
    config_n[keys_n[7]] = str(wr)
    config_n[keys_n[8]] = str(wb)
    config_n[keys_n[9]] = str(wc)
    config_h.filename = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini'
    config_n.filename = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'
    config_h.write(); config_n.write()

# %%
"""!!!!! CAREFUL WHEN RUNNING THIS deletes a whole directory of frontend parameter files"""
### Run frontend for all different .ini files

#command = 'cd; rm -r /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/'
#os.system(command)
#command = 'cd /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/; mkdir Output'
#os.system(command)

a_n = hypercube_arrays(f_phi_array)
for i in range(len(f_phi_array)):
    Update_ini(str(i), f_phi_array[i], np.array(a_n).T[i], '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_parameters.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_parameters.ini')
    command = 'cd ; cd /home/c2042999/HiCOLA_env/Hi-COLA; python3 -m HiCOLA.Frontend.generate_simulation_input /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'
    os.system(command)
# Out:
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-0.0004142151350726962, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.30964144154550644
# Omega_r0 = 0.0
# Omega_lambda0 = 0.6902895225986482
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 0.00013807171169089028
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-0.0013098632681440147, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.30964144154550644
# Omega_r0 = 0.0
# Omega_lambda0 = 0.6901402479098029
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 0.00043662108938136157
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-0.0041421513507269615, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.30964144154550644
# Omega_r0 = 0.0
# Omega_lambda0 = 0.6896681998960391
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 0.0013807171169090138
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-0.013098632681440146, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.30964144154550644
# Omega_r0 = 0.0
# Omega_lambda0 = 0.6881754530075869
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 0.004366210893813283
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-0.041421513507269615, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.30964144154550644
# Omega_r0 = 0.0
# Omega_lambda0 = 0.6834549728699486
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 0.013807171169089916
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-0.13098632681440148, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.30964144154550644
# Omega_r0 = 0.0
# Omega_lambda0 = 0.6685275039854267
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 0.043662108938133715
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-0.4142151350726962, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.30964144154550644
# Omega_r0 = 0.0
# Omega_lambda0 = 0.6213227026090442
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 0.13807171169089894
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-1.3098632681440148, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.30964144154550644
# Omega_r0 = 0.0
# Omega_lambda0 = 0.4720480137638244
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 0.4366210893813388
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests
# /home/c2042999/HiCOLA_env/3.7.12/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-4.142151350726961, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.30964144154550644
# Omega_r0 = 0.0
# Omega_lambda0 = 0.0
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 1.3807171169089885
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests

# %% [markdown]
# ### Plot background

# %%
## Plotting ##

fig, axs = plt.subplots(1)

zero_vals = []

for i in range(len(f_phi_array)-4):
    expansion_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_{}_expansion.txt".format(i))

    a_today = expansion_today.T[0]
    E_a_today = expansion_today.T[1]
    E_a_GR = np.sqrt((wb+wc)*a_today**(-3) + wr*a_today**(-4) + (h**2 - (wb+wc) -wr))/h
    if (np.min(E_a_today/E_a_GR)) == 0.0:
        zero_vals.append(i)
    plt.plot(1/a_today -1, E_a_today/E_a_GR, alpha=0.7)
plt.xscale("log")

#plt.ylim(0.91,1.05)
plt.xlabel("z")
plt.ylabel(r"$E^{CuGal}/E^{\Lambda CDM}$")
# Out:
# Text(0, 0.5, '$E^{CuGal}/E^{\\Lambda CDM}$')

# %%
## Plotting ##

fig, axs = plt.subplots(1)


for i in range(len(f_phi_array)):
    expansion_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_{}_expansion.txt".format(i))

    a_today = expansion_today.T[0]
    E_a_today = expansion_today.T[1]

    E_prime_a_today = expansion_today.T[2]
    
    plt.plot(1/a_today -1, -E_prime_a_today*E_a_today, alpha=0.7)

plt.xscale("log")


plt.yscale("log")
plt.xlabel("z")
plt.ylabel(r"$-E'$")
# Out:
# Text(0, 0.5, "$-E'$")

# %%
## Plotting ##

fig, axs = plt.subplots(1)


for i in range(len(f_phi_array)):
    force_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files//Output/f_phi_tests/horndeski_model_run_{}_force.txt".format(i))
    a_today = force_today.T[0]
    chiD_today = force_today.T[1]
    coupling = force_today.T[2]

    plt.plot(1/a_today -1, chiD_today, alpha=0.7)


plt.xscale("log")
plt.xlabel("z")
plt.ylabel(r"$chiD^{CuGal}/chiD^{\Lambda CDM}$")
# Out:
# Text(0, 0.5, '$chiD^{CuGal}/chiD^{\\Lambda CDM}$')

# %%
## Plotting ##

fig, axs = plt.subplots(1)


for i in range(len(f_phi_array)):
    force_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files//Output/f_phi_tests/horndeski_model_run_{}_force.txt".format(i))

    a_today = force_today.T[0]
    chiD_today = force_today.T[1]
    coupling = force_today.T[2]

    plt.plot(1/a_today -1, coupling, alpha=0.7)


plt.xscale("log")
plt.xlabel("z")
plt.ylabel(r"$coupling^{CuGal}$")
# Out:
# Text(0, 0.5, '$coupling^{CuGal}$')

# %% [markdown]
# # Run Frontend

# %%
def rewriteluafile(k,fphi,txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """
    
    # from paper
    wr = 0.0#4.28e-5
    wc = 0.11933
    wb = 0.02242
    h = 0.6766

    wm = wc + wb
    # We assume:
    A_s = 2.1e-9
    n_s = 0.966
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = (wc+wb)/h**2
    Omg_b = wb/h**2
    
    f_phi = fphi[k]
    k1_tracker = k_1T(Omg_m, Omg_r, f_phi)
    
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/f_phi_tests/Hi-COLA_params_emu_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_{}"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(1e-10)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('HiCOLA_expansion_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_{}_expansion.txt"'.format(str(k))+'\n')
        elif i== 100:
            c.write('HiCOLA_preforce_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_{}_force.txt"'.format(str(k))+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests"'+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {20}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')  
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_f_phi_tests.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# Same as above
txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

# %%
"""Re-write lua file"""
for i in range(len(f_phi_array)):
    rewriteluafile(i,f_phi_array,txt,400,512,1536)

# %%
"""Create Pk"""
for i in range(len(f_phi_array)):
    os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/f_phi_tests/Hi-COLA_params_emu_{}.lua".format(str(i)))
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-3]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-3]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-3]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-3]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-3]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-3]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-3]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-3]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-3]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-3]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-3]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-3]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-3]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-3]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-3]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-3]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-3]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-3]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-3]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-3]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-3]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-3]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-3]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-3]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-3]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-3]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-3]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-3]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-3]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-3]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-3]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-3]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 62 elements:
# #=====================================================
#   HiCOLA_expansion_filename      : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_0_expansion.txt
#   HiCOLA_preforce_filename       : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_0_force.txt
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.1e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.260667
#   cosmology_OmegaLambda          : 0.690359
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.0489747
#   cosmology_TCMB_kelvin          : 1e-10
#   cosmology_h                    : 0.6766
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : HiCOLA
#   cosmology_ns                   : 0.966
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : HiCOLA
#   gravity_model_HiCOLA_smoothing_filter : gaussian
#   gravity_model_HiCOLA_smoothing_scale_over_boxsize : 0.0075
#   gravity_model_screening        : true
#   gravity_model_screening_enforce_largescale_linear : true
#   gravity_model_screening_linear_scale_hmpc : 0.2
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : false
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_f_phi_tests.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : false
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_0
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              20 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [HiCOLA]
# # Omegab      : 0.0489747
# # OmegaM      : 0.309641
# # OmegaMNu    : 0
# # OmegaCDM    : 0.260667
# # OmegaLambda : 0.690359
# # OmegaR      : 9.78972e-47
# # OmegaNu     : 6.77223e-47
# # OmegaRtot   : 1.6562e-46
# # OmegaK      : 0
# # h           : 0.6766
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 1e-10 K
# # Tnu         : 7.16486e-11 K
# # As          : 2.1e-09
# # ns          : 0.966
# # kpivot      : 0.05 1/Mpc
# # HiCOLA_expansion_filename     : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_0_expansion.txt
# #=====================================================
#
# #=====================================================
# # GravityModel is [HiCOLA] and has the cosmology: [HiCOLA]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# # HiCOLA_preforce_filename : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_0_force.txt
# # Screening method : true
# # Enforce correct linear evolution : true
# # Scale for which we enforce this  : 0.2 h/Mpc
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_0
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_f_phi_tests.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : false
# ic_reverse_phases                        : false
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 20
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_f_phi_tests.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      2.57583         501627
# 0.00251653      5.79055         485923
# 0.00621709      11.41           440693
# 0.0153593       16.2558         339845
# 0.0379453       10.5571         176943
# 0.0937441       4.07243         71002.3
# 0.231595        0.939837        22037.2
# 0.572157        0.155733        5795.68
# 1.41352         0.0199338       1339.66
# 3.4921          0.00218881      286.806
# 8.62724         0.00021673      58.308
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 14.606 (Mpc/h)^3
# k =  0.10: P(k,zini) = 3.62049 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0447366 (Mpc/h)^3
# k = 10.00: P(k,zini) = 0.000147462 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.820893
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.723559 Mpc/h
# Maximum 1LPT velocity: 284.696 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.0100159 Mpc/h
# Maximum 2LPT velocity: 7.88186 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 20
# Step: 0    / 20
# Positions  from z = 49              -> 13.4928
# Velocities from z = 49              -> 21.4719
# Step: 1    / 20
# Positions  from z = 13.4928         -> 7.47458
# Velocities from z = 21.4719         -> 9.69519
# Step: 2    / 20
# Positions  from z = 7.47458         -> 4.98802
# Velocities from z = 9.69519         -> 6.01754
# Step: 3    / 20
# Positions  from z = 4.98802         -> 3.62963
# Velocities from z = 6.01754         -> 4.22193
# Step: 4    / 20
# Positions  from z = 3.62963         -> 2.77358
# Velocities from z = 4.22193         -> 3.158
# Step: 5    / 20
# Positions  from z = 2.77358         -> 2.18471
# Velocities from z = 3.158           -> 2.45423
# Step: 6    / 20
# Positions  from z = 2.18471         -> 1.75482
# Velocities from z = 2.45423         -> 1.95421
# Step: 7    / 20
# Positions  from z = 1.75482         -> 1.42718
# Velocities from z = 1.95421         -> 1.58065
# Step: 8    / 20
# Positions  from z = 1.42718         -> 1.1692
# Velocities from z = 1.58065         -> 1.29095
# Step: 9    / 20
# Positions  from z = 1.1692          -> 0.960784
# Velocities from z = 1.29095         -> 1.05973
# Step: 10   / 20
# Positions  from z = 0.960784        -> 0.788909
# Velocities from z = 1.05973         -> 0.870907
# Step: 11   / 20
# Positions  from z = 0.788909        -> 0.644737
# Velocities from z = 0.870907        -> 0.713796
# Step: 12   / 20
# Positions  from z = 0.644737        -> 0.52207
# Velocities from z = 0.713796        -> 0.581028
# Step: 13   / 20
# Positions  from z = 0.52207         -> 0.416431
# Velocities from z = 0.581028        -> 0.467351
# Step: 14   / 20
# Positions  from z = 0.416431        -> 0.324503
# Velocities from z = 0.467351        -> 0.368925
# Step: 15   / 20
# Positions  from z = 0.324503        -> 0.243781
# Velocities from z = 0.368925        -> 0.282874
# Step: 16   / 20
# Positions  from z = 0.243781        -> 0.172333
# Velocities from z = 0.282874        -> 0.207001
# Step: 17   / 20
# Positions  from z = 0.172333        -> 0.108647
# Velocities from z = 0.207001        -> 0.139601
# Step: 18   / 20
# Positions  from z = 0.108647        -> 0.0515247
# Velocities from z = 0.139601        -> 0.0793308
# Step: 19   / 20
# Positions  from z = 0.0515247       -> 0
# Velocities from z = 0.0793308       -> 0.0251153
# Step: 20   / 20
# Positions  from z = 0               -> 0
# Velocities from z = 0.0251153       -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 20 Total steps taken: 0
# Positions from  z = 49              -> 13.4928
# Velocities from z = 49              -> 21.4719
# deltatime_pos = 11.731          deltatime_vel = 12.4945
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# At a= 0.02 chi/delta=0.658967 coupling=1.28725e-10
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00264272
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000428999
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4204454 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.49 %% (min)
# #               50.7302 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4704.22         MB (min over tasks)
# # Current RSS: 4705.09         MB (max over tasks)
# # Peak RSS:    5630.14         MB (min over tasks)
# # Peak RSS:    5631.04         MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 20 Total steps taken: 1
# Positions from  z = 13.4928         -> 7.47458
# Velocities from z = 21.4719         -> 9.69519
# deltatime_pos = 3.21694         deltatime_vel = 4.93762
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# At a= 0.069 chi/delta=0.597746 coupling=1.59782e-10
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00506754
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000984252
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4210903 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.179 %% (min)
# #               51.2302 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4694.09         MB (min over tasks)
# # Current RSS: 4710.71         MB (max over tasks)
# # Peak RSS:    5631.11         MB (min over tasks)
# # Peak RSS:    5631.91         MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 20 Total steps taken: 2
# Positions from  z = 7.47458         -> 4.98802
# Velocities from z = 9.69519         -> 6.01754
# deltatime_pos = 1.66267         deltatime_vel = 2.18028
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# At a= 0.118 chi/delta=0.32682 coupling=7.46487e-10
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00510788
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00326006
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4216292 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.8681 %% (min)
# #               51.7708 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4696.22         MB (min over tasks)
# # Current RSS: 4711.8          MB (max over tasks)
# # Peak RSS:    5631.87         MB (min over tasks)
# # Peak RSS:    5636.76         MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 20 Total steps taken: 3
# Positions from  z = 4.98802         -> 3.62963
# Velocities from z = 6.01754         -> 4.22193
# deltatime_pos = 1.05354         deltatime_vel = 1.28708
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# At a= 0.167 chi/delta=0.269237 coupling=4.28258e-09
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00590337
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00512388
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4219499 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.5898 %% (min)
# #               52.3274 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4696.96         MB (min over tasks)
# # Current RSS: 4712.53         MB (max over tasks)
# # Peak RSS:    5632.63         MB (min over tasks)
# # Peak RSS:    5637.76         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 20 Total steps taken: 4
# Positions from  z = 3.62963         -> 2.77358
# Velocities from z = 4.22193         -> 3.158
# deltatime_pos = 0.740171        deltatime_vel = 0.868832
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# At a= 0.216 chi/delta=0.258498 coupling=1.83879e-08
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00582395
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00610209
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4223236 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.3246 %% (min)
# #               52.8935 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4697.99         MB (min over tasks)
# # Current RSS: 4713.3          MB (max over tasks)
# # Peak RSS:    5633.41         MB (min over tasks)
# # Peak RSS:    5638.58         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 20 Total steps taken: 5
# Positions from  z = 2.77358         -> 2.18471
# Velocities from z = 3.158           -> 2.45423
# deltatime_pos = 0.553164        deltatime_vel = 0.633149
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# At a= 0.265 chi/delta=0.257179 coupling=5.99805e-08
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00557452
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00687079
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4224678 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.1074 %% (min)
# #               53.483 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4698.79         MB (min over tasks)
# # Current RSS: 4714.06         MB (max over tasks)
# # Peak RSS:    5634.2          MB (min over tasks)
# # Peak RSS:    5639.28         MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 20 Total steps taken: 6
# Positions from  z = 2.18471         -> 1.75482
# Velocities from z = 2.45423         -> 1.95421
# deltatime_pos = 0.430435        deltatime_vel = 0.484376
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# At a= 0.314 chi/delta=0.258974 coupling=1.59318e-07
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00681196
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.0100125
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4226508 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.8885 %% (min)
# #               54.0574 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4698.99         MB (min over tasks)
# # Current RSS: 4714.82         MB (max over tasks)
# # Peak RSS:    5634.96         MB (min over tasks)
# # Peak RSS:    5640.11         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 20 Total steps taken: 7
# Positions from  z = 1.75482         -> 1.42718
# Velocities from z = 1.95421         -> 1.58065
# deltatime_pos = 0.344378        deltatime_vel = 0.382934
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# At a= 0.363 chi/delta=0.262799 coupling=3.63162e-07
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.0061461
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00954093
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4226730 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.6802 %% (min)
# #               54.5654 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4699.22         MB (min over tasks)
# # Current RSS: 4715.57         MB (max over tasks)
# # Peak RSS:    5635.73         MB (min over tasks)
# # Peak RSS:    5640.84         MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 20 Total steps taken: 8
# Positions from  z = 1.42718         -> 1.1692
# Velocities from z = 1.58065         -> 1.29095
# deltatime_pos = 0.281063        deltatime_vel = 0.309834
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# At a= 0.412 chi/delta=0.267868 coupling=7.33724e-07
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00507815
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00897034
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4225773 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.4957 %% (min)
# #               55.0315 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4699.98         MB (min over tasks)
# # Current RSS: 4716.41         MB (max over tasks)
# # Peak RSS:    5636.51         MB (min over tasks)
# # Peak RSS:    5641.63         MB (max over tasks)
# #=====================================================
#
# Taking substep: 9 / 20 Total steps taken: 9
# Positions from  z = 1.1692          -> 0.960784
# Velocities from z = 1.29095         -> 1.05973
# deltatime_pos = 0.232775        deltatime_vel = 0.254953
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# At a= 0.461 chi/delta=0.273952 coupling=1.34519e-06
# ...
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4229735 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.0647 %% (min)
# #               55.9029 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4700.01         MB (min over tasks)
# # Current RSS: 4717.91         MB (max over tasks)
# # Peak RSS:    5637.97         MB (min over tasks)
# # Peak RSS:    5643.2          MB (max over tasks)
# #=====================================================
#
# Taking substep: 11 / 20 Total steps taken: 11
# Positions from  z = 0.788909        -> 0.644737
# Velocities from z = 0.870907        -> 0.713796
# deltatime_pos = 0.164707        deltatime_vel = 0.178794
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# At a= 0.559 chi/delta=0.288488 coupling=1.1393e-05
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00474776
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00885981
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4230296 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.7724 %% (min)
# #               56.3449 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4699.67         MB (min over tasks)
# # Current RSS: 4718.68         MB (max over tasks)
# # Peak RSS:    5638.74         MB (min over tasks)
# # Peak RSS:    5643.96         MB (max over tasks)
# #=====================================================
#
# Taking substep: 12 / 20 Total steps taken: 12
# Positions from  z = 0.644737        -> 0.52207
# Velocities from z = 0.713796        -> 0.581028
# deltatime_pos = 0.140155        deltatime_vel = 0.151648
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# At a= 0.608 chi/delta=0.296404 coupling=1.70264e-05
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00414708
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00882533
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4228268 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.5736 %% (min)
# #               56.719 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4699.66         MB (min over tasks)
# # Current RSS: 4719.44         MB (max over tasks)
# # Peak RSS:    5639.51         MB (min over tasks)
# # Peak RSS:    5644.73         MB (max over tasks)
# #=====================================================
#
# Taking substep: 13 / 20 Total steps taken: 13
# Positions from  z = 0.52207         -> 0.416431
# Velocities from z = 0.581028        -> 0.467351
# deltatime_pos = 0.119989        deltatime_vel = 0.129463
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# At a= 0.657 chi/delta=0.304315 coupling=2.42226e-05
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.003705
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00789961
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4226102 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.3892 %% (min)
# #               57.1662 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4699.06         MB (min over tasks)
# # Current RSS: 4720.23         MB (max over tasks)
# # Peak RSS:    5640.29         MB (min over tasks)
# # Peak RSS:    5645.49         MB (max over tasks)
# #=====================================================
#
# Taking substep: 14 / 20 Total steps taken: 14
# Positions from  z = 0.416431        -> 0.324503
# Velocities from z = 0.467351        -> 0.368925
# deltatime_pos = 0.103279        deltatime_vel = 0.111155
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# At a= 0.706 chi/delta=0.311873 coupling=3.3028e-05
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00343892
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00755508
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4223397 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.1717 %% (min)
# #               57.6145 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4699.05         MB (min over tasks)
# # Current RSS: 4720.87         MB (max over tasks)
# # Peak RSS:    5641.05         MB (min over tasks)
# # Peak RSS:    5646.28         MB (max over tasks)
# #=====================================================
#
# Taking substep: 15 / 20 Total steps taken: 15
# Positions from  z = 0.324503        -> 0.243781
# Velocities from z = 0.368925        -> 0.282874
# deltatime_pos = 0.0893283       deltatime_vel = 0.0959184
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# At a= 0.755 chi/delta=0.318725 coupling=4.34038e-05
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc

# %% [markdown]
# # Run GR Frontend

# %%
def rewriteluafile(txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """
    
    # from paper
    wr = 0.0#4.28e-5
    wc = 0.11933
    wb = 0.02242
    h = 0.6766

    wm = wc + wb
    # We assume:
    A_s = 2.1e-9
    n_s = 0.966
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = (wc+wb)/h**2
    Omg_b = wb/h**2
    
    Omg_DE = (1-Omg_m-Omg_r)
    
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/f_phi_tests/Hi-COLA_params_emu_GR.lua','w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_GR"'+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(1e-10)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests"'+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {20}'+'\n')   
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_f_phi_tests.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# Same as above
txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

# %%
"""Re-write lua file"""
rewriteluafile(txt,400,512,1536)

# %%
"""Create Pk"""
#for i in range(10):
os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/f_phi_tests/Hi-COLA_params_emu_GR.lua")

# %% [markdown]
# # Get Plots

# %%
"""Plotting the NL power spectra for the simulations at z = 0"""

for i in range(len(f_phi_array)):
    k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests/pofk_my_new_Hi-COLA_simulation_{}_cb_z0.000.txt".format(i)).T
    
    plt.plot(k,Pk_NL)

plt.xscale("log")
plt.yscale("log")

plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("$P^{CG}_{NL}(k)$ [h $Mpc^{-1}]^{-3}$")
# Out:
# Text(0, 0.5, '$P^{CG}_{NL}(k)$ [h $Mpc^{-1}]^{-3}$')

# %%
"""Plotting the NL power spectra for the simulations at z = 0"""
params = {'legend.fontsize': 9,
          'legend.handlelength': 2}
plot.rcParams.update(params)

for i in range(len(f_phi_array)):
    k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests/pofk_my_new_Hi-COLA_simulation_{}_cb_z0.000.txt".format(i)).T
    k, Pk_NL_GR,Pk_Lin_GR = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests/pofk_my_new_Hi-COLA_simulation_GR_cb_z0.000.txt".format(i)).T
    
    plt.plot(k,Pk_NL/Pk_NL_GR, label = r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[i]) )

plt.xscale("log")
plt.legend()

plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("Boost $B(k)$")
# Out:
# Text(0, 0.5, 'Boost $B(k)$')

# %% [markdown]
# ## Plots to send

# %%
"""Plotting the NL power spectra for the simulations at z = 0"""

fig, ax = plt.subplots(3,2,sharex=True, figsize=(14,6))
fig.subplots_adjust(hspace=0,wspace=0)

params = {'legend.fontsize': 12,
          'legend.handlelength': 2}
plot.rcParams.update(params)

for i in range(len(f_phi_array)):
    expansion_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_{}_expansion.txt".format(i))

    a_today = expansion_today.T[0]
    E_a_today = expansion_today.T[1]
    E_a_GR = np.sqrt((wb+wc)*a_today**(-3) + wr*a_today**(-4) + (h**2 - (wb+wc) -wr))/h
    if (np.min(E_a_today/E_a_GR)) == 0.0:
        zero_vals.append(i)
    ax[0][0].plot(1/a_today -1, E_a_today/E_a_GR, alpha=0.7)

for i in range(len(f_phi_array)):
    force_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files//Output/f_phi_tests/horndeski_model_run_{}_force.txt".format(i))
    a_today = force_today.T[0]
    chiD_today = force_today.T[1]
    coupling = force_today.T[2]

    ax[1][0].plot(1/a_today -1, chiD_today, alpha=0.7)

for i in range(len(f_phi_array)):
    force_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files//Output/f_phi_tests/horndeski_model_run_{}_force.txt".format(i))

    a_today = force_today.T[0]
    chiD_today = force_today.T[1]
    coupling = force_today.T[2]

    ax[2][0].plot(1/a_today -1, coupling, alpha=0.7)



for i in range(len(f_phi_array)-4):
    expansion_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/f_phi_tests/horndeski_model_run_{}_expansion.txt".format(i))

    a_today = expansion_today.T[0]
    E_a_today = expansion_today.T[1]
    E_a_GR = np.sqrt((wb+wc)*a_today**(-3) + wr*a_today**(-4) + (h**2 - (wb+wc) -wr))/h
    if (np.min(E_a_today/E_a_GR)) == 0.0:
        zero_vals.append(i)
    ax[0][1].plot(1/a_today -1, E_a_today/E_a_GR, alpha=0.7)

for i in range(len(f_phi_array)-4):
    force_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files//Output/f_phi_tests/horndeski_model_run_{}_force.txt".format(i))
    a_today = force_today.T[0]
    chiD_today = force_today.T[1]
    coupling = force_today.T[2]

    ax[1][1].plot(1/a_today -1, chiD_today, alpha=0.7)

for i in range(len(f_phi_array)-4):
    force_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files//Output/f_phi_tests/horndeski_model_run_{}_force.txt".format(i))

    a_today = force_today.T[0]
    chiD_today = force_today.T[1]
    coupling = force_today.T[2]

    ax[2][1].plot(1/a_today -1, coupling, alpha=0.7)

ax[0][1].yaxis.set_ticks_position("right")
ax[1][1].yaxis.set_ticks_position("right")
ax[2][1].yaxis.set_ticks_position("right")

ax[0][0].set_xscale("log")
ax[1][0].set_xscale("log")
ax[2][0].set_xscale("log")
ax[0][1].set_xscale("log")
ax[1][1].set_xscale("log")
ax[2][1].set_xscale("log")

ax[0][0].set_title("Background quantities for $f_{\phi} \leq 1$")
ax[0][1].set_title("Background quantities for $f_{\phi} \leq 10^{-2}$")
ax[0][0].set_ylabel(r"$E(z)$")
ax[1][0].set_ylabel(r"$chiD^{CuGal}/chiD^{\Lambda CDM}$")
ax[2][0].set_ylabel(r"$coupling^{CuGal}$")

fig.legend([r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[0]),
           r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[1]),
           r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[2]),
           r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[3]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[4]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[5]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[6]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[7]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[8])],
          bbox_to_anchor=(1.07, 0.7))
ax[2][0].set_xlim(2e-2,100)

ax[2][0].set_xlabel("z")
ax[2][1].set_xlabel("z")
#plt.savefig("Background_f_phi_rage", bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(14,6),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0)

params = {'legend.fontsize': 12,
          'legend.handlelength': 2}
plot.rcParams.update(params)

for i in range(len(f_phi_array)):
    k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests/pofk_my_new_Hi-COLA_simulation_{}_cb_z0.000.txt".format(i)).T
    k, Pk_NL_GR,Pk_Lin_GR = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests/pofk_my_new_Hi-COLA_simulation_GR_cb_z0.000.txt".format(i)).T
    
    ax[0].plot(k,Pk_NL/Pk_NL_GR, label = r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[i]) )

for i in range(len(f_phi_array)-4):
    k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests/pofk_my_new_Hi-COLA_simulation_{}_cb_z0.000.txt".format(i)).T
    k, Pk_NL_GR,Pk_Lin_GR = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_fphi_tests/pofk_my_new_Hi-COLA_simulation_GR_cb_z0.000.txt".format(i)).T
    
    ax[1].plot(k,Pk_NL/Pk_NL_GR, label = r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[i]) )


ax[0].set_xscale("log")
ax[1].set_xscale("log")
fig.legend([r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[0]),
           r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[1]),
           r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[2]),
           r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[3]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[4]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[5]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[6]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[7]),
          r"$f_{\phi} = $" + '%.E' % float('%.1g' % f_phi_array[8])],
          bbox_to_anchor=(1.07, 0.7))

ax[0].set_xlabel(r"k [h $Mpc^{-1}]$")
ax[1].set_xlabel(r"k [h $Mpc^{-1}]$")
ax[1].yaxis.set_ticks_position("right")
ax[0].set_xlim(2e-2,10)
ax[0].set_title("Background quantities for $f_{\phi} \leq 1$")
ax[1].set_title("Background quantities for $f_{\phi} \leq 3 x 10^{-2}$")

plt.savefig("Boosts_f_phi_rage", bbox_inches='tight')
ax[0].set_ylabel("Boost $B(k)$")
# Out:
# Text(128.84722222222223, 0.5, 'Boost $B(k)$')
