# %%
from configobj import ConfigObj
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline
from scipy.interpolate import RegularGridInterpolator
import pyccl as ccl

#from HiCOLA import Frontend

# %%
def wr_funct(T_CMB):
    return 4.48150052e-7*T_CMB**4 *(1+ 3.044*7/8 * (4/11)**(4/3))

T_CMB = 2.72548 # K
print(wr_funct(T_CMB))
# Out:
# 4.182345109176885e-05

# %% [markdown]
# # Get Latin Hypercube

# %% [markdown]
# Latin hypercube already saved in:
# '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

# %%
sample_new = np.loadtxt('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker').T

# %% [markdown]
# # Get Power Spectra

# %% [raw]
# Power spectra already saved in "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_{}.dat".format(i)"

# %%
# Create cola folders - only need to do this once

#for i in range(len(sample_new[0])):
    # CAREFUL!! might not need this next step
    #command = 'cd; rm -r /home/c2042999/HiCOLA_env/Cubic_galileon_emu/Output_backend/COLA_{}_GR_tracker'.format(str(i))
    #os.system(command)
    #os.system("cd; cd /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/; mkdir COLA_{}_GR_tracker".format(str(i)))

# %% [markdown]
# # Run Frontend

# %%
def rewriteluafile(k,txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    wb = 0.0223
    wr = wr_funct(T_CMB)
    
    hcube = np.loadtxt(txt).T
    n_s = hcube[1][k]
    A_s = hcube[2][k]
    h = hcube[3][k]
    wm = hcube[0][k]*h**2

    f_phi = hcube[4][k]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}_GR_tracker.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_{}_GR_tracker"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_{}_GR_tracker"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = false'+'\n')
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_{}.dat"'.format(str(k))+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# Same as above
txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

# %%
def rewriteluafile_phasepair(k,txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    wb = 0.0223
    wr = wr_funct(T_CMB)
    
    hcube = np.loadtxt(txt).T
    n_s = hcube[1][k]
    A_s = hcube[2][k]
    h = hcube[3][k]
    wm = hcube[0][k]*h**2
    
    f_phi = hcube[4][k]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}_GR_tracker_phasepair.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_{}_GR_tracker_phasepair"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_{}_GR_tracker"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = true'+'\n')
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_{}.dat"'.format(str(k))+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# Same as above
txt = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_tracker'

# %%
"""Re-write lua file"""
for i in range(len(sample_new[0])):
    rewriteluafile(i,txt,400,512,1536)
    # phase pair
    rewriteluafile_phasepair(i,txt,400,512,1536)

# %%
"""Create Pk"""
for i in range(len(sample_new[0])):
    os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}_GR_tracker.lua".format(str(i)))
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-5]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-5]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-5]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-5]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-5]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-5]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-5]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-5]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-5]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-5]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-5]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-5]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-5]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-5]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-5]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-5]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-5]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-5]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-5]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-5]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-5]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-5]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-5]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-5]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-5]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-5]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-5]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-5]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-5]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-5]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-5]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-5]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 55 elements:
# #=====================================================
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.541e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.261386
#   cosmology_OmegaLambda          : 0.689394
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.049128
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.673733
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : LCDM
#   cosmology_ns                   : 1.085
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : GR
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_0.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : false
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_GR_tracker
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_0_GR_tracker
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              50 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [LCDM]
# # Omegab      : 0.049128
# # OmegaM      : 0.310514
# # OmegaMNu    : 0
# # OmegaCDM    : 0.261386
# # OmegaLambda : 0.689394
# # OmegaR      : 5.44792e-05
# # OmegaNu     : 3.7687e-05
# # OmegaRtot   : 9.21661e-05
# # OmegaK      : 0
# # h           : 0.673733
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 2.541e-09
# # ns          : 1.085
# # kpivot      : 0.05 1/Mpc
# #=====================================================
#
# #=====================================================
# # GravityModel is [GR] and has the cosmology: [LCDM]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_0_GR_tracker
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_0.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : false
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 50
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_GR_tracker
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_backscaled_0.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      1.86065         504470
# 0.00251653      4.65747         488644
# 0.00621709      10.2167         443084
# 0.0153593       16.2025         341615
# 0.0379453       11.7129         177824
# 0.0937441       5.03084         71349.8
# 0.231595        1.29067         22125.5
# 0.572157        0.238058        5817.58
# 1.41352         0.0339245       1344.53
# 3.4921          0.00414748      287.819
# 8.62724         0.000457274     58.51
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 13.8359 (Mpc/h)^3
# k =  0.10: P(k,zini) = 4.50439 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0730716 (Mpc/h)^3
# k = 10.00: P(k,zini) = 0.000316636 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.933564
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.821801 Mpc/h
# Maximum 1LPT velocity: 323.122 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.0160693 Mpc/h
# Maximum 2LPT velocity: 12.6688 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 50
# Step: 0    / 50
# Positions  from z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# Step: 1    / 50
# Positions  from z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# Step: 2    / 50
# Positions  from z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# Step: 3    / 50
# Positions  from z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# Step: 4    / 50
# Positions  from z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# Step: 5    / 50
# Positions  from z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# Step: 6    / 50
# Positions  from z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# Step: 7    / 50
# Positions  from z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# Step: 8    / 50
# Positions  from z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# Step: 9    / 50
# Positions  from z = 4.09165         -> 3.62963
# Velocities from z = 4.35906         -> 3.84966
# Step: 10   / 50
# Positions  from z = 3.62963         -> 3.24448
# Velocities from z = 3.84966         -> 3.4287
# Step: 11   / 50
# Positions  from z = 3.24448         -> 2.9185
# Velocities from z = 3.4287          -> 3.07498
# Step: 12   / 50
# Positions  from z = 2.9185          -> 2.63901
# Velocities from z = 3.07498         -> 2.77358
# Step: 13   / 50
# Positions  from z = 2.63901         -> 2.39674
# Velocities from z = 2.77358         -> 2.5137
# Step: 14   / 50
# Positions  from z = 2.39674         -> 2.18471
# Velocities from z = 2.5137          -> 2.28731
# Step: 15   / 50
# Positions  from z = 2.18471         -> 1.9976
# Velocities from z = 2.28731         -> 2.08833
# Step: 16   / 50
# Positions  from z = 1.9976          -> 1.83126
# Velocities from z = 2.08833         -> 1.91206
# Step: 17   / 50
# Positions  from z = 1.83126         -> 1.6824
# Velocities from z = 1.91206         -> 1.75482
# Step: 18   / 50
# Positions  from z = 1.6824          -> 1.54842
# Velocities from z = 1.75482         -> 1.6137
# Step: 19   / 50
# Positions  from z = 1.54842         -> 1.42718
# Velocities from z = 1.6137          -> 1.48633
# Step: 20   / 50
# Positions  from z = 1.42718         -> 1.31696
# Velocities from z = 1.48633         -> 1.37079
# Step: 21   / 50
# Positions  from z = 1.31696         -> 1.21631
# Velocities from z = 1.37079         -> 1.26552
# Step: 22   / 50
# Positions  from z = 1.21631         -> 1.12404
# Velocities from z = 1.26552         -> 1.1692
# Step: 23   / 50
# Positions  from z = 1.12404         -> 1.03915
# Velocities from z = 1.1692          -> 1.08073
# Step: 24   / 50
# Positions  from z = 1.03915         -> 0.960784
# Velocities from z = 1.08073         -> 0.9992
# Step: 25   / 50
# Positions  from z = 0.960784        -> 0.888218
# Velocities from z = 0.9992          -> 0.923817
# Step: 26   / 50
# Positions  from z = 0.888218        -> 0.82083
# Velocities from z = 0.923817        -> 0.853912
# Step: 27   / 50
# Positions  from z = 0.82083         -> 0.758087
# Velocities from z = 0.853912        -> 0.788909
# Step: 28   / 50
# Positions  from z = 0.758087        -> 0.699524
# Velocities from z = 0.788909        -> 0.72831
# Step: 29   / 50
# Positions  from z = 0.699524        -> 0.644737
# Velocities from z = 0.72831         -> 0.671682
# Step: 30   / 50
# Positions  from z = 0.644737        -> 0.593372
# Velocities from z = 0.671682        -> 0.618647
# Step: 31   / 50
# Positions  from z = 0.593372        -> 0.545117
# Velocities from z = 0.618647        -> 0.568874
# Step: 32   / 50
# Positions  from z = 0.545117        -> 0.4997
# Velocities from z = 0.568874        -> 0.52207
# Step: 33   / 50
# Positions  from z = 0.4997          -> 0.456876
# Velocities from z = 0.52207         -> 0.477978
# Step: 34   / 50
# Positions  from z = 0.456876        -> 0.416431
# Velocities from z = 0.477978        -> 0.436369
# Step: 35   / 50
# Positions  from z = 0.416431        -> 0.37817
# Velocities from z = 0.436369        -> 0.397038
# Step: 36   / 50
# Positions  from z = 0.37817         -> 0.341922
# Velocities from z = 0.397038        -> 0.359804
# Step: 37   / 50
# Positions  from z = 0.341922        -> 0.307531
# Velocities from z = 0.359804        -> 0.324503
# Step: 38   / 50
# Positions  from z = 0.307531        -> 0.27486
# Velocities from z = 0.324503        -> 0.290989
# Step: 39   / 50
# Positions  from z = 0.27486         -> 0.243781
# Velocities from z = 0.290989        -> 0.259129
# Step: 40   / 50
# Positions  from z = 0.243781        -> 0.214182
# Velocities from z = 0.259129        -> 0.228803
# Step: 41   / 50
# Positions  from z = 0.214182        -> 0.185958
# Velocities from z = 0.228803        -> 0.199904
# Step: 42   / 50
# Positions  from z = 0.185958        -> 0.159017
# Velocities from z = 0.199904        -> 0.172333
# Step: 43   / 50
# Positions  from z = 0.159017        -> 0.133273
# Velocities from z = 0.172333        -> 0.146
# Step: 44   / 50
# Positions  from z = 0.133273        -> 0.108647
# Velocities from z = 0.146           -> 0.120825
# Step: 45   / 50
# Positions  from z = 0.108647        -> 0.0850694
# Velocities from z = 0.120825        -> 0.0967317
# Step: 46   / 50
# Positions  from z = 0.0850694       -> 0.0624734
# Velocities from z = 0.0967317       -> 0.0736526
# Step: 47   / 50
# Positions  from z = 0.0624734       -> 0.0407993
# Velocities from z = 0.0736526       -> 0.0515247
# Step: 48   / 50
# Positions  from z = 0.0407993       -> 0.0199918
# Velocities from z = 0.0515247       -> 0.0302905
# Step: 49   / 50
# Positions  from z = 0.0199918       -> 0
# Velocities from z = 0.0302905       -> 0.00989699
# Step: 50   / 50
# Positions  from z = 0               -> 0
# Velocities from z = 0.00989699      -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 50 Total steps taken: 0
# Positions from  z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# deltatime_pos = 7.30283         deltatime_vel = 5.56619
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.000607315
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000151051
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4198993 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.6352 %% (min)
# #               50.4274 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4704.08         MB (min over tasks)
# # Current RSS: 4705.09         MB (max over tasks)
# # Peak RSS:    4804.49         MB (min over tasks)
# # Peak RSS:    4806.4          MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 50 Total steps taken: 1
# Positions from  z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# deltatime_pos = 3.27424         deltatime_vel = 4.48098
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00156338
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000260502
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4203429 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.495 %% (min)
# #               50.5124 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4704.87         MB (min over tasks)
# # Current RSS: 4711.07         MB (max over tasks)
# # Peak RSS:    4804.49         MB (min over tasks)
# # Peak RSS:    4807.19         MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 50 Total steps taken: 2
# Positions from  z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# deltatime_pos = 1.9605          deltatime_vel = 2.44362
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00111519
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00037896
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4208067 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.299 %% (min)
# #               50.6791 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4684.72         MB (min over tasks)
# # Current RSS: 4711.5          MB (max over tasks)
# # Peak RSS:    4804.49         MB (min over tasks)
# # Peak RSS:    4811.66         MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 50 Total steps taken: 3
# Positions from  z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# deltatime_pos = 1.34072         deltatime_vel = 1.58932
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.0010769
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000840102
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4210470 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.1351 %% (min)
# #               50.8674 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4685.61         MB (min over tasks)
# # Current RSS: 4712.6          MB (max over tasks)
# # Peak RSS:    4804.49         MB (min over tasks)
# # Peak RSS:    4811.66         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 50 Total steps taken: 4
# Positions from  z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# deltatime_pos = 0.990616        deltatime_vel = 1.13801
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00133387
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00122296
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4212182 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.969 %% (min)
# #               51.0369 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4686.68         MB (min over tasks)
# # Current RSS: 4713.36         MB (max over tasks)
# # Peak RSS:    4804.49         MB (min over tasks)
# # Peak RSS:    4811.66         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 50 Total steps taken: 5
# Positions from  z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# deltatime_pos = 0.770043        deltatime_vel = 0.865823
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00187469
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00185109
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4214059 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.8048 %% (min)
# #               51.2134 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4687.65         MB (min over tasks)
# # Current RSS: 4714.13         MB (max over tasks)
# # Peak RSS:    4804.49         MB (min over tasks)
# # Peak RSS:    4811.66         MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 50 Total steps taken: 6
# Positions from  z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# deltatime_pos = 0.620442        deltatime_vel = 0.686818
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00205392
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.0026122
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4216494 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.6473 %% (min)
# #               51.3873 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4688.75         MB (min over tasks)
# # Current RSS: 4714.9          MB (max over tasks)
# # Peak RSS:    4804.49         MB (min over tasks)
# # Peak RSS:    4812.61         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 50 Total steps taken: 7
# Positions from  z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# deltatime_pos = 0.51341         deltatime_vel = 0.561659
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00287726
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00360338
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4219504 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.504 %% (min)
# #               51.5712 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4689.14         MB (min over tasks)
# # Current RSS: 4715.66         MB (max over tasks)
# # Peak RSS:    4804.49         MB (min over tasks)
# # Peak RSS:    4813.74         MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 50 Total steps taken: 8
# Positions from  z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# deltatime_pos = 0.433662        deltatime_vel = 0.470053
# Adding particles (baryons+CDM) to the densityfield

# %%
"""Create Pk"""
for i in range(len(sample_new[0])):
    os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}_GR_tracker_phasepair.lua".format(str(i)))
