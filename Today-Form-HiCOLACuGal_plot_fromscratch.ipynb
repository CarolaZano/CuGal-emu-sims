# %%
from configobj import ConfigObj
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline
from scipy.interpolate import RegularGridInterpolator
import pyccl as ccl

# %%
## Define parameters for comparison plots

# from paper
wr = 4.28e-5
wc = 0.1274
wb = 0.02196
h = 0.7307

f_phi = 1.0
k_1 = -6. * 0.8484372511237896**2

# We assume:
A_s = 2.1e-9
n_s = 0.966

# Derived params
Omg_r = wr/h**2
Omg_m = (wc+wb)/h**2
Omg_b = wb/h**2
Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)

# %%
print(Omg_m)
# Out:
# 0.2797409788825341

# %%
g31T_pred = (1-Omg_m-Omg_r) - k_1/6
print(g31T_pred)
print(1.4400246287638065)
# Out:
# 1.4400246287638052
# 1.4400246287638065

# %%
np.savetxt('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_reduced',\
           np.array([wc+wb,n_s,A_s,k_1,f_phi]).T)

# %% [markdown]
# # CuGal Simulation

# %% [markdown]
# ## Run Backend

# %% [markdown]
# ### Get Power Spectra

# %%
## Power spectrum from CCL - with radiation

kk = np.logspace(-3,1,500)*h     # in 1/Mpc


cosmoLCDM = ccl.Cosmology(Omega_c=Omg_m - Omg_b,
                               Omega_b=Omg_b, 
                               A_s=A_s, #2.3429595e-9,
                               h = h,
                               n_s=n_s, #0.953,
                               Omega_k=0)

Pk = ccl.power.linear_matter_power(cosmoLCDM, kk, 1/(1+49))    # in (Mpc)^3


P_k_units = Pk*h**3    # in (Mpc)^3/h^3

kk_units = kk/h    # in h/Mpc

## Save power spectrum for initial conditions (Linear)

np.savetxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid.dat", np.array([kk_units, P_k_units]).T)

# %%
## Power spectrum from CCL -without radiation

kk = np.logspace(-3,1,500)*h     # in 1/Mpc


cosmoLCDM = ccl.Cosmology(Omega_c=Omg_m - Omg_b,
                               Omega_b=Omg_b, 
                               A_s=A_s, #2.3429595e-9,
                               h = h,
                               n_s=n_s, #0.953,
                               Omega_k=0)

# Omega_g::: Note that if a non-None value is given, this may result in a physically 
# inconsistent model because the CMB temperature will still be non-zero in the parameters.
cosmoLCDM_norad = ccl.Cosmology(Omega_c=Omg_m - Omg_b,
                               Omega_b=Omg_b, 
                               A_s=A_s, #2.3429595e-9,
                               h = h,
                               n_s=n_s, #0.953,
                               Omega_k=0,
                               Omega_g = 0,
                               T_CMB = 0.0)

Pk_0 = ccl.power.linear_matter_power(cosmoLCDM, kk, 1)    # in (Mpc)^3

Growth_0 = ccl.background.growth_factor(cosmoLCDM_norad, 1)

Growth_49 = ccl.background.growth_factor(cosmoLCDM_norad, 1/(1+49))

print(Growth_49/Growth_0)
print(ccl.background.growth_factor(cosmoLCDM, 1/(1+49)) / ccl.background.growth_factor(cosmoLCDM, 1))
P_k_units_norad = (Growth_49/Growth_0)**2 * Pk_0*h**3    # in (Mpc)^3/h^3

kk_units = kk/h    # in h/Mpc
## Save power spectrum for initial conditions (Linear)

np.savetxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid_backscaled.dat", np.array([kk_units, P_k_units_norad]).T)
# Out:
# 0.026096800154296957
# 0.026330542538800603

# %%
## Plot power spectrum


plt.plot(kk_units,P_k_units)
plt.plot(kk_units,P_k_units_norad, "--")
kk_Georgios, Pk_Georgios = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/LCDM_1306dot3219_matterpower_z0.000.dat").T

plt.plot(kk_Georgios,Pk_Georgios)

plt.xscale("log")
plt.yscale("log")

# %%
## Plot power spectrum


plt.plot(kk_units,P_k_units/P_k_units_norad)
plt.xscale("log")

# %% [markdown]
# ### Get expansion and force files

# %%
''' Define useful functions'''

def hypercube_arrays(txt):
    """
    Takes in txt file with (omega_m,n_s,A_s,k_1,f_phi)
    returns  numerical array
    # numerical - [h , wr , wb , wc, n_s , A_s]
    """
    wr = 4.28e-5
    wb = 0.02196
    h = 0.7307
    
    hcube = np.loadtxt(txt).T
    wm = hcube[0]
    n_s = hcube[1]
    A_s = hcube[2]
    arr_num = [h, wr, wb, wm - wb, n_s, A_s]
    
    return arr_num

def Update_ini(run, arr_hor, arr_num, horn_ini, num_ini):
    """
    Updates files num_ini and horn_ini to include the parameters (numerical and MG) from 
    arr_hor = f_phi, H0, k1, g31 and
    arr_num = h , wr , wb , wc, n_s , A_s
    """
    ## Horndeski params
    f_phi, k1 = arr_hor
    h , wr , wb , wc, n_s , A_s = arr_num
    config_h = ConfigObj(horn_ini)
    
    keys_h = config_h.keys()
    
    config_h[keys_h[1]] = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today'
    config_h[keys_h[0]] = 'horndeski_model'
    
    config_h[keys_h[2]] = 'k_1*X'
    config_h[keys_h[3]] = 'g_31*X'
    config_h[keys_h[4]] = '0.5'

    config_h[keys_h[7]] = str(k1)
    config_h[keys_h[8]] = str("1")
    config_h[keys_h[9]] = str(f_phi)
    config_h[keys_h[10]] = str("1")
    config_h[keys_h[11]] = str("1")
    config_h[keys_h[20]] = str("False")
    config_h[keys_h[22]] = str("1")

    ## Numerical params
    config_n = ConfigObj(num_ini)
    keys_n = config_n.keys()
    
    config_n[keys_n[0]] = 'run_'+str(run)

    
    config_n[keys_n[6]] = str(h)
    config_n[keys_n[7]] = str(wr)
    config_n[keys_n[8]] = str(wb)
    config_n[keys_n[9]] = str(wc)
    config_h.filename = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini'
    config_n.filename = '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'
    config_h.write(); config_n.write()

# %%
## TODO - need to delete the files manually every time
a_n = hypercube_arrays('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_reduced')
a_h = np.array([f_phi, k_1])

Update_ini(str(0), np.array(a_h).T, np.array(a_n).T, '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_parameters.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_parameters.ini')
command = 'cd ; cd /home/c2042999/HiCOLA_env/Hi-COLA; python3 -m HiCOLA.Frontend.generate_simulation_input /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'
os.system(command)
# Out:
# Namespace(input_ini_filenames=['/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/horndeski_today.ini', '/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/numerical_today.ini'])
# Horndeski functions --------------
# K = X*k_1
# G_3 = X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# horndeski_model model parameters, [k_1, g_31] = [-4.319074614566955, 0.9]
# Cosmological parameters-----------
# Omega_m0 = 0.2797409788825341
# Omega_r0 = 8.016144815327033e-05
# Omega_lambda0 = 0.0
# Initial conditions----------------
# Hubble0 = 1.0
# scalar_prime0 = 1.0
# Closure parameter is g_31 = 1.4400246287638065
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today
# 0

# %% [markdown]
# ## Run Frontend

# %%
def rewriteluafile(k,txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,k_1,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """
    wr = 4.28e-5
    wb = 0.02196
    h = 0.7307
    
    hcube = np.loadtxt(txt).T
    wm = hcube[0]
    n_s = hcube[1]
    A_s = hcube[2]
    f_phi = hcube[4]

    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)

    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_{}_norad"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today/horndeski_model_run_{}_expansion.txt"'.format(str(k))+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today/horndeski_model_run_{}_force.txt"'.format(str(k))+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_{}_T"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {20}'+'\n')        
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid_backscaled.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

txt = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_reduced"

# %%
"""Re-write lua file"""
rewriteluafile(0,txt,400,512,512)

# %%
"""Create Pk"""

os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_0.lua")
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-3]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-3]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-3]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-3]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-3]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-3]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-3]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-3]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-3]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-3]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-3]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-3]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-3]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-3]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-3]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-3]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-3]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-3]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-3]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-3]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-3]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-3]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-3]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-3]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-3]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-3]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-3]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-3]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-3]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-3]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-3]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-3]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 62 elements:
# #=====================================================
#   HiCOLA_expansion_filename      : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today/horndeski_model_run_0_expansion.txt
#   HiCOLA_preforce_filename       : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today/horndeski_model_run_0_force.txt
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.1e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.238611
#   cosmology_OmegaLambda          : 0.720179
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.0411296
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.7307
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : HiCOLA
#   cosmology_ns                   : 0.966
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 512
#   gravity_model                  : HiCOLA
#   gravity_model_HiCOLA_smoothing_filter : gaussian
#   gravity_model_HiCOLA_smoothing_scale_over_boxsize : 0.0075
#   gravity_model_screening        : true
#   gravity_model_screening_enforce_largescale_linear : true
#   gravity_model_screening_linear_scale_hmpc : 0.2
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : false
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid_backscaled.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 1234
#   ic_reverse_phases              : false
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_T
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 512
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_0_norad
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              20 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [HiCOLA]
# # Omegab      : 0.0411296
# # OmegaM      : 0.279741
# # OmegaMNu    : 0
# # OmegaCDM    : 0.238611
# # OmegaLambda : 0.720177
# # OmegaR      : 4.63157e-05
# # OmegaNu     : 3.20398e-05
# # OmegaRtot   : 7.83555e-05
# # OmegaK      : 0
# # h           : 0.7307
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 2.1e-09
# # ns          : 0.966
# # kpivot      : 0.05 1/Mpc
# # HiCOLA_expansion_filename     : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today/horndeski_model_run_0_expansion.txt
# #=====================================================
#
# #=====================================================
# # GravityModel is [HiCOLA] and has the cosmology: [HiCOLA]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# # HiCOLA_preforce_filename : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today/horndeski_model_run_0_force.txt
# # Screening method : true
# # Enforce correct linear evolution : true
# # Scale for which we enforce this  : 0.2 h/Mpc
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_0_norad
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 512
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid_backscaled.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 1234
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : false
# ic_reverse_phases                        : false
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 20
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 512
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_T
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid_backscaled.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      3.145           475868
# 0.00251653      7.05592         460509
# 0.00621709      13.8304         416546
# 0.0153593       19.4082         318803
# 0.0379453       12.4446         164932
# 0.0937441       4.73347         65718.8
# 0.231595        1.14            20837
# 0.572157        0.184222        5411.77
# 1.41352         0.0235284       1249.54
# 3.4921          0.0025797       267.314
# 8.62724         0.000255156     54.3157
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 17.6018 (Mpc/h)^3
# k =  0.10: P(k,zini) = 4.3046 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0528409 (Mpc/h)^3
# k = 10.00: P(k,zini) = 0.000173587 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.933377
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.820443 Mpc/h
# Maximum 1LPT velocity: 306.184 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.0123567 Mpc/h
# Maximum 2LPT velocity: 9.24612 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 20
# Step: 0    / 20
# Positions  from z = 49              -> 13.4928
# Velocities from z = 49              -> 21.4719
# Step: 1    / 20
# Positions  from z = 13.4928         -> 7.47458
# Velocities from z = 21.4719         -> 9.69519
# Step: 2    / 20
# Positions  from z = 7.47458         -> 4.98802
# Velocities from z = 9.69519         -> 6.01754
# Step: 3    / 20
# Positions  from z = 4.98802         -> 3.62963
# Velocities from z = 6.01754         -> 4.22193
# Step: 4    / 20
# Positions  from z = 3.62963         -> 2.77358
# Velocities from z = 4.22193         -> 3.158
# Step: 5    / 20
# Positions  from z = 2.77358         -> 2.18471
# Velocities from z = 3.158           -> 2.45423
# Step: 6    / 20
# Positions  from z = 2.18471         -> 1.75482
# Velocities from z = 2.45423         -> 1.95421
# Step: 7    / 20
# Positions  from z = 1.75482         -> 1.42718
# Velocities from z = 1.95421         -> 1.58065
# Step: 8    / 20
# Positions  from z = 1.42718         -> 1.1692
# Velocities from z = 1.58065         -> 1.29095
# Step: 9    / 20
# Positions  from z = 1.1692          -> 0.960784
# Velocities from z = 1.29095         -> 1.05973
# Step: 10   / 20
# Positions  from z = 0.960784        -> 0.788909
# Velocities from z = 1.05973         -> 0.870907
# Step: 11   / 20
# Positions  from z = 0.788909        -> 0.644737
# Velocities from z = 0.870907        -> 0.713796
# Step: 12   / 20
# Positions  from z = 0.644737        -> 0.52207
# Velocities from z = 0.713796        -> 0.581028
# Step: 13   / 20
# Positions  from z = 0.52207         -> 0.416431
# Velocities from z = 0.581028        -> 0.467351
# Step: 14   / 20
# Positions  from z = 0.416431        -> 0.324503
# Velocities from z = 0.467351        -> 0.368925
# Step: 15   / 20
# Positions  from z = 0.324503        -> 0.243781
# Velocities from z = 0.368925        -> 0.282874
# Step: 16   / 20
# Positions  from z = 0.243781        -> 0.172333
# Velocities from z = 0.282874        -> 0.207001
# Step: 17   / 20
# Positions  from z = 0.172333        -> 0.108647
# Velocities from z = 0.207001        -> 0.139601
# Step: 18   / 20
# Positions  from z = 0.108647        -> 0.0515247
# Velocities from z = 0.139601        -> 0.0793308
# Step: 19   / 20
# Positions  from z = 0.0515247       -> 0
# Velocities from z = 0.0793308       -> 0.0251153
# Step: 20   / 20
# Positions  from z = 0               -> 0
# Velocities from z = 0.0251153       -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 20 Total steps taken: 0
# Positions from  z = 49              -> 13.4928
# Velocities from z = 49              -> 21.4719
# deltatime_pos = 12.2874         deltatime_vel = 13.0806
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# At a= 0.02 chi/delta=0.632101 coupling=9.39483e-05
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00289402
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000283466
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4202928 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.3103 %% (min)
# #               50.616 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1116.1          MB (min over tasks)
# # Current RSS: 1133.1          MB (max over tasks)
# # Peak RSS:    1279.82         MB (min over tasks)
# # Peak RSS:    1280.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 20 Total steps taken: 1
# Positions from  z = 13.4928         -> 7.47458
# Velocities from z = 21.4719         -> 9.69519
# deltatime_pos = 3.38157         deltatime_vel = 5.1847
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# At a= 0.069 chi/delta=0.689803 coupling=5.32427e-05
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00554701
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00075248
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4208442 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.8551 %% (min)
# #               50.9907 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1116.47         MB (min over tasks)
# # Current RSS: 1148.31         MB (max over tasks)
# # Peak RSS:    1279.82         MB (min over tasks)
# # Peak RSS:    1280.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 20 Total steps taken: 2
# Positions from  z = 7.47458         -> 4.98802
# Velocities from z = 9.69519         -> 6.01754
# deltatime_pos = 1.75271         deltatime_vel = 2.29497
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# At a= 0.118 chi/delta=0.630359 coupling=7.22994e-05
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00360826
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00143153
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4217988 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.3946 %% (min)
# #               51.394 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1116.83         MB (min over tasks)
# # Current RSS: 1144.81         MB (max over tasks)
# # Peak RSS:    1279.82         MB (min over tasks)
# # Peak RSS:    1280.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 20 Total steps taken: 3
# Positions from  z = 4.98802         -> 3.62963
# Velocities from z = 6.01754         -> 4.22193
# deltatime_pos = 1.11565         deltatime_vel = 1.35965
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# At a= 0.167 chi/delta=0.440698 coupling=0.000144017
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00514098
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00416934
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4225226 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.9571 %% (min)
# #               51.7959 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1117.09         MB (min over tasks)
# # Current RSS: 1145.41         MB (max over tasks)
# # Peak RSS:    1279.82         MB (min over tasks)
# # Peak RSS:    1280.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 20 Total steps taken: 4
# Positions from  z = 3.62963         -> 2.77358
# Velocities from z = 4.22193         -> 3.158
# deltatime_pos = 0.789236        deltatime_vel = 0.923086
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# At a= 0.216 chi/delta=0.32886 coupling=0.000363909
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00522403
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00497907
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4232021 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.508 %% (min)
# #               52.1799 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1125.47         MB (min over tasks)
# # Current RSS: 1146.57         MB (max over tasks)
# # Peak RSS:    1279.82         MB (min over tasks)
# # Peak RSS:    1280.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 20 Total steps taken: 5
# Positions from  z = 2.77358         -> 2.18471
# Velocities from z = 3.158           -> 2.45423
# deltatime_pos = 0.595321        deltatime_vel = 0.678183
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# At a= 0.265 chi/delta=0.28606 coupling=0.000967957
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00589768
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00775465
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4238619 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.0761 %% (min)
# #               52.5735 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1125.91         MB (min over tasks)
# # Current RSS: 1146.93         MB (max over tasks)
# # Peak RSS:    1279.82         MB (min over tasks)
# # Peak RSS:    1280.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 20 Total steps taken: 6
# Positions from  z = 2.18471         -> 1.75482
# Velocities from z = 2.45423         -> 1.95421
# deltatime_pos = 0.468353        deltatime_vel = 0.524185
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# At a= 0.314 chi/delta=0.272046 coupling=0.00241628
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00528305
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00813819
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4245138 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.6657 %% (min)
# #               53.0198 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1126.51         MB (min over tasks)
# # Current RSS: 1146.93         MB (max over tasks)
# # Peak RSS:    1279.82         MB (min over tasks)
# # Peak RSS:    1280.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 20 Total steps taken: 7
# Positions from  z = 1.75482         -> 1.42718
# Velocities from z = 1.95421         -> 1.58065
# deltatime_pos = 0.37899         deltatime_vel = 0.419157
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# At a= 0.363 chi/delta=0.271905 coupling=0.00549431
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00570378
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00873207
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4250625 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.2411 %% (min)
# #               53.457 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1126.96         MB (min over tasks)
# # Current RSS: 1146.93         MB (max over tasks)
# # Peak RSS:    1279.82         MB (min over tasks)
# # Peak RSS:    1280.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 20 Total steps taken: 8
# Positions from  z = 1.42718         -> 1.1692
# Velocities from z = 1.58065         -> 1.29095
# deltatime_pos = 0.31235         deltatime_vel = 0.342839
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# At a= 0.412 chi/delta=0.282412 coupling=0.0114133
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00640291
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00987249
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4252509 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               45.8302 %% (min)
# #               53.8924 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1127.35         MB (min over tasks)
# # Current RSS: 1150.38         MB (max over tasks)
# # Peak RSS:    1279.82         MB (min over tasks)
# # Peak RSS:    1280.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 9 / 20 Total steps taken: 9
# Positions from  z = 1.1692          -> 0.960784
# Velocities from z = 1.29095         -> 1.05973
# deltatime_pos = 0.260292        deltatime_vel = 0.284439
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# At a= 0.461 chi/delta=0.304773 coupling=0.0218706
# ...
# Mean over tasks: 988.932         MB
# Max over tasks:  1007.24         MB
# [Peak resident set size]:
# Min over tasks:  1279.82         MB
# Mean over tasks: 1280.3          MB
# Max over tasks:  1280.82         MB
#
# For info below we are only tracking allocation of standard
# container (Vector) and only allocations larger than 0 bytes
#
# Memory in use (Task 0):   943.997         MB
# Min over tasks:           943.997         MB
# Mean over tasks:          943.997         MB
# Max over tasks:           943.997         MB
#
# Peak memory use (Task 0): 1122.95         MB
# Max over tasks:           1122.95         MB
#
#
# We have the following things allocated on task 0:
# Address: 0x7fb77b8cb010 Size: 872.415 (MB) Label: MPIPartices::create_particle_grid
# Address: 0x7fb7b4156010 Size: 35.7908 (MB) Label: phi_2LPT(k,zini)
# Address: 0x7fb7ba37b010 Size: 35.7908 (MB) Label: phi_1LPT(k,zini)
#
# Total memory as function of time:
#  Time (sec): 0             Memory: 0             (MB)
#  Time (sec): 7.84e-07      Memory: 35.7908       (MB)
#  Time (sec): 1.35955       Memory: 71.5817       (MB)
#  Time (sec): 1.3756        Memory: 107.373       (MB)
#  Time (sec): 1.39692       Memory: 71.5817       (MB)
#  Time (sec): 1.43082       Memory: 107.373       (MB)
#  Time (sec): 1.46215       Memory: 143.163       (MB)
#  Time (sec): 1.48785       Memory: 107.373       (MB)
#  Time (sec): 1.4905        Memory: 143.163       (MB)
#  Time (sec): 1.51057       Memory: 178.954       (MB)
#  Time (sec): 1.53786       Memory: 143.163       (MB)
#  Time (sec): 1.541         Memory: 178.954       (MB)
#  Time (sec): 1.56422       Memory: 214.745       (MB)
#  Time (sec): 1.60123       Memory: 178.954       (MB)
#  Time (sec): 2.42945       Memory: 214.745       (MB)
#  Time (sec): 2.4525        Memory: 250.536       (MB)
#  Time (sec): 2.47218       Memory: 214.745       (MB)
#  Time (sec): 2.60792       Memory: 178.954       (MB)
#  Time (sec): 2.61085       Memory: 143.163       (MB)
#  Time (sec): 2.6457        Memory: 107.373       (MB)
#  Time (sec): 2.68795       Memory: 143.163       (MB)
#  Time (sec): 2.71085       Memory: 178.954       (MB)
#  Time (sec): 2.7318        Memory: 143.163       (MB)
#  Time (sec): 2.73547       Memory: 178.954       (MB)
#  Time (sec): 2.75832       Memory: 214.745       (MB)
#  Time (sec): 2.77787       Memory: 178.954       (MB)
#  Time (sec): 2.78133       Memory: 214.745       (MB)
#  Time (sec): 2.83296       Memory: 250.536       (MB)
#  Time (sec): 2.85217       Memory: 214.745       (MB)
#  Time (sec): 3.66591       Memory: 178.954       (MB)
#  Time (sec): 3.66878       Memory: 143.163       (MB)
#  Time (sec): 3.67166       Memory: 107.373       (MB)
#  Time (sec): 4.27759       Memory: 979.788       (MB)
#  Time (sec): 4.98117       Memory: 1015.58       (MB)
#  Time (sec): 5.0056        Memory: 1051.37       (MB)
#  Time (sec): 5.02498       Memory: 1015.58       (MB)
#  Time (sec): 5.02959       Memory: 1051.37       (MB)
#  Time (sec): 5.05383       Memory: 1087.16       (MB)
#  Time (sec): 5.07347       Memory: 1051.37       (MB)
#  Time (sec): 5.07763       Memory: 1087.16       (MB)
#  Time (sec): 5.10181       Memory: 1122.95       (MB)
#  Time (sec): 5.12233       Memory: 1087.16       (MB)
#  Time (sec): 5.77615       Memory: 1051.37       (MB)
#  Time (sec): 6.13638       Memory: 1015.58       (MB)
#  Time (sec): 6.13834       Memory: 979.788       (MB)
#  Time (sec): 6.17795       Memory: 943.997       (MB)
#  Time (sec): 6.17999       Memory: 979.788       (MB)
#  Time (sec): 6.22698       Memory: 1015.58       (MB)
#  Time (sec): 6.24774       Memory: 1051.37       (MB)
#  Time (sec): 6.26743       Memory: 1015.58       (MB)
#  Time (sec): 6.26971       Memory: 1051.37       (MB)
#  Time (sec): 6.29122       Memory: 1087.16       (MB)
#  Time (sec): 6.31093       Memory: 1051.37       (MB)
#  Time (sec): 6.3129        Memory: 1087.16       (MB)
#  Time (sec): 6.33441       Memory: 1122.95       (MB)
#  Time (sec): 6.3542        Memory: 1087.16       (MB)
#  Time (sec): 7.02076       Memory: 1051.37       (MB)
#  Time (sec): 7.42977       Memory: 1015.58       (MB)
#  Time (sec): 7.43193       Memory: 979.788       (MB)
#  Time (sec): 7.4342        Memory: 943.997       (MB)
#  Time (sec): 8.14057       Memory: 979.788       (MB)
#  Time (sec): 8.2373        Memory: 1015.58       (MB)
#  Time (sec): 8.26273       Memory: 979.788       (MB)
#  Time (sec): 8.37192       Memory: 943.997       (MB)
#  Time (sec): 8.38509       Memory: 979.788       (MB)
#  Time (sec): 9.52564       Memory: 1015.58       (MB)
#  Time (sec): 11.4919       Memory: 1051.37       (MB)
#  Time (sec): 11.5428       Memory: 1087.16       (MB)
#  Time (sec): 11.5635       Memory: 1122.95       (MB)
#  Time (sec): 12.122        Memory: 1087.16       (MB)
#  Time (sec): 13.4867       Memory: 1051.37       (MB)
#  Time (sec): 13.4958       Memory: 1015.58       (MB)
#  Time (sec): 13.5039       Memory: 979.788       (MB)
#  Time (sec): 13.5115       Memory: 943.997       (MB)
#  Time (sec): 13.5195       Memory: 979.788       (MB)
#  Time (sec): 14.4194       Memory: 1015.58       (MB)
#  Time (sec): 16.3349       Memory: 1051.37       (MB)
#  Time (sec): 16.356        Memory: 1087.16       (MB)
#  Time (sec): 16.3938       Memory: 1122.95       (MB)
#  Time (sec): 17.0246       Memory: 1087.16       (MB)
#  Time (sec): 18.3725       Memory: 1051.37       (MB)
#  Time (sec): 18.3801       Memory: 1015.58       (MB)
#  Time (sec): 18.3869       Memory: 979.788       (MB)
#  Time (sec): 18.3935       Memory: 943.997       (MB)
#  Time (sec): 18.4012       Memory: 979.788       (MB)
#  Time (sec): 19.2805       Memory: 1015.58       (MB)
#  Time (sec): 21.1429       Memory: 1051.37       (MB)
#  Time (sec): 21.221        Memory: 1087.16       (MB)
#  Time (sec): 21.269        Memory: 1122.95       (MB)
#  Time (sec): 21.88         Memory: 1087.16       (MB)
#  Time (sec): 23.2278       Memory: 1051.37       (MB)
#  Time (sec): 23.2353       Memory: 1015.58       (MB)
#  Time (sec): 23.2422       Memory: 979.788       (MB)
#  Time (sec): 23.2486       Memory: 943.997       (MB)
#  Time (sec): 23.2555       Memory: 979.788       (MB)
#  Time (sec): 24.1316       Memory: 1015.58       (MB)
#  Time (sec): 26.0852       Memory: 1051.37       (MB)
#  Time (sec): 26.1065       Memory: 1087.16       (MB)
#  Time (sec): 26.1722       Memory: 1122.95       (MB)
#  Time (sec): 26.7603       Memory: 1087.16       (MB)
#  Time (sec): 28.121        Memory: 1051.37       (MB)
#  Time (sec): 28.1289       Memory: 1015.58       (MB)
#  Time (sec): 28.1361       Memory: 979.788       (MB)
#  Time (sec): 28.1426       Memory: 943.997       (MB)
#  Time (sec): 28.15         Memory: 979.788       (MB)
#  Time (sec): 29.0347       Memory: 1015.58       (MB)
#  Time (sec): 30.9261       Memory: 1051.37       (MB)
#  Time (sec): 31.0138       Memory: 1087.16       (MB)
#  Time (sec): 31.0463       Memory: 1122.95       (MB)
#  Time (sec): 31.6332       Memory: 1087.16       (MB)
#  Time (sec): 33.0531       Memory: 1051.37       (MB)
#  Time (sec): 33.0606       Memory: 1015.58       (MB)
#  Time (sec): 33.0675       Memory: 979.788       (MB)
#  Time (sec): 33.0736       Memory: 943.997       (MB)
#  Time (sec): 33.0806       Memory: 979.788       (MB)
#  Time (sec): 34.0122       Memory: 1015.58       (MB)
#  Time (sec): 35.8101       Memory: 1051.37       (MB)
#  Time (sec): 35.8533       Memory: 1087.16       (MB)
#  Time (sec): 35.9216       Memory: 1122.95       (MB)
#  Time (sec): 36.62         Memory: 1087.16       (MB)
#  Time (sec): 38.0787       Memory: 1051.37       (MB)
#  Time (sec): 38.0858       Memory: 1015.58       (MB)
#  Time (sec): 38.0926       Memory: 979.788       (MB)
#  Time (sec): 38.0985       Memory: 943.997       (MB)
#  Time (sec): 38.1051       Memory: 979.788       (MB)
#  Time (sec): 39.0796       Memory: 1015.58       (MB)
#  Time (sec): 40.8479       Memory: 1051.37       (MB)
#  Time (sec): 40.8738       Memory: 1087.16       (MB)
#  Time (sec): 40.8912       Memory: 1122.95       (MB)
#  Time (sec): 41.6912       Memory: 1087.16       (MB)
#  Time (sec): 43.1194       Memory: 1051.37       (MB)
#  Time (sec): 43.1269       Memory: 1015.58       (MB)
#  Time (sec): 43.1335       Memory: 979.788       (MB)
#  Time (sec): 43.1395       Memory: 943.997       (MB)
#  Time (sec): 43.1466       Memory: 979.788       (MB)
#  Time (sec): 44.1114       Memory: 1015.58       (MB)
#  Time (sec): 46.0363       Memory: 1051.37       (MB)
#  Time (sec): 46.0591       Memory: 1087.16       (MB)
#  Time (sec): 46.0793       Memory: 1122.95       (MB)
#  Time (sec): 46.7148       Memory: 1087.16       (MB)
#  Time (sec): 48.1565       Memory: 1051.37       (MB)
#  Time (sec): 48.1646       Memory: 1015.58       (MB)
#  Time (sec): 48.1726       Memory: 979.788       (MB)
#  Time (sec): 48.1802       Memory: 943.997       (MB)
#  Time (sec): 48.1877       Memory: 979.788       (MB)
#  Time (sec): 49.1838       Memory: 1015.58       (MB)
#  Time (sec): 51.101        Memory: 1051.37       (MB)
#  Time (sec): 51.1192       Memory: 1087.16       (MB)
#  Time (sec): 51.1445       Memory: 1122.95       (MB)
#  Time (sec): 51.8355       Memory: 1087.16       (MB)
#  Time (sec): 53.3105       Memory: 1051.37       (MB)
#  Time (sec): 53.3177       Memory: 1015.58       (MB)
#  Time (sec): 53.3243       Memory: 979.788       (MB)
#  Time (sec): 53.3304       Memory: 943.997       (MB)
#  Time (sec): 53.3373       Memory: 979.788       (MB)
#  Time (sec): 54.3763       Memory: 1015.58       (MB)
#  Time (sec): 56.3142       Memory: 1051.37       (MB)
#  Time (sec): 56.3863       Memory: 1087.16       (MB)
#  Time (sec): 56.4294       Memory: 1122.95       (MB)
#  Time (sec): 56.9911       Memory: 1087.16       (MB)
#  Time (sec): 58.4828       Memory: 1051.37       (MB)
#  Time (sec): 58.4908       Memory: 1015.58       (MB)
#  Time (sec): 58.4982       Memory: 979.788       (MB)
#  Time (sec): 58.5052       Memory: 943.997       (MB)
#  Time (sec): 58.512        Memory: 979.788       (MB)
#  Time (sec): 59.5134       Memory: 1015.58       (MB)
#  Time (sec): 61.4255       Memory: 1051.37       (MB)
#  Time (sec): 61.4448       Memory: 1087.16       (MB)
#  Time (sec): 61.4859       Memory: 1122.95       (MB)
#  Time (sec): 62.113        Memory: 1087.16       (MB)
#  Time (sec): 63.5675       Memory: 1051.37       (MB)
#  Time (sec): 63.575        Memory: 1015.58       (MB)
#  Time (sec): 63.5816       Memory: 979.788       (MB)
#  Time (sec): 63.5877       Memory: 943.997       (MB)
#  Time (sec): 63.5946       Memory: 979.788       (MB)
#  Time (sec): 64.653        Memory: 1015.58       (MB)
#  Time (sec): 66.4194       Memory: 1051.37       (MB)
#  Time (sec): 66.4925       Memory: 1087.16       (MB)
#  Time (sec): 66.5108       Memory: 1122.95       (MB)
#  Time (sec): 67.2429       Memory: 1087.16       (MB)
#  Time (sec): 68.7683       Memory: 1051.37       (MB)
#  Time (sec): 68.7755       Memory: 1015.58       (MB)
#  Time (sec): 68.7822       Memory: 979.788       (MB)
#  Time (sec): 68.7882       Memory: 943.997       (MB)
#  Time (sec): 68.795        Memory: 979.788       (MB)
#  Time (sec): 69.8045       Memory: 1015.58       (MB)
#  Time (sec): 71.7119       Memory: 1051.37       (MB)
#  Time (sec): 71.7875       Memory: 1087.16       (MB)
#  Time (sec): 71.8062       Memory: 1122.95       (MB)
#  Time (sec): 72.4196       Memory: 1087.16       (MB)
#  Time (sec): 73.8993       Memory: 1051.37       (MB)
#  Time (sec): 73.9075       Memory: 1015.58       (MB)
#  Time (sec): 73.9146       Memory: 979.788       (MB)
#  Time (sec): 73.9208       Memory: 943.997       (MB)
#  Time (sec): 73.9278       Memory: 979.788       (MB)
#  Time (sec): 74.9398       Memory: 1015.58       (MB)
#  Time (sec): 76.7341       Memory: 1051.37       (MB)
#  Time (sec): 76.7909       Memory: 1087.16       (MB)
#  Time (sec): 76.8086       Memory: 1122.95       (MB)
#  Time (sec): 77.5626       Memory: 1087.16       (MB)
#  Time (sec): 79.0411       Memory: 1051.37       (MB)
#  Time (sec): 79.05         Memory: 1015.58       (MB)
#  Time (sec): 79.0581       Memory: 979.788       (MB)
#  Time (sec): 79.0656       Memory: 943.997       (MB)
#  Time (sec): 79.0735       Memory: 979.788       (MB)
#  Time (sec): 80.1001       Memory: 1015.58       (MB)
#  Time (sec): 82.0039       Memory: 1051.37       (MB)
#  Time (sec): 82.0491       Memory: 1087.16       (MB)
#  Time (sec): 82.069        Memory: 1122.95       (MB)
#  Time (sec): 82.7318       Memory: 1087.16       (MB)
#  Time (sec): 84.2108       Memory: 1051.37       (MB)
#  Time (sec): 84.2181       Memory: 1015.58       (MB)
#  Time (sec): 84.225        Memory: 979.788       (MB)
#  Time (sec): 84.2312       Memory: 943.997       (MB)
#  Time (sec): 84.2384       Memory: 979.788       (MB)
#  Time (sec): 85.2746       Memory: 1015.58       (MB)
#  Time (sec): 87.0045       Memory: 1051.37       (MB)
#  Time (sec): 87.0214       Memory: 1087.16       (MB)
#  Time (sec): 87.1613       Memory: 1122.95       (MB)
#  Time (sec): 87.8902       Memory: 1087.16       (MB)
#  Time (sec): 89.3886       Memory: 1051.37       (MB)
#  Time (sec): 89.3978       Memory: 1015.58       (MB)
#  Time (sec): 89.4061       Memory: 979.788       (MB)
#  Time (sec): 89.4135       Memory: 943.997       (MB)
#  Time (sec): 89.4212       Memory: 979.788       (MB)
#  Time (sec): 90.4937       Memory: 1015.58       (MB)
#  Time (sec): 92.2199       Memory: 1051.37       (MB)
#  Time (sec): 92.3834       Memory: 1087.16       (MB)
#  Time (sec): 92.4453       Memory: 1122.95       (MB)
#  Time (sec): 93.1044       Memory: 1087.16       (MB)
#  Time (sec): 94.603        Memory: 1051.37       (MB)
#  Time (sec): 94.6101       Memory: 1015.58       (MB)
#  Time (sec): 94.617        Memory: 979.788       (MB)
#  Time (sec): 94.6231       Memory: 943.997       (MB)
#  Time (sec): 94.6299       Memory: 979.788       (MB)
#  Time (sec): 95.6738       Memory: 1015.58       (MB)
#  Time (sec): 97.5163       Memory: 1051.37       (MB)
#  Time (sec): 97.5699       Memory: 1087.16       (MB)
#  Time (sec): 97.7421       Memory: 1122.95       (MB)
#  Time (sec): 98.2875       Memory: 1087.16       (MB)
#  Time (sec): 99.8262       Memory: 1051.37       (MB)
#  Time (sec): 99.8337       Memory: 1015.58       (MB)
#  Time (sec): 99.8403       Memory: 979.788       (MB)
#  Time (sec): 99.8466       Memory: 943.997       (MB)
#  Time (sec): 99.8537       Memory: 979.788       (MB)
#  Time (sec): 100.904       Memory: 1015.58       (MB)
#  Time (sec): 102.795       Memory: 1051.37       (MB)
#  Time (sec): 102.839       Memory: 1087.16       (MB)
#  Time (sec): 102.875       Memory: 1122.95       (MB)
#  Time (sec): 103.528       Memory: 1087.16       (MB)
#  Time (sec): 105.033       Memory: 1051.37       (MB)
#  Time (sec): 105.041       Memory: 1015.58       (MB)
#  Time (sec): 105.048       Memory: 979.788       (MB)
#  Time (sec): 105.056       Memory: 943.997       (MB)
#  Time (sec): 105.063       Memory: 979.788       (MB)
#  Time (sec): 106.107       Memory: 1015.58       (MB)
#  Time (sec): 107.968       Memory: 1051.37       (MB)
#  Time (sec): 107.997       Memory: 1087.16       (MB)
#  Time (sec): 108.023       Memory: 1122.95       (MB)
#  Time (sec): 108.704       Memory: 1087.16       (MB)
#  Time (sec): 110.201       Memory: 1051.37       (MB)
#  Time (sec): 110.21        Memory: 1015.58       (MB)
#  Time (sec): 110.218       Memory: 979.788       (MB)
#  Time (sec): 110.226       Memory: 943.997       (MB)
#  Time (sec): 110.234       Memory: 979.788       (MB)
#  Time (sec): 111.288       Memory: 1015.58       (MB)
#  Time (sec): 113.276       Memory: 1051.37       (MB)
#  Time (sec): 113.332       Memory: 1087.16       (MB)
#  Time (sec): 113.389       Memory: 1122.95       (MB)
#  Time (sec): 113.921       Memory: 1087.16       (MB)
#  Time (sec): 115.132       Memory: 1051.37       (MB)
#  Time (sec): 115.14        Memory: 1015.58       (MB)
#  Time (sec): 115.147       Memory: 979.788       (MB)
#  Time (sec): 115.153       Memory: 943.997       (MB)
#  Time (sec): 115.483       Memory: 986.104       (MB)
#  Time (sec): 117.873       Memory: 1028.21       (MB)
#  Time (sec): 122.032       Memory: 986.104       (MB)
#  Time (sec): 122.461       Memory: 943.997       (MB)
#
# #=====================================================
# 0

# %% [markdown]
# # GR Simulation

# %% [markdown]
# ## Run Frontend

# %%
def rewriteluafile(k,txt,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """
    wr = 4.28e-5
    wb = 0.02196
    h = 0.7307
    
    hcube = np.loadtxt(txt).T
    wm = hcube[0]
    n_s = hcube[1]
    A_s = hcube[2]

    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)

    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_{}_GR.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_{}_GR"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_{}"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {20}'+'\n')   
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid.dat"'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

txt = "/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/cosmo_newdesign_reduced"

# %%
"""Re-write lua file"""
rewriteluafile(0,txt,400,512,512)

# %%
os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/luafiles/Hi-COLA_params_emu_0_GR.lua")
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-3]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-3]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-3]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-3]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-3]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-3]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-3]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-3]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-3]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-3]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-3]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-3]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-3]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-3]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-3]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-3]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-3]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-3]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-3]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-3]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-3]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-3]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-3]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-3]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-3]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-3]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-3]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-3]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-3]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-3]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-3]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-3]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 55 elements:
# #=====================================================
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.1e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.238611
#   cosmology_OmegaLambda          : 0.720179
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.0411296
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.7307
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : LCDM
#   cosmology_ns                   : 0.966
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 512
#   gravity_model                  : GR
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : false
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid.dat
#   ic_input_redshift              : 0
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 1234
#   ic_reverse_phases              : false
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 512
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_0_GR
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              20 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [LCDM]
# # Omegab      : 0.0411296
# # OmegaM      : 0.279741
# # OmegaMNu    : 0
# # OmegaCDM    : 0.238611
# # OmegaLambda : 0.720177
# # OmegaR      : 4.63157e-05
# # OmegaNu     : 3.20398e-05
# # OmegaRtot   : 7.83555e-05
# # OmegaK      : 0
# # h           : 0.7307
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 2.1e-09
# # ns          : 0.966
# # kpivot      : 0.05 1/Mpc
# #=====================================================
#
# #=====================================================
# # GravityModel is [GR] and has the cosmology: [LCDM]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_0_GR
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 512
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 0
# ic_nmesh                                 : 512
# ic_random_seed                           : 1234
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : false
# ic_reverse_phases                        : false
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 20
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 512
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/P_k_z/Pk_lin_z49_LCDM_fid.dat]
# # The P(k) is at the redshift: 0
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      0.00209587      12284.6
# 0.00251653      0.00482955      12048
# 0.00621709      0.0096912       11026.4
# 0.0153593       0.0136758       8462.66
# 0.0379453       0.00877938      4380.73
# 0.0937441       0.00334006      1745.73
# 0.231595        0.00080441      553.506
# 0.572157        0.000129994     143.757
# 1.41352         1.66025e-05     33.1925
# 3.4921          1.82034e-06     7.10092
# 8.62724         1.80056e-07     1.44287
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 0.0123831 (Mpc/h)^3
# k =  0.10: P(k,zini) = 0.00303743 (Mpc/h)^3
# k =  1.00: P(k,zini) = 3.72865e-05 (Mpc/h)^3
# k = 10.00: P(k,zini) = 1.22497e-07 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.0229968
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.0217911 Mpc/h
# Maximum 1LPT velocity: 8.13333 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 8.71913e-06 Mpc/h
# Maximum 2LPT velocity: 0.00652439 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 20
# Step: 0    / 20
# Positions  from z = 49              -> 13.4928
# Velocities from z = 49              -> 21.4719
# Step: 1    / 20
# Positions  from z = 13.4928         -> 7.47458
# Velocities from z = 21.4719         -> 9.69519
# Step: 2    / 20
# Positions  from z = 7.47458         -> 4.98802
# Velocities from z = 9.69519         -> 6.01754
# Step: 3    / 20
# Positions  from z = 4.98802         -> 3.62963
# Velocities from z = 6.01754         -> 4.22193
# Step: 4    / 20
# Positions  from z = 3.62963         -> 2.77358
# Velocities from z = 4.22193         -> 3.158
# Step: 5    / 20
# Positions  from z = 2.77358         -> 2.18471
# Velocities from z = 3.158           -> 2.45423
# Step: 6    / 20
# Positions  from z = 2.18471         -> 1.75482
# Velocities from z = 2.45423         -> 1.95421
# Step: 7    / 20
# Positions  from z = 1.75482         -> 1.42718
# Velocities from z = 1.95421         -> 1.58065
# Step: 8    / 20
# Positions  from z = 1.42718         -> 1.1692
# Velocities from z = 1.58065         -> 1.29095
# Step: 9    / 20
# Positions  from z = 1.1692          -> 0.960784
# Velocities from z = 1.29095         -> 1.05973
# Step: 10   / 20
# Positions  from z = 0.960784        -> 0.788909
# Velocities from z = 1.05973         -> 0.870907
# Step: 11   / 20
# Positions  from z = 0.788909        -> 0.644737
# Velocities from z = 0.870907        -> 0.713796
# Step: 12   / 20
# Positions  from z = 0.644737        -> 0.52207
# Velocities from z = 0.713796        -> 0.581028
# Step: 13   / 20
# Positions  from z = 0.52207         -> 0.416431
# Velocities from z = 0.581028        -> 0.467351
# Step: 14   / 20
# Positions  from z = 0.416431        -> 0.324503
# Velocities from z = 0.467351        -> 0.368925
# Step: 15   / 20
# Positions  from z = 0.324503        -> 0.243781
# Velocities from z = 0.368925        -> 0.282874
# Step: 16   / 20
# Positions  from z = 0.243781        -> 0.172333
# Velocities from z = 0.282874        -> 0.207001
# Step: 17   / 20
# Positions  from z = 0.172333        -> 0.108647
# Velocities from z = 0.207001        -> 0.139601
# Step: 18   / 20
# Positions  from z = 0.108647        -> 0.0515247
# Velocities from z = 0.139601        -> 0.0793308
# Step: 19   / 20
# Positions  from z = 0.0515247       -> 0
# Velocities from z = 0.0793308       -> 0.0251153
# Step: 20   / 20
# Positions  from z = 0               -> 0
# Velocities from z = 0.0251153       -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 20 Total steps taken: 0
# Positions from  z = 49              -> 13.4928
# Velocities from z = 49              -> 21.4719
# deltatime_pos = 12.2895         deltatime_vel = 13.0839
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 7.60208e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 8.6705e-06
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4195899 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5633 %% (min)
# #               50.3314 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1115.29         MB (min over tasks)
# # Current RSS: 1117.46         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 20 Total steps taken: 1
# Positions from  z = 13.4928         -> 7.47458
# Velocities from z = 21.4719         -> 9.69519
# deltatime_pos = 3.37867         deltatime_vel = 5.18325
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00014024
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.59704e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4195918 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.562 %% (min)
# #               50.3314 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1115.87         MB (min over tasks)
# # Current RSS: 1149.17         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 20 Total steps taken: 2
# Positions from  z = 7.47458         -> 4.98802
# Velocities from z = 9.69519         -> 6.01754
# deltatime_pos = 1.74668         deltatime_vel = 2.29042
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 7.96993e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.82825e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4195921 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5616 %% (min)
# #               50.3313 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1116.15         MB (min over tasks)
# # Current RSS: 1149.25         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 20 Total steps taken: 3
# Positions from  z = 4.98802         -> 3.62963
# Velocities from z = 6.01754         -> 4.22193
# deltatime_pos = 1.10629         deltatime_vel = 1.3519
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 5.54074e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.94559e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4195936 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5603 %% (min)
# #               50.332 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1116.38         MB (min over tasks)
# # Current RSS: 1149.35         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 20 Total steps taken: 4
# Positions from  z = 3.62963         -> 2.77358
# Velocities from z = 4.22193         -> 3.158
# deltatime_pos = 0.776488        deltatime_vel = 0.911948
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 4.19845e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 2.00624e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4195997 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.56 %% (min)
# #               50.3316 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1116.78         MB (min over tasks)
# # Current RSS: 1149.35         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 20 Total steps taken: 5
# Positions from  z = 2.77358         -> 2.18471
# Velocities from z = 3.158           -> 2.45423
# deltatime_pos = 0.579426        deltatime_vel = 0.663742
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 3.32854e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 2.04573e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196035 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5595 %% (min)
# #               50.332 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1117.06         MB (min over tasks)
# # Current RSS: 1149.35         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 20 Total steps taken: 6
# Positions from  z = 2.18471         -> 1.75482
# Velocities from z = 2.45423         -> 1.95421
# deltatime_pos = 0.449932        deltatime_vel = 0.506863
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 2.70621e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 2.07407e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196019 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.559 %% (min)
# #               50.3321 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1117.32         MB (min over tasks)
# # Current RSS: 1149.44         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 20 Total steps taken: 7
# Positions from  z = 1.75482         -> 1.42718
# Velocities from z = 1.95421         -> 1.58065
# deltatime_pos = 0.359038        deltatime_vel = 0.399771
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 2.23078e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 2.0693e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196024 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5592 %% (min)
# #               50.3319 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1117.58         MB (min over tasks)
# # Current RSS: 1149.71         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 20 Total steps taken: 8
# Positions from  z = 1.42718         -> 1.1692
# Velocities from z = 1.58065         -> 1.29095
# deltatime_pos = 0.292121        deltatime_vel = 0.322531
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 1.85154e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 2.03629e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196036 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5588 %% (min)
# #               50.332 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1117.84         MB (min over tasks)
# # Current RSS: 1149.98         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 9 / 20 Total steps taken: 9
# Positions from  z = 1.1692          -> 0.960784
# Velocities from z = 1.29095         -> 1.05973
# deltatime_pos = 0.241094        deltatime_vel = 0.264526
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 1.54217e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.97974e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196055 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5591 %% (min)
# #               50.3322 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1118.11         MB (min over tasks)
# # Current RSS: 1150.23         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 10 / 20 Total steps taken: 10
# Positions from  z = 0.960784        -> 0.788909
# Velocities from z = 1.05973         -> 0.870907
# deltatime_pos = 0.201158        deltatime_vel = 0.219641
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 1.28653e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.90444e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196036 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.559 %% (min)
# #               50.3322 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1118.37         MB (min over tasks)
# # Current RSS: 1150.5          MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 11 / 20 Total steps taken: 11
# Positions from  z = 0.788909        -> 0.644737
# Velocities from z = 0.870907        -> 0.713796
# deltatime_pos = 0.16929         deltatime_vel = 0.184127
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 1.07199e-05
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.81516e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196038 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5589 %% (min)
# #               50.3324 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1118.63         MB (min over tasks)
# # Current RSS: 1150.75         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 12 / 20 Total steps taken: 12
# Positions from  z = 0.644737        -> 0.52207
# Velocities from z = 0.713796        -> 0.581028
# deltatime_pos = 0.143491        deltatime_vel = 0.155557
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 8.91757e-06
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.71642e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196046 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5587 %% (min)
# #               50.3326 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1118.9          MB (min over tasks)
# # Current RSS: 1151.02         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 13 / 20 Total steps taken: 13
# Positions from  z = 0.52207         -> 0.416431
# Velocities from z = 0.581028        -> 0.467351
# deltatime_pos = 0.122374        deltatime_vel = 0.132286
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 7.40698e-06
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.61232e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196034 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5588 %% (min)
# #               50.3327 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1119.16         MB (min over tasks)
# # Current RSS: 1151.28         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 14 / 20 Total steps taken: 14
# Positions from  z = 0.416431        -> 0.324503
# Velocities from z = 0.467351        -> 0.368925
# deltatime_pos = 0.104942        deltatime_vel = 0.113148
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 6.14576e-06
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.50633e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196027 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.559 %% (min)
# #               50.3329 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1119.42         MB (min over tasks)
# # Current RSS: 1151.54         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 15 / 20 Total steps taken: 15
# Positions from  z = 0.324503        -> 0.243781
# Velocities from z = 0.368925        -> 0.282874
# deltatime_pos = 0.0904519       deltatime_vel = 0.0972898
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 5.09714e-06
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.40122e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196032 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5591 %% (min)
# #               50.3329 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1119.68         MB (min over tasks)
# # Current RSS: 1151.8          MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 16 / 20 Total steps taken: 16
# Positions from  z = 0.243781        -> 0.172333
# Velocities from z = 0.282874        -> 0.207001
# deltatime_pos = 0.0783372       deltatime_vel = 0.0840663
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 4.22863e-06
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.29909e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196048 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5591 %% (min)
# #               50.3329 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1119.95         MB (min over tasks)
# # Current RSS: 1152.09         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 17 / 20 Total steps taken: 17
# Positions from  z = 0.172333        -> 0.108647
# Velocities from z = 0.207001        -> 0.139601
# deltatime_pos = 0.0681562       deltatime_vel = 0.07298
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 3.51149e-06
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.20142e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196056 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5589 %% (min)
# #               50.3329 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1120.22         MB (min over tasks)
# # Current RSS: 1152.35         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 18 / 20 Total steps taken: 18
# Positions from  z = 0.108647        -> 0.0515247
# Velocities from z = 0.139601        -> 0.0793308
# deltatime_pos = 0.0595598       deltatime_vel = 0.0636399
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 2.9206e-06
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.10917e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196044 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5589 %% (min)
# #               50.333 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1120.47         MB (min over tasks)
# # Current RSS: 1152.62         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 19 / 20 Total steps taken: 19
# Positions from  z = 0.0515247       -> 0
# Velocities from z = 0.0793308       -> 0.0251153
# deltatime_pos = 0.0522689       deltatime_vel = 0.0557351
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 2.43428e-06
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 1.02286e-05
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196037 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5588 %% (min)
# #               50.333 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1120.74         MB (min over tasks)
# # Current RSS: 1152.88         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# Taking substep: 20 / 20 Total steps taken: 20
# Positions from  z = 0               -> 0
# Velocities from z = 0.0251153       -> 0
# deltatime_pos = 0               deltatime_vel = 0.0249822
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 5.26939e-07
# [Kick] + [Drift] COLA 2LPT
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4196037 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5588 %% (min)
# #               50.333 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 1121            MB (min over tasks)
# # Current RSS: 1153.13         MB (max over tasks)
# # Peak RSS:    1279.63         MB (min over tasks)
# # Peak RSS:    1281.27         MB (max over tasks)
# #=====================================================
#
# #=====================================================
# # Analyze and output
# #=====================================================
# Doing output 0 at redshift z = 0
# Snapshot will be stored in folder /home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/snapshot_my_new_Hi-COLA_simulation_0_GR_z0.000
# Adding on the LPT velocity to particles (COLA)
#
# #=====================================================
# # Computing power-spectrum of particles
# # pofk_nmesh                     : 512
# # pofk_density_assignment_method : PCS
# # pofk_interlacing               : true
# # pofk_subtract_shotnoise        : true
# #=====================================================
# Adding on the LPT velocity to particles (COLA)
#
# ============================================
# All the recorded timings for task 0:
# ============================================
# Total elapsed time for [COLA                               ]: 3.71992    sec
# Total elapsed time for [COLA output                        ]: 0.284915   sec
# Total elapsed time for [ComputeDensityField                ]: 17.856     sec
# Total elapsed time for [ComputeForce                       ]: 14.8738    sec
# Total elapsed time for [Drift                              ]: 6.20806    sec
# Total elapsed time for [InitialConditions                  ]: 6.92805    sec
# Total elapsed time for [InitialDensityField                ]: 1.43111    sec
# Total elapsed time for [Kick                               ]: 16.5484    sec
# Total elapsed time for [Power-spectrum                     ]: 6.25662    sec
# Total elapsed time for [The whole simulation               ]: 78.0407    sec
# Total elapsed time for [Timestepping                       ]: 67.4644    sec
# ============================================
#
#
# #=====================================================
# #                   MemoryLogging
# #=====================================================
#
# Info about resident set size:
# [Current resident set size]:
# Min over tasks:  978.084         MB
# Mean over tasks: 992.046         MB
# Max over tasks:  1009.95         MB
# [Peak resident set size]:
# Min over tasks:  1279.63         MB
# Mean over tasks: 1280.42         MB
# Max over tasks:  1281.27         MB
#
# For info below we are only tracking allocation of standard
# container (Vector) and only allocations larger than 0 bytes
#
# Memory in use (Task 0):   943.997         MB
# Min over tasks:           943.997         MB
# Mean over tasks:          943.997         MB
# Max over tasks:           943.997         MB
#
# Peak memory use (Task 0): 1122.95         MB
# Max over tasks:           1122.95         MB
#
#
# We have the following things allocated on task 0:
# Address: 0x7fab928d7010 Size: 872.415 (MB) Label: MPIPartices::create_particle_grid
# Address: 0x7fabcb162010 Size: 35.7908 (MB) Label: phi_2LPT(k,zini)
# Address: 0x7fabd1387010 Size: 35.7908 (MB) Label: phi_1LPT(k,zini)
#
# Total memory as function of time:
#  Time (sec): 0             Memory: 0             (MB)
#  Time (sec): 1.026e-06     Memory: 35.7908       (MB)
#  Time (sec): 1.44856       Memory: 71.5817       (MB)
#  Time (sec): 1.51843       Memory: 107.373       (MB)
#  Time (sec): 1.5624        Memory: 71.5817       (MB)
#  Time (sec): 1.6246        Memory: 107.373       (MB)
#  Time (sec): 1.68174       Memory: 143.163       (MB)
#  Time (sec): 1.74668       Memory: 107.373       (MB)
#  Time (sec): 1.7498        Memory: 143.163       (MB)
#  Time (sec): 1.77652       Memory: 178.954       (MB)
#  Time (sec): 1.79713       Memory: 143.163       (MB)
#  Time (sec): 1.80029       Memory: 178.954       (MB)
#  Time (sec): 1.83118       Memory: 214.745       (MB)
#  Time (sec): 1.84997       Memory: 178.954       (MB)
#  Time (sec): 2.36048       Memory: 214.745       (MB)
#  Time (sec): 2.38408       Memory: 250.536       (MB)
#  Time (sec): 2.4037        Memory: 214.745       (MB)
#  Time (sec): 2.56409       Memory: 178.954       (MB)
#  Time (sec): 2.56686       Memory: 143.163       (MB)
#  Time (sec): 2.57556       Memory: 107.373       (MB)
#  Time (sec): 2.57805       Memory: 143.163       (MB)
#  Time (sec): 2.59905       Memory: 178.954       (MB)
#  Time (sec): 2.62949       Memory: 143.163       (MB)
#  Time (sec): 2.63236       Memory: 178.954       (MB)
#  Time (sec): 2.65401       Memory: 214.745       (MB)
#  Time (sec): 2.67508       Memory: 178.954       (MB)
#  Time (sec): 2.67856       Memory: 214.745       (MB)
#  Time (sec): 2.70029       Memory: 250.536       (MB)
#  Time (sec): 2.72181       Memory: 214.745       (MB)
#  Time (sec): 3.45731       Memory: 178.954       (MB)
#  Time (sec): 3.46007       Memory: 143.163       (MB)
#  Time (sec): 3.46248       Memory: 107.373       (MB)
#  Time (sec): 4.14758       Memory: 979.788       (MB)
#  Time (sec): 4.89008       Memory: 1015.58       (MB)
#  Time (sec): 4.91445       Memory: 1051.37       (MB)
#  Time (sec): 4.93442       Memory: 1015.58       (MB)
#  Time (sec): 4.93908       Memory: 1051.37       (MB)
#  Time (sec): 4.96301       Memory: 1087.16       (MB)
#  Time (sec): 4.98273       Memory: 1051.37       (MB)
#  Time (sec): 4.98772       Memory: 1087.16       (MB)
#  Time (sec): 5.01159       Memory: 1122.95       (MB)
#  Time (sec): 5.09128       Memory: 1087.16       (MB)
#  Time (sec): 5.67137       Memory: 1051.37       (MB)
#  Time (sec): 6.11984       Memory: 1015.58       (MB)
#  Time (sec): 6.12338       Memory: 979.788       (MB)
#  Time (sec): 6.12639       Memory: 943.997       (MB)
#  Time (sec): 6.12922       Memory: 979.788       (MB)
#  Time (sec): 6.15624       Memory: 1015.58       (MB)
#  Time (sec): 6.17718       Memory: 1051.37       (MB)
#  Time (sec): 6.19676       Memory: 1015.58       (MB)
#  Time (sec): 6.1986        Memory: 1051.37       (MB)
#  Time (sec): 6.22003       Memory: 1087.16       (MB)
#  Time (sec): 6.24008       Memory: 1051.37       (MB)
#  Time (sec): 6.24196       Memory: 1087.16       (MB)
#  Time (sec): 6.2655        Memory: 1122.95       (MB)
#  Time (sec): 6.36771       Memory: 1087.16       (MB)
#  Time (sec): 6.91478       Memory: 1051.37       (MB)
#  Time (sec): 7.34965       Memory: 1015.58       (MB)
#  Time (sec): 7.35211       Memory: 979.788       (MB)
#  Time (sec): 7.35435       Memory: 943.997       (MB)
#  Time (sec): 8.07349       Memory: 979.788       (MB)
#  Time (sec): 8.28151       Memory: 1015.58       (MB)
#  Time (sec): 8.37642       Memory: 979.788       (MB)
#  Time (sec): 8.52122       Memory: 943.997       (MB)
#  Time (sec): 8.52886       Memory: 979.788       (MB)
#  Time (sec): 9.44632       Memory: 1015.58       (MB)
#  Time (sec): 9.46568       Memory: 1051.37       (MB)
#  Time (sec): 9.48447       Memory: 1087.16       (MB)
#  Time (sec): 11.4394       Memory: 1051.37       (MB)
#  Time (sec): 11.4462       Memory: 1015.58       (MB)
#  Time (sec): 11.4531       Memory: 979.788       (MB)
#  Time (sec): 11.4595       Memory: 943.997       (MB)
#  Time (sec): 11.4661       Memory: 979.788       (MB)
#  Time (sec): 12.3399       Memory: 1015.58       (MB)
#  Time (sec): 12.3588       Memory: 1051.37       (MB)
#  Time (sec): 12.3777       Memory: 1087.16       (MB)
#  Time (sec): 14.3222       Memory: 1051.37       (MB)
#  Time (sec): 14.3304       Memory: 1015.58       (MB)
#  Time (sec): 14.3384       Memory: 979.788       (MB)
#  Time (sec): 14.3461       Memory: 943.997       (MB)
#  Time (sec): 14.3535       Memory: 979.788       (MB)
#  Time (sec): 15.2137       Memory: 1015.58       (MB)
#  Time (sec): 15.2328       Memory: 1051.37       (MB)
#  Time (sec): 15.252        Memory: 1087.16       (MB)
#  Time (sec): 17.2019       Memory: 1051.37       (MB)
#  Time (sec): 17.2096       Memory: 1015.58       (MB)
#  Time (sec): 17.2164       Memory: 979.788       (MB)
#  Time (sec): 17.2233       Memory: 943.997       (MB)
#  Time (sec): 17.2305       Memory: 979.788       (MB)
#  Time (sec): 18.0738       Memory: 1015.58       (MB)
#  Time (sec): 18.0931       Memory: 1051.37       (MB)
#  Time (sec): 18.112        Memory: 1087.16       (MB)
#  Time (sec): 20.0591       Memory: 1051.37       (MB)
#  Time (sec): 20.0678       Memory: 1015.58       (MB)
#  Time (sec): 20.0762       Memory: 979.788       (MB)
#  Time (sec): 20.0845       Memory: 943.997       (MB)
#  Time (sec): 20.0921       Memory: 979.788       (MB)
#  Time (sec): 20.9726       Memory: 1015.58       (MB)
#  Time (sec): 20.9971       Memory: 1051.37       (MB)
#  Time (sec): 21.0214       Memory: 1087.16       (MB)
#  Time (sec): 22.9856       Memory: 1051.37       (MB)
#  Time (sec): 22.9929       Memory: 1015.58       (MB)
#  Time (sec): 22.9996       Memory: 979.788       (MB)
#  Time (sec): 23.0065       Memory: 943.997       (MB)
#  Time (sec): 23.0131       Memory: 979.788       (MB)
#  Time (sec): 23.8897       Memory: 1015.58       (MB)
#  Time (sec): 23.9087       Memory: 1051.37       (MB)
#  Time (sec): 23.9277       Memory: 1087.16       (MB)
#  Time (sec): 25.8845       Memory: 1051.37       (MB)
#  Time (sec): 25.8919       Memory: 1015.58       (MB)
#  Time (sec): 25.8988       Memory: 979.788       (MB)
#  Time (sec): 25.9058       Memory: 943.997       (MB)
#  Time (sec): 25.9128       Memory: 979.788       (MB)
#  Time (sec): 26.7896       Memory: 1015.58       (MB)
#  Time (sec): 26.8142       Memory: 1051.37       (MB)
#  Time (sec): 26.8388       Memory: 1087.16       (MB)
#  Time (sec): 28.7659       Memory: 1051.37       (MB)
#  Time (sec): 28.7743       Memory: 1015.58       (MB)
#  Time (sec): 28.7824       Memory: 979.788       (MB)
#  Time (sec): 28.7904       Memory: 943.997       (MB)
#  Time (sec): 28.798        Memory: 979.788       (MB)
#  Time (sec): 29.6458       Memory: 1015.58       (MB)
#  Time (sec): 29.6701       Memory: 1051.37       (MB)
#  Time (sec): 29.6942       Memory: 1087.16       (MB)
#  Time (sec): 31.6738       Memory: 1051.37       (MB)
#  Time (sec): 31.6814       Memory: 1015.58       (MB)
#  Time (sec): 31.6882       Memory: 979.788       (MB)
#  Time (sec): 31.6948       Memory: 943.997       (MB)
#  Time (sec): 31.7014       Memory: 979.788       (MB)
#  Time (sec): 32.6149       Memory: 1015.58       (MB)
#  Time (sec): 32.6339       Memory: 1051.37       (MB)
#  Time (sec): 32.6529       Memory: 1087.16       (MB)
#  Time (sec): 34.6098       Memory: 1051.37       (MB)
#  Time (sec): 34.6176       Memory: 1015.58       (MB)
#  Time (sec): 34.6248       Memory: 979.788       (MB)
#  Time (sec): 34.6316       Memory: 943.997       (MB)
#  Time (sec): 34.6387       Memory: 979.788       (MB)
#  Time (sec): 35.4946       Memory: 1015.58       (MB)
#  Time (sec): 35.5142       Memory: 1051.37       (MB)
#  Time (sec): 35.5331       Memory: 1087.16       (MB)
#  Time (sec): 37.4852       Memory: 1051.37       (MB)
#  Time (sec): 37.4939       Memory: 1015.58       (MB)
#  Time (sec): 37.5021       Memory: 979.788       (MB)
#  Time (sec): 37.51         Memory: 943.997       (MB)
#  Time (sec): 37.5177       Memory: 979.788       (MB)
#  Time (sec): 38.3765       Memory: 1015.58       (MB)
#  Time (sec): 38.396        Memory: 1051.37       (MB)
#  Time (sec): 38.415        Memory: 1087.16       (MB)
#  Time (sec): 40.3736       Memory: 1051.37       (MB)
#  Time (sec): 40.381        Memory: 1015.58       (MB)
#  Time (sec): 40.3879       Memory: 979.788       (MB)
#  Time (sec): 40.3947       Memory: 943.997       (MB)
#  Time (sec): 40.4017       Memory: 979.788       (MB)
#  Time (sec): 41.3295       Memory: 1015.58       (MB)
#  Time (sec): 41.3486       Memory: 1051.37       (MB)
#  Time (sec): 41.3676       Memory: 1087.16       (MB)
#  Time (sec): 43.3442       Memory: 1051.37       (MB)
#  Time (sec): 43.3518       Memory: 1015.58       (MB)
#  Time (sec): 43.3586       Memory: 979.788       (MB)
#  Time (sec): 43.3652       Memory: 943.997       (MB)
#  Time (sec): 43.3724       Memory: 979.788       (MB)
#  Time (sec): 44.2477       Memory: 1015.58       (MB)
#  Time (sec): 44.2668       Memory: 1051.37       (MB)
#  Time (sec): 44.2857       Memory: 1087.16       (MB)
#  Time (sec): 46.2567       Memory: 1051.37       (MB)
#  Time (sec): 46.2642       Memory: 1015.58       (MB)
#  Time (sec): 46.2715       Memory: 979.788       (MB)
#  Time (sec): 46.2785       Memory: 943.997       (MB)
#  Time (sec): 46.2857       Memory: 979.788       (MB)
#  Time (sec): 47.1957       Memory: 1015.58       (MB)
#  Time (sec): 47.2147       Memory: 1051.37       (MB)
#  Time (sec): 47.2335       Memory: 1087.16       (MB)
#  Time (sec): 49.1822       Memory: 1051.37       (MB)
#  Time (sec): 49.1913       Memory: 1015.58       (MB)
#  Time (sec): 49.2001       Memory: 979.788       (MB)
#  Time (sec): 49.2086       Memory: 943.997       (MB)
#  Time (sec): 49.2166       Memory: 979.788       (MB)
#  Time (sec): 50.1075       Memory: 1015.58       (MB)
#  Time (sec): 50.1265       Memory: 1051.37       (MB)
#  Time (sec): 50.1452       Memory: 1087.16       (MB)
#  Time (sec): 52.0882       Memory: 1051.37       (MB)
#  Time (sec): 52.0957       Memory: 1015.58       (MB)
#  Time (sec): 52.1025       Memory: 979.788       (MB)
#  Time (sec): 52.1092       Memory: 943.997       (MB)
#  Time (sec): 52.1162       Memory: 979.788       (MB)
#  Time (sec): 53.0237       Memory: 1015.58       (MB)
#  Time (sec): 53.0429       Memory: 1051.37       (MB)
#  Time (sec): 53.0621       Memory: 1087.16       (MB)
#  Time (sec): 55.0687       Memory: 1051.37       (MB)
#  Time (sec): 55.0767       Memory: 1015.58       (MB)
#  Time (sec): 55.0839       Memory: 979.788       (MB)
#  Time (sec): 55.0911       Memory: 943.997       (MB)
#  Time (sec): 55.0986       Memory: 979.788       (MB)
#  Time (sec): 55.9656       Memory: 1015.58       (MB)
#  Time (sec): 55.9847       Memory: 1051.37       (MB)
#  Time (sec): 56.0036       Memory: 1087.16       (MB)
#  Time (sec): 57.99         Memory: 1051.37       (MB)
#  Time (sec): 57.9989       Memory: 1015.58       (MB)
#  Time (sec): 58.007        Memory: 979.788       (MB)
#  Time (sec): 58.015        Memory: 943.997       (MB)
#  Time (sec): 58.0229       Memory: 979.788       (MB)
#  Time (sec): 58.8964       Memory: 1015.58       (MB)
#  Time (sec): 58.9209       Memory: 1051.37       (MB)
#  Time (sec): 58.9453       Memory: 1087.16       (MB)
#  Time (sec): 60.8904       Memory: 1051.37       (MB)
#  Time (sec): 60.8979       Memory: 1015.58       (MB)
#  Time (sec): 60.9052       Memory: 979.788       (MB)
#  Time (sec): 60.9121       Memory: 943.997       (MB)
#  Time (sec): 60.9193       Memory: 979.788       (MB)
#  Time (sec): 61.7804       Memory: 1015.58       (MB)
#  Time (sec): 61.7995       Memory: 1051.37       (MB)
#  Time (sec): 61.8184       Memory: 1087.16       (MB)
#  Time (sec): 63.7854       Memory: 1051.37       (MB)
#  Time (sec): 63.7931       Memory: 1015.58       (MB)
#  Time (sec): 63.8001       Memory: 979.788       (MB)
#  Time (sec): 63.8071       Memory: 943.997       (MB)
#  Time (sec): 63.8139       Memory: 979.788       (MB)
#  Time (sec): 64.6775       Memory: 1015.58       (MB)
#  Time (sec): 64.7021       Memory: 1051.37       (MB)
#  Time (sec): 64.7265       Memory: 1087.16       (MB)
#  Time (sec): 66.6822       Memory: 1051.37       (MB)
#  Time (sec): 66.6905       Memory: 1015.58       (MB)
#  Time (sec): 66.6986       Memory: 979.788       (MB)
#  Time (sec): 66.7065       Memory: 943.997       (MB)
#  Time (sec): 66.7143       Memory: 979.788       (MB)
#  Time (sec): 67.5384       Memory: 1015.58       (MB)
#  Time (sec): 67.5578       Memory: 1051.37       (MB)
#  Time (sec): 67.5768       Memory: 1087.16       (MB)
#  Time (sec): 69.2277       Memory: 1051.37       (MB)
#  Time (sec): 69.236        Memory: 1015.58       (MB)
#  Time (sec): 69.2437       Memory: 979.788       (MB)
#  Time (sec): 69.2514       Memory: 943.997       (MB)
#  Time (sec): 69.6358       Memory: 986.104       (MB)
#  Time (sec): 71.895        Memory: 1028.21       (MB)
#  Time (sec): 75.0163       Memory: 986.104       (MB)
#  Time (sec): 75.5787       Memory: 943.997       (MB)
#
# #=====================================================
# 0

# %% [markdown]
# # Comparison Plots

# %%
## Plotting ##

fig, axs = plt.subplots(1)
expansioni = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_0_expansion.txt")

expansionPap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/Galdat_f1p0_EdS_max_expansion.txt")

expansion_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today/horndeski_model_run_0_expansion.txt")

a = expansioni.T[0]
E_a = expansioni.T[1]

a_Pap = expansionPap.T[0]
E_a_Pap = expansionPap.T[1]

a_today = expansion_today.T[0]
E_a_today = expansion_today.T[1]

E_a_GR = np.sqrt((wb+wc)*a**(-3) + wr*a**(-4) + (h**2 - (wb+wc) -wr))/h
plt.plot(1/a -1, E_a_Pap/E_a_GR, alpha=1, color="k")
plt.plot(1/a -1, E_a/E_a_GR, "g--", alpha=1)
plt.plot(1/a -1, E_a_today/E_a_GR, "r--", alpha=1)


plt.xscale("log")

plt.xlabel("z")
plt.ylabel(r"$E^{CuGal}/E^{\Lambda CDM}$")
# Out:
# Text(0, 0.5, '$E^{CuGal}/E^{\\Lambda CDM}$')

# %%
## Plotting ##

fig, axs = plt.subplots(1)
force = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_0_force.txt")
#force_new = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output/horndeski_model_run_0_force_2.txt")
force_today = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Output_today/horndeski_model_run_0_force.txt")

forcePap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/Galdat_f1p0_EdS_max_screencoupl.txt")
forcePap1 = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/cG-f1.0_force.txt")

#force_new = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/cuGal_f1p0_WMAP_force.txt")

a = force.T[0]
chiD = force.T[1]
coupling = force.T[2]

aPap = forcePap.T[0]
chiDPap = forcePap.T[1]
couplingPap = forcePap.T[2]

aPap1 = forcePap1.T[0]
chiDPap1 = forcePap1.T[1]
couplingPap1 = forcePap1.T[2]

aPap_today = force_today.T[0]
chiDPap_today = force_today.T[1]
couplingPap_today = force_today.T[2]

plt.plot(1/a -1, chiD, alpha=1, color="k")
plt.plot(1/a -1, chiDPap, alpha=1, color="r")
plt.plot(1/a -1, chiDPap1, "g--",alpha=1)
plt.plot(1/a -1, chiDPap_today, "b--",alpha=1)
#plt.plot(1/a -1, couplingPap, alpha=1, color="k")
#plt.plot(1/a -1, coupling-couplingPap, "r--", alpha=1)


plt.xscale("log")

plt.xlabel("z")
plt.ylabel(r"$E^{CuGal}/E^{\Lambda CDM}$")
# Out:
# Text(0, 0.5, '$E^{CuGal}/E^{\\Lambda CDM}$')

# %%
"""Plotting the Boost for the simulations at z = 0"""


k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/pofk_my_new_Hi-COLA_simulation_0_cb_z0.000.txt").T
k, Pk_NL_GR,Pk_Lin_GR = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_GR/pofk_my_new_Hi-COLA_simulation_0_GR_cb_z0.000.txt").T

k, Pk_NL_norad,Pk_Lin_norad = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/pofk_my_new_Hi-COLA_simulation_0_norad_cb_z0.000.txt").T

k, Pk_NL_T_norad,Pk_Lin_T_norad = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_T/pofk_my_new_Hi-COLA_simulation_0_norad_cb_z0.000.txt").T



k_pap, Pk_NL_pap,Pk_Lin_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_cuGal_fphi1p0_z-0.002.txt").T
k_pap, Pk_NL_GR_pap,Pk_Lin_GR_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_GR-LCDM_z-0.002.txt").T


#plt.plot(k,Pk_NL/Pk_NL_GR)
#plt.plot(k_pap,Pk_NL_pap/Pk_NL_GR_pap)

#plt.plot(k,Pk_NL_GR, "g")
#plt.plot(k_pap,Pk_NL_GR_pap)

plt.plot(k_pap,Pk_NL_pap, "k")

plt.plot(k,Pk_NL, "r")
plt.plot(k,Pk_NL_norad, "g--")
plt.plot(k,Pk_NL_T_norad, "g--")

plt.xscale("log")
plt.yscale("log")

plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("$B(k)$ ")
# Out:
# Text(0, 0.5, '$B(k)$ ')

# %%
# Plotting boosts


plt.plot(k_pap,Pk_NL_pap/Pk_NL_GR_pap, "k")

plt.plot(k,Pk_NL/Pk_NL_GR, "r")
plt.plot(k,Pk_NL_norad/Pk_NL_GR, "g--")
plt.plot(k,Pk_NL_T_norad/Pk_NL_GR, "b--")


plt.xscale("log")
plt.xlim(1e-2,2)
plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("$B(k)$ ")
# Out:
# Text(0, 0.5, '$B(k)$ ')

# %%
# Plotting boost ratios = Pk ratios with and without radiation effects


plt.plot(k,(Pk_NL)/(Pk_NL_norad), "r")

plt.plot(k,np.ones(len(k)), "k--")

plt.xscale("log")
plt.xlim(1e-2,2)
plt.ylim(0.96,1.04)

plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("ratio ")
# Out:
# Text(0, 0.5, 'ratio ')

# %%
"""Plotting the Boost for the simulations at z = 0"""


k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/pofk_my_new_Hi-COLA_simulation_0_cb_z0.000.txt").T
k, Pk_NL_GR,Pk_Lin_GR = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_GR/pofk_my_new_Hi-COLA_simulation_0_GR_cb_z0.000.txt").T

#k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/snapshot_my_new_Hi-COLA_simulation_0_z0.000/pofk_z0.000.txt").T


k_pap, Pk_NL_pap,Pk_Lin_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_cuGal_fphi1p0_z-0.002.txt").T
k_pap, Pk_NL_GR_pap,Pk_Lin_GR_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_GR-LCDM_z-0.002.txt").T


#plt.plot(k,Pk_NL/Pk_NL_GR)
#plt.plot(k_pap,Pk_NL_pap/Pk_NL_GR_pap)

plt.plot(k,Pk_NL_GR, "g")
#plt.plot(k_pap,Pk_NL_GR_pap)


plt.plot(k,Pk_NL)
plt.plot(k_pap,Pk_NL_pap)

plt.xscale("log")
plt.yscale("log")

plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("$B(k)$ ")
# Out:
# Text(0, 0.5, '$B(k)$ ')

# %%
"""Plotting the Boost for the simulations at z = 0"""


k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/pofk_my_new_Hi-COLA_simulation_0_cb_z0.000.txt").T
k, Pk_NL_GR,Pk_Lin_GR = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_GR/pofk_my_new_Hi-COLA_simulation_0_GR_cb_z0.000.txt").T

#k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/snapshot_my_new_Hi-COLA_simulation_0_z0.000/pofk_z0.000.txt").T


k_pap, Pk_NL_pap,Pk_Lin_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_cuGal_fphi1p0_z-0.002.txt").T
k_pap, Pk_NL_GR_pap,Pk_Lin_GR_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_GR-LCDM_z-0.002.txt").T

# Ashim re-running same things
k_ACode, Pk_NL_ACode,Pk_Lin_ACode = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_cuGal_bgCarola_icCCL_cb_z0.000.txt").T
k_ACode, Pk_NL_GR_ACode,Pk_Lin_GR_ACode = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_LCDM_bgFML_icCCL_cb_z0.000.txt").T


#plt.plot(k,Pk_NL/Pk_NL_GR)
#plt.plot(k_pap,Pk_NL_pap/Pk_NL_GR_pap)

#plt.plot(k,Pk_NL_GR, "g")
#plt.plot(k,Pk_NL_GR_ACode, "r--")
#plt.plot(k_pap,Pk_NL_GR_pap)


plt.plot(k,Pk_NL)
plt.plot(k_pap,Pk_NL_pap)

#plt.plot(k_pap,Pk_NL_pap)

plt.xscale("log")
plt.yscale("log")

plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("$P(k)$ ")
# Out:
# Text(0, 0.5, '$P(k)$ ')

# %%
"""Plotting the Boost for the simulations at z = 0"""


k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/pofk_my_new_Hi-COLA_simulation_0_cb_z0.000.txt").T
k, Pk_NL_GR,Pk_Lin_GR = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_GR/pofk_my_new_Hi-COLA_simulation_0_GR_cb_z0.000.txt").T

#k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/snapshot_my_new_Hi-COLA_simulation_0_z0.000/pofk_z0.000.txt").T


k_pap, Pk_NL_pap,Pk_Lin_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_cuGal_fphi1p0_z-0.002.txt").T
k_pap, Pk_NL_GR_pap,Pk_Lin_GR_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_GR-LCDM_z-0.002.txt").T


#plt.plot(k,Pk_NL/Pk_NL_GR)
#plt.plot(k_pap,Pk_NL_pap/Pk_NL_GR_pap)

plt.plot(k,Pk_NL_GR)
plt.plot(k_pap,Pk_NL_GR_pap)


#plt.plot(k,Pk_NL)
#plt.plot(k_pap,Pk_NL_pap)

plt.xscale("log")
plt.yscale("log")

plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("$P(k)$ ")
# Out:
# Text(0, 0.5, '$P(k)$ ')

# %%
"""Plotting the Boost for the simulations at z = 0"""


k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/pofk_my_new_Hi-COLA_simulation_0_cb_z0.000.txt").T
k, Pk_NL_GR,Pk_Lin_GR = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_GR/pofk_my_new_Hi-COLA_simulation_0_GR_cb_z0.000.txt").T

#k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/snapshot_my_new_Hi-COLA_simulation_0_z0.000/pofk_z0.000.txt").T


k_pap, Pk_NL_pap,Pk_Lin_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_cuGal_fphi1p0_z-0.002.txt").T
k_pap, Pk_NL_GR_pap,Pk_Lin_GR_pap = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Backend_input_parameter_files/Ashim_files/pofk_GR-LCDM_z-0.002.txt").T


#plt.plot(k,Pk_NL/Pk_NL_GR)
#plt.plot(k_pap,Pk_NL_pap/Pk_NL_GR_pap)

#plt.plot(k,Pk_NL_GR)
#plt.plot(k_pap,Pk_NL_GR_pap)


plt.plot(k,Pk_NL_pap/Pk_NL_GR_pap)

plt.xscale("log")
plt.xlim(1e-2,2)
plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("$B(k)$ ")
# Out:
# Text(0, 0.5, '$B(k)$ ')

# %%
Pk_nl =ccl.nonlin_matter_power(cosmoLCDM, k*h, 1)

# %%
"""Plotting the NL power spectra for the simulations at z = 0"""


k, Pk_NL,Pk_Lin = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0/pofk_my_new_Hi-COLA_simulation_0_cb_z0.000.txt").T
k, Pk_NL_GR,Pk_Lin_GR = np.loadtxt("/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Output_backend/COLA_0_GR/pofk_my_new_Hi-COLA_simulation_0_GR_cb_z0.000.txt").T

#plt.plot(k,Pk_NL, "r", label = "MG")
#plt.plot(k,Pk_NL_GR, "g", label = "GR")
#plt.plot(kk/h,Pk_nl*h**3, "k--", label = "GR, ccl")


plt.plot(k,Pk_NL/(Pk_nl*h**3), "r", label = "MG")
plt.plot(k,Pk_NL_GR/(Pk_nl*h**3), "g", label = "GR")

#plt.plot(k,Pk_NL/Pk_nl, label = "CuGal")
plt.xscale("log")
#plt.yscale("log")
plt.legend()

plt.xlabel(r"k [h $Mpc^{-1}]$")
#plt.ylabel("$\dfrac{P_{NL}(k)}{P_{lin}(k)}$")
plt.ylabel("$P^{CG}_{NL}(k)$ [h $Mpc^{-1}]^{-3}$")
# Out:
# Text(0, 0.5, '$P^{CG}_{NL}(k)$ [h $Mpc^{-1}]^{-3}$')
